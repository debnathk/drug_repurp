# %% [markdown]
# ### A Deep Learning based Efficacy Prediction System for Drug Discovery

# %% [markdown]
# Here shows the demo for training process

# %%
########################################################
# All rights reserved. 
# Author: XIE Zhengwei @ Beijing Gigaceuticals Tech Co., Ltd 
#                      @ Peking University International Cancer Institute
# Contact: xiezhengwei@gmail.com
#
#
########################################################
import os
import pdb
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
os.environ["CUDA_VISIBLE_DEVICES"] = "4"

from keras import backend as K
import utils
# from densenet import DLEPS
import molecule_vae
from dleps.code.DLEPS.dti_predictor_gvae_cnn import DLEPS
# import tensorflow as tf
# from deepPurpose_CNN import CNN
import keras
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping


## Note: protobuf error can be resolved by downgrading it v3.20.1
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
# Drug model

dleps_p = DLEPS()
model = dleps_p.model[0]
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\debnathk\Desktop\study\drug_repurp\dleps\code\DLEPS\models\model_zinc.py:115: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 277, 76)      0
# __________________________________________________________________________________________________
# conv_1 (Conv1D)                 (None, 269, 9)       6165        input_4[0][0]
# __________________________________________________________________________________________________
# visible_1 (InputLayer)          (None, 26, 1000)     0
# __________________________________________________________________________________________________
# conv_2 (Conv1D)                 (None, 261, 9)       738         conv_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 26, 32)       96032       visible_1[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv1D)                 (None, 251, 10)      1000        conv_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 13, 32)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 2510)         0           conv_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 13, 64)       6208        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 435)          1092285     flatten_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 6, 64)        0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 56)           24416       dense_1[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 56)           24416       dense_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 384)          0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 56)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 56)           21560       flatten_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 112)          0           lambda[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 512)          57856       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 512)          262656      dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 512)          0           dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 512)          262656      dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 512)          262656      dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           dense_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            513         dropout_4[0][0]
# ==================================================================================================
# Total params: 2,119,157
# Trainable params: 2,119,157
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Load dataset

import h5py

h5f = h5py.File('../../data/drugs.h5', 'r')
drugs = h5f['data'][:]
h5f = h5py.File('../../data/proteins.h5', 'r')
proteins = h5f['data'][:]
h5f = h5py.File('../../data/pIC50.h5', 'r')
labels = h5f['data'][:]


print(drugs.shape)
print(proteins.shape)
print(labels.shape)
# Out:
# (18815, 277, 76)
# (18815, 26, 1000)
# (18815,)

# %%
# Clean data to remove inf, nan, if present any
drugs = utils.clean_data(drugs, fill_value=0)
proteins = utils.clean_data(proteins, fill_value=0)
labels = utils.clean_data(labels)

# %%
# Split dataset

drug_train, protein_train, y_train, drug_val, protein_val, y_val, drug_test, protein_test, y_test = utils.train_val_test_split(drugs, proteins, labels)

# %%
print(drug_train.shape)
print(protein_train.shape)
print(y_train.shape)
print(drug_val.shape)
print(protein_val.shape)
print(y_val.shape)
print(drug_test.shape)
print(protein_test.shape)
print(y_test.shape)
# Out:
# (13170, 277, 76)
# (13170, 26, 1000)
# (13170,)
# (2822, 277, 76)
# (2822, 26, 1000)
# (2822,)
# (2823, 277, 76)
# (2823, 26, 1000)
# (2823,)

# %% [markdown]
# ## Leveraging transfer learning for pretrained models

# %%
# Freezing already trained layers
# for layers in model.layers[:-8]:
#     layers.trainable = False

# %%
# compile the model
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])

# %%
# Use ModelCheckpoint to save model and weights
from keras.callbacks import ModelCheckpoint
# filepath = "weights.best.sequential.hdf5" - best
# filepath = "weights.best.sample.hdf5"
filepath = "test.weights.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
# Use the final model to get a single output
epochs = 100
batch_size = 256
early_stopping = EarlyStopping(monitor='val_mae', patience=10)
history = model.fit([drug_train, protein_train], y_train, batch_size=batch_size, epochs=epochs, callbacks=[checkpoint, early_stopping], validation_data=([drug_val, protein_val], y_val))
# Out:
# WARNING:tensorflow:From c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 13170 samples, validate on 2822 samples
# Epoch 1/100
# 13170/13170 [==============================] - 39s 3ms/step - loss: 5.7493 - mae: 1.8274 - val_loss: 4.1882 - val_mae: 1.6654
#
# Epoch 00001: val_loss improved from inf to 4.18819, saving model to test.weights.hdf5
# Epoch 2/100
# 13170/13170 [==============================] - 29s 2ms/step - loss: 2.5517 - mae: 1.2717 - val_loss: 4.8567 - val_mae: 1.8325
#
# Epoch 00002: val_loss did not improve from 4.18819
# Epoch 3/100
# 13170/13170 [==============================] - 36s 3ms/step - loss: 2.2740 - mae: 1.1869 - val_loss: 4.4062 - val_mae: 1.7540
#
# Epoch 00003: val_loss did not improve from 4.18819
# Epoch 4/100
# 13170/13170 [==============================] - 31s 2ms/step - loss: 2.0152 - mae: 1.1096 - val_loss: 3.2979 - val_mae: 1.4933
#
# Epoch 00004: val_loss improved from 4.18819 to 3.29793, saving model to test.weights.hdf5
# Epoch 5/100
# 13170/13170 [==============================] - 36s 3ms/step - loss: 1.9019 - mae: 1.0753 - val_loss: 3.5063 - val_mae: 1.5601
#
# Epoch 00005: val_loss did not improve from 3.29793
# Epoch 6/100
# 13170/13170 [==============================] - 39s 3ms/step - loss: 1.7516 - mae: 1.0195 - val_loss: 2.4638 - val_mae: 1.2459
#
# Epoch 00006: val_loss improved from 3.29793 to 2.46380, saving model to test.weights.hdf5
# Epoch 7/100
# 13170/13170 [==============================] - 39s 3ms/step - loss: 1.6369 - mae: 0.9857 - val_loss: 2.1956 - val_mae: 1.1778
#
# Epoch 00007: val_loss improved from 2.46380 to 2.19556, saving model to test.weights.hdf5
# Epoch 8/100
# 13170/13170 [==============================] - 33s 3ms/step - loss: 1.5393 - mae: 0.9500 - val_loss: 2.2158 - val_mae: 1.1901
#
# Epoch 00008: val_loss did not improve from 2.19556
# Epoch 9/100
# 13170/13170 [==============================] - 27s 2ms/step - loss: 1.4695 - mae: 0.9276 - val_loss: 1.7735 - val_mae: 1.0453
#
# Epoch 00009: val_loss improved from 2.19556 to 1.77353, saving model to test.weights.hdf5
# Epoch 10/100
# 13170/13170 [==============================] - 29s 2ms/step - loss: 1.4032 - mae: 0.9058 - val_loss: 1.5050 - val_mae: 0.9465
#
# Epoch 00010: val_loss improved from 1.77353 to 1.50505, saving model to test.weights.hdf5
# Epoch 11/100
# 13170/13170 [==============================] - 31s 2ms/step - loss: 1.3490 - mae: 0.8825 - val_loss: 1.7964 - val_mae: 1.0453
#
# Epoch 00011: val_loss did not improve from 1.50505
# Epoch 12/100
# 13170/13170 [==============================] - 30s 2ms/step - loss: 1.2976 - mae: 0.8604 - val_loss: 1.8946 - val_mae: 1.0742
#
# Epoch 00012: val_loss did not improve from 1.50505
# Epoch 13/100
# 13170/13170 [==============================] - 26s 2ms/step - loss: 1.2864 - mae: 0.8538 - val_loss: 1.4209 - val_mae: 0.9084
#
# Epoch 00013: val_loss improved from 1.50505 to 1.42092, saving model to test.weights.hdf5
# Epoch 14/100
# 13170/13170 [==============================] - 30s 2ms/step - loss: 1.2615 - mae: 0.8443 - val_loss: 1.4028 - val_mae: 0.9079
#
# Epoch 00014: val_loss improved from 1.42092 to 1.40280, saving model to test.weights.hdf5
# Epoch 15/100
# 13170/13170 [==============================] - 29s 2ms/step - loss: 1.2047 - mae: 0.8255 - val_loss: 1.5413 - val_mae: 0.9515
#
# Epoch 00015: val_loss did not improve from 1.40280
# Epoch 16/100
# 13170/13170 [==============================] - 27s 2ms/step - loss: 1.1913 - mae: 0.8193 - val_loss: 1.5763 - val_mae: 0.9708
#
# Epoch 00016: val_loss did not improve from 1.40280
# Epoch 17/100
# 13170/13170 [==============================] - 30s 2ms/step - loss: 1.1657 - mae: 0.8049 - val_loss: 1.5063 - val_mae: 0.9397
#
# Epoch 00017: val_loss did not improve from 1.40280
# Epoch 18/100
# 13170/13170 [==============================] - 29s 2ms/step - loss: 1.1497 - mae: 0.7969 - val_loss: 1.7193 - val_mae: 1.0117
#
# Epoch 00018: val_loss did not improve from 1.40280
# Epoch 19/100
# 13170/13170 [==============================] - 28s 2ms/step - loss: 1.1455 - mae: 0.7983 - val_loss: 1.3430 - val_mae: 0.8615
#
# Epoch 00019: val_loss improved from 1.40280 to 1.34303, saving model to test.weights.hdf5
# Epoch 20/100
# 13170/13170 [==============================] - 25s 2ms/step - loss: 1.1010 - mae: 0.7814 - val_loss: 1.3777 - val_mae: 0.8698
#
# Epoch 00020: val_loss did not improve from 1.34303
# Epoch 21/100
# 13170/13170 [==============================] - 24s 2ms/step - loss: 1.0861 - mae: 0.7700 - val_loss: 1.3359 - val_mae: 0.8503
#
# Epoch 00021: val_loss improved from 1.34303 to 1.33591, saving model to test.weights.hdf5
# Epoch 22/100
# 13170/13170 [==============================] - 27s 2ms/step - loss: 1.0979 - mae: 0.7759 - val_loss: 1.3467 - val_mae: 0.8586
#
# Epoch 00022: val_loss did not improve from 1.33591
# Epoch 23/100
# 13170/13170 [==============================] - 30s 2ms/step - loss: 1.0665 - mae: 0.7634 - val_loss: 1.3673 - val_mae: 0.8788
#
# Epoch 00023: val_loss did not improve from 1.33591
# Epoch 24/100
# 13170/13170 [==============================] - 30s 2ms/step - loss: 1.0418 - mae: 0.7503 - val_loss: 1.3430 - val_mae: 0.8695
#
# Epoch 00024: val_loss did not improve from 1.33591
# Epoch 25/100
# 13170/13170 [==============================] - 32s 2ms/step - loss: 1.0460 - mae: 0.7552 - val_loss: 1.3560 - val_mae: 0.8639
#
# Epoch 00025: val_loss did not improve from 1.33591
# Epoch 26/100
# 13170/13170 [==============================] - 29s 2ms/step - loss: 1.0414 - mae: 0.7507 - val_loss: 1.3306 - val_mae: 0.8527
#
# Epoch 00026: val_loss improved from 1.33591 to 1.33064, saving model to test.weights.hdf5
# Epoch 27/100
# 13170/13170 [==============================] - 31s 2ms/step - loss: 1.0473 - mae: 0.7510 - val_loss: 1.4142 - val_mae: 0.8992
#
# Epoch 00027: val_loss did not improve from 1.33064
# Epoch 28/100
# 13170/13170 [==============================] - 31s 2ms/step - loss: 1.0210 - mae: 0.7400 - val_loss: 1.4562 - val_mae: 0.9090
#
# Epoch 00028: val_loss did not improve from 1.33064
# Epoch 29/100
# 13170/13170 [==============================] - 27s 2ms/step - loss: 1.0047 - mae: 0.7314 - val_loss: 1.3769 - val_mae: 0.8635
#
# Epoch 00029: val_loss did not improve from 1.33064
# Epoch 30/100
# 13170/13170 [==============================] - 29s 2ms/step - loss: 0.9884 - mae: 0.7254 - val_loss: 1.3360 - val_mae: 0.8448
#
# Epoch 00030: val_loss did not improve from 1.33064
# Epoch 31/100
# 13170/13170 [==============================] - 28s 2ms/step - loss: 0.9871 - mae: 0.7274 - val_loss: 1.3243 - val_mae: 0.8454
#
# Epoch 00031: val_loss improved from 1.33064 to 1.32433, saving model to test.weights.hdf5
# Epoch 32/100
# 13170/13170 [==============================] - 29s 2ms/step - loss: 0.9953 - mae: 0.7272 - val_loss: 1.3236 - val_mae: 0.8512
#
# Epoch 00032: val_loss improved from 1.32433 to 1.32363, saving model to test.weights.hdf5
# Epoch 33/100
# 13170/13170 [==============================] - 28s 2ms/step - loss: 0.9791 - mae: 0.7233 - val_loss: 1.3413 - val_mae: 0.8380
#
# Epoch 00033: val_loss did not improve from 1.32363
# Epoch 34/100
# 13170/13170 [==============================] - 27s 2ms/step - loss: 0.9835 - mae: 0.7236 - val_loss: 1.4187 - val_mae: 0.8834
#
# Epoch 00034: val_loss did not improve from 1.32363
# Epoch 35/100
# 13170/13170 [==============================] - 32s 2ms/step - loss: 0.9551 - mae: 0.7099 - val_loss: 1.3554 - val_mae: 0.8656
#
# Epoch 00035: val_loss did not improve from 1.32363
# Epoch 36/100
# 13170/13170 [==============================] - 33s 3ms/step - loss: 0.9742 - mae: 0.7160 - val_loss: 1.3419 - val_mae: 0.8537
#
# Epoch 00036: val_loss did not improve from 1.32363
# Epoch 37/100
# 13170/13170 [==============================] - 60s 5ms/step - loss: 0.9740 - mae: 0.7163 - val_loss: 1.3989 - val_mae: 0.8808
#
# Epoch 00037: val_loss did not improve from 1.32363
# Epoch 38/100
# 13170/13170 [==============================] - 45s 3ms/step - loss: 0.9552 - mae: 0.7106 - val_loss: 1.3563 - val_mae: 0.8587
#
# Epoch 00038: val_loss did not improve from 1.32363
# Epoch 39/100
# 13170/13170 [==============================] - 41s 3ms/step - loss: 0.9746 - mae: 0.7155 - val_loss: 1.3994 - val_mae: 0.8840
#
# Epoch 00039: val_loss did not improve from 1.32363
# Epoch 40/100
# 13170/13170 [==============================] - 46s 4ms/step - loss: 0.9345 - mae: 0.6995 - val_loss: 1.3078 - val_mae: 0.8335
#
# Epoch 00040: val_loss improved from 1.32363 to 1.30778, saving model to test.weights.hdf5
# Epoch 41/100
# 13170/13170 [==============================] - 41s 3ms/step - loss: 0.9558 - mae: 0.7055 - val_loss: 1.3602 - val_mae: 0.8593
#
# Epoch 00041: val_loss did not improve from 1.30778
# Epoch 42/100
# 13170/13170 [==============================] - 41s 3ms/step - loss: 0.9285 - mae: 0.6974 - val_loss: 1.3200 - val_mae: 0.8420
#
# Epoch 00042: val_loss did not improve from 1.30778
# Epoch 43/100
# 13170/13170 [==============================] - 37s 3ms/step - loss: 0.9376 - mae: 0.6966 - val_loss: 1.3388 - val_mae: 0.8627
#
# Epoch 00043: val_loss did not improve from 1.30778
# Epoch 44/100
# 13170/13170 [==============================] - 42s 3ms/step - loss: 0.9333 - mae: 0.6976 - val_loss: 1.3504 - val_mae: 0.8557
#
# Epoch 00044: val_loss did not improve from 1.30778
# Epoch 45/100
# 13170/13170 [==============================] - 43s 3ms/step - loss: 0.9212 - mae: 0.6911 - val_loss: 1.3234 - val_mae: 0.8413
#
# Epoch 00045: val_loss did not improve from 1.30778
# Epoch 46/100
# 13170/13170 [==============================] - 39s 3ms/step - loss: 0.9273 - mae: 0.6952 - val_loss: 1.3527 - val_mae: 0.8443
#
# Epoch 00046: val_loss did not improve from 1.30778
# Epoch 47/100
# 13170/13170 [==============================] - 39s 3ms/step - loss: 0.9187 - mae: 0.6868 - val_loss: 1.3902 - val_mae: 0.8728
#
# Epoch 00047: val_loss did not improve from 1.30778
# Epoch 48/100
# 13170/13170 [==============================] - 36s 3ms/step - loss: 0.9311 - mae: 0.6951 - val_loss: 1.3381 - val_mae: 0.8383
#
# Epoch 00048: val_loss did not improve from 1.30778
# Epoch 49/100
# 13170/13170 [==============================] - 35s 3ms/step - loss: 0.9225 - mae: 0.6887 - val_loss: 1.3444 - val_mae: 0.8401
#
# Epoch 00049: val_loss did not improve from 1.30778
# Epoch 50/100
# 13170/13170 [==============================] - 36s 3ms/step - loss: 0.9178 - mae: 0.6869 - val_loss: 1.3355 - val_mae: 0.8446
#
# Epoch 00050: val_loss did not improve from 1.30778

# %%
# Plot the training and validation loss
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the training and validation MAE
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
model.load_weights("test.weights.hdf5")

# %%
# Find the epoch with the minimum validation loss
optimal_epoch = history.history['val_loss'].index(min(history.history['val_loss'])) + 1
print(f"Optimal Epoch: {optimal_epoch} loss: {history.history['val_loss'][optimal_epoch-1]}")
# Out:
# Optimal Epoch: 40 loss: 1.3077822895780005

# %%
# Evaluate the model on the test set
results = model.evaluate([drug_test, protein_test], y_test)
# Out:
# 2823/2823 [==============================] - 9s 3ms/step

# %%
# Print the evaluation results
print("Test Loss:", results[0])
print("Test MAE:", results[1])
# Out:
# Test Loss: 1.3098830211850883
# Test MAE: 0.8333700299263

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import numpy as np
y_pred = model.predict([drug_test, protein_test])
print(np.corrcoef(y_test, y_pred.ravel()))
print(r2_score(y_test, y_pred))
plt.scatter(y_test, y_pred)
m, b = np.polyfit(y_test, y_pred, 1)
plt.plot(y_test, m * y_test + b, 'r')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()
# Out:
# [[1.         0.72514398]
#  [0.72514398 1.        ]]
# 0.5233332696239459

# %% [markdown]
# ## END
