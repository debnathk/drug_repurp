# %%
# %pwd
# Out:
# 'c:\\Users\\debnathk\\Desktop\\study\\DLEPS-main\\code\\DLEPS\\dleps\\code\\DLEPS'

# %%
import h5py
import pandas as pd
import numpy as np
from scipy.stats import zscore
import matplotlib.pyplot as plt

# %%
# Load the training set
df = pd.read_csv('../../data/drug full screening data NEW edited.csv')
df
# Out:
#                    DRUG NAME  MDA7+D1+1  MDA7+D1+2  MDA7+D1+3  MDA7+D2+1  \
# 0             Angiotensin II   0.467198   0.492122   0.500198   0.651233
# 1              Levetiracetam   0.424844   0.503705   0.433523   0.517083
# 2                 Daptomycin   0.462072   0.509482   0.424083   0.451883
# 3               Lansoprazole   0.464806   0.494925   0.502533   0.491361
# 4                  Adapalene   0.407362   0.425062   0.490854   0.489590
# ...                      ...        ...        ...        ...        ...
# 1966     Chondroitin sulfate   0.750820   0.741770   0.826674   0.835227
# 1967                 Aucubin   0.714064   0.849337   0.563837   0.869225
# 1968           Cepharanthine   0.592418   0.708048   0.883598   0.811905
# 1969     4-Aminobutyric acid   0.705559   0.941525   0.717699   0.887134
# 1970  Prulifloxacin (Pruvel)   0.844985   0.773646   0.742799   0.802596
#
#       MDA7+D2+2  MDA7+D2+3      D1+1      D1+2      D1+3  ...  MDA7+D1+9  \
# 0      0.762780   0.484070  0.878523  0.952131  1.122307  ...        NaN
# 1      0.498133   0.485443  0.985621  1.002564  1.297499  ...        NaN
# 2      0.495565   0.472871  0.980899  0.906619  0.982075  ...        NaN
# 3      0.479975   0.443513  1.363714  0.919337  1.273511  ...        NaN
# 4      0.513733   0.395002  0.437537  0.569486  0.435191  ...        NaN
# ...         ...        ...       ...       ...       ...  ...        ...
# 1966   0.807444   0.802552  0.790976  0.905025  0.865902  ...        NaN
# 1967   0.700734   0.823960  0.808023  0.719939  0.689561  ...        NaN
# 1968   0.849278   0.827013  1.053463  1.007266  0.957949  ...        NaN
# 1969   0.716770   0.617353  0.804578  0.716076  0.845920  ...        NaN
# 1970   0.787334   0.757312  0.618461  0.797263  0.793098  ...        NaN
#
#       MDA7+D2+7  MDA7+D2+8  MDA7+D2+9  D1+7  D1+8  D1+9  D2+7  D2+8  D2+9
# 0           NaN        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1           NaN        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2           NaN        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3           NaN        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4           NaN        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...         ...        ...        ...   ...   ...   ...   ...   ...   ...
# 1966        NaN        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1967        NaN        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1968        NaN        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1969        NaN        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1970        NaN        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1971 rows x 37 columns]

# %%
# df_merged = pd.read_csv('../../../../../data/gene_expression_data/train_chembl_merged_smiles.csv')
# df_merged

# %%
# drug_names_unique = pd.read_csv('../../../../../data/gen_exp_drugs.csv')
# drug_names_unique.drop_duplicates(inplace=True)
# drug_names_unique

# %%
# Check how many unique drugs are present in the merged dataset

# x = df_merged[df_merged['pref_name'].str.lower().isin(drug_names_unique['drug_name'])]
# x.drop_duplicates(subset='pref_name', inplace=True)
# x.to_csv('../../../../../data/final_425_common_train_rna-seq_dataset.csv', index=False)
# x

df_merged = pd.read_csv('../../data/final_425_common_train_rna-seq_dataset.csv')
df_merged
# Out:
#                DRUG_NAME                                             SMILES  \
# 0    5-Methoxytryptamine                         COC1=CC(C(CCN)=CN2)=C2C=C1
# 1                ACP-196  O=C(NC1=NC=CC=C1)C2=CC=C(C3=C4C(N)=NC=CN4C([C@...
# 2             Acemetacin  CC1=C(C2=C(N1C(=O)C3=CC=C(C=C3)Cl)C=CC(=C2)OC)...
# 3               Acipimox                        CC1=CN=C(C=[N+]1[O-])C(=O)O
# 4              Adapalene  COC1=C(C=C(C=C1)C2=CC3=C(C=C2)C=C(C=C3)C(=O)O)...
# ..                   ...                                                ...
# 420  Zibotentan (ZD4054)  CC1=CN=C(C(=N1)OC)NS(=O)(=O)C2=C(N=CC=C2)C3=CC...
# 421             Zileuton                    CC(C1=CC2=CC=CC=C2S1)N(C(=O)N)O
# 422          Ziprasidone  C1CN(CCN1CCC2=C(C=C3C(=C2)CC(=O)N3)Cl)C4=NSC5=...
# 423           Zonisamide                   C1=CC=C2C(=C1)C(=NO2)CS(=O)(=O)N
# 424         Zoxazolamine                           C1=CC2=C(C=C1Cl)N=C(O2)N
#
#                                    standardized_SMILES            pref_name  \
# 0                              COc1ccc2[nH]cc(CCN)c2c1  5-METHOXYTRYPTAMINE
# 1    CC#CC(=O)N1CCC[C@H]1c1nc(-c2ccc(C(=O)Nc3ccccn3...        ACALABRUTINIB
# 2    COc1ccc2c(c1)c(CC(=O)OCC(=O)O)c(C)n2C(=O)c1ccc...           ACEMETACIN
# 3                             Cc1cnc(C(=O)O)c[n+]1[O-]             ACIPIMOX
# 4    COc1ccc(-c2ccc3cc(C(=O)O)ccc3c2)cc1C12CC3CC(CC...            ADAPALENE
# ..                                                 ...                  ...
# 420  COc1nc(C)cnc1NS(=O)(=O)c1cccnc1-c1ccc(-c2nnco2...           ZIBOTENTAN
# 421                        CC(c1cc2ccccc2s1)N(O)C(N)=O             ZILEUTON
# 422     O=C1Cc2cc(CCN3CCN(c4nsc5ccccc45)CC3)c(Cl)cc2N1          ZIPRASIDONE
# 423                           NS(=O)(=O)Cc1noc2ccccc12           ZONISAMIDE
# 424                                 Nc1nc2cc(Cl)ccc2o1         ZOXAZOLAMINE
#
#                                    molecule_structures
# 0                              COc1ccc2[nH]cc(CCN)c2c1
# 1    CC#CC(=O)N1CCC[C@H]1c1nc(-c2ccc(C(=O)Nc3ccccn3...
# 2    COc1ccc2c(c1)c(CC(=O)OCC(=O)O)c(C)n2C(=O)c1ccc...
# 3                             Cc1cnc(C(=O)O)c[n+]1[O-]
# 4    COc1ccc(-c2ccc3cc(C(=O)O)ccc3c2)cc1C12CC3CC(CC...
# ..                                                 ...
# 420  COc1nc(C)cnc1NS(=O)(=O)c1cccnc1-c1ccc(-c2nnco2...
# 421                        CC(c1cc2ccccc2s1)N(O)C(N)=O
# 422     O=C1Cc2cc(CCN3CCN(c4nsc5ccccc45)CC3)c(Cl)cc2N1
# 423                           NS(=O)(=O)Cc1noc2ccccc12
# 424                                 Nc1nc2cc(Cl)ccc2o1
#
# [425 rows x 5 columns]

# %%
# Merge x with df

df = df.merge(df_merged, left_on='DRUG NAME', right_on='DRUG_NAME')
df.sort_values('pref_name', ascending=True, inplace=True)
df
# Out:
#                DRUG NAME  MDA7+D1+1  MDA7+D1+2  MDA7+D1+3  MDA7+D2+1  \
# 372  5-Methoxytryptamine   0.723188   0.801154   0.822601   0.839875
# 366              ACP-196   0.627039   0.772925   0.757654   0.762336
# 177           Acemetacin   0.587154   0.662696   0.692944   0.931102
# 282             Acipimox   0.902399   0.939315   0.990576   1.059831
# 0              Adapalene   0.407362   0.425062   0.490854   0.489590
# ..                   ...        ...        ...        ...        ...
# 97   Zibotentan (ZD4054)   0.752919   0.913578   0.820408   0.710610
# 94              Zileuton   0.665070   0.687888   0.820727   0.620963
# 56           Ziprasidone   0.488007   0.446471   0.405887   0.406742
# 93            Zonisamide   0.673634   0.773978   0.726651   0.690597
# 234         Zoxazolamine   0.879666   0.921867   0.642560   0.738475
#
#      MDA7+D2+2  MDA7+D2+3      D1+1      D1+2      D1+3  ...  D1+8  D1+9  \
# 372   0.834651   0.819050  1.001127  0.976009  0.948555  ...   NaN   NaN
# 366   0.803738   0.807494  0.900312  0.894956  0.836284  ...   NaN   NaN
# 177   0.716981   0.550529  0.752684  0.983370  0.906611  ...   NaN   NaN
# 282   0.901014   1.065956  0.945784  1.126811  1.140040  ...   NaN   NaN
# 0     0.513733   0.395002  0.437537  0.569486  0.435191  ...   NaN   NaN
# ..         ...        ...       ...       ...       ...  ...   ...   ...
# 97    0.751213   0.728701  0.895915  0.794392  0.893209  ...   NaN   NaN
# 94    0.651704   0.639108  0.762338  0.525181  0.765302  ...   NaN   NaN
# 56    0.393678   0.383321  0.380997  0.428339  0.412881  ...   NaN   NaN
# 93    0.698378   0.677257  0.919629  0.797323  0.860303  ...   NaN   NaN
# 234   0.630410   0.465936  0.729317  0.739281  0.786496  ...   NaN   NaN
#
#      D2+7  D2+8  D2+9            DRUG_NAME  \
# 372   NaN   NaN   NaN  5-Methoxytryptamine
# 366   NaN   NaN   NaN              ACP-196
# 177   NaN   NaN   NaN           Acemetacin
# 282   NaN   NaN   NaN             Acipimox
# 0     NaN   NaN   NaN            Adapalene
# ..    ...   ...   ...                  ...
# 97    NaN   NaN   NaN  Zibotentan (ZD4054)
# 94    NaN   NaN   NaN             Zileuton
# 56    NaN   NaN   NaN          Ziprasidone
# 93    NaN   NaN   NaN           Zonisamide
# 234   NaN   NaN   NaN         Zoxazolamine
#
#                                                 SMILES  \
# 372                         COC1=CC(C(CCN)=CN2)=C2C=C1
# 366  O=C(NC1=NC=CC=C1)C2=CC=C(C3=C4C(N)=NC=CN4C([C@...
# 177  CC1=C(C2=C(N1C(=O)C3=CC=C(C=C3)Cl)C=CC(=C2)OC)...
# 282                        CC1=CN=C(C=[N+]1[O-])C(=O)O
# 0    COC1=C(C=C(C=C1)C2=CC3=C(C=C2)C=C(C=C3)C(=O)O)...
# ..                                                 ...
# 97   CC1=CN=C(C(=N1)OC)NS(=O)(=O)C2=C(N=CC=C2)C3=CC...
# 94                     CC(C1=CC2=CC=CC=C2S1)N(C(=O)N)O
# 56   C1CN(CCN1CCC2=C(C=C3C(=C2)CC(=O)N3)Cl)C4=NSC5=...
# 93                    C1=CC=C2C(=C1)C(=NO2)CS(=O)(=O)N
# 234                           C1=CC2=C(C=C1Cl)N=C(O2)N
#
#                                    standardized_SMILES            pref_name  \
# 372                            COc1ccc2[nH]cc(CCN)c2c1  5-METHOXYTRYPTAMINE
# 366  CC#CC(=O)N1CCC[C@H]1c1nc(-c2ccc(C(=O)Nc3ccccn3...        ACALABRUTINIB
# 177  COc1ccc2c(c1)c(CC(=O)OCC(=O)O)c(C)n2C(=O)c1ccc...           ACEMETACIN
# 282                           Cc1cnc(C(=O)O)c[n+]1[O-]             ACIPIMOX
# 0    COc1ccc(-c2ccc3cc(C(=O)O)ccc3c2)cc1C12CC3CC(CC...            ADAPALENE
# ..                                                 ...                  ...
# 97   COc1nc(C)cnc1NS(=O)(=O)c1cccnc1-c1ccc(-c2nnco2...           ZIBOTENTAN
# 94                         CC(c1cc2ccccc2s1)N(O)C(N)=O             ZILEUTON
# 56      O=C1Cc2cc(CCN3CCN(c4nsc5ccccc45)CC3)c(Cl)cc2N1          ZIPRASIDONE
# 93                            NS(=O)(=O)Cc1noc2ccccc12           ZONISAMIDE
# 234                                 Nc1nc2cc(Cl)ccc2o1         ZOXAZOLAMINE
#
#                                    molecule_structures
# 372                            COc1ccc2[nH]cc(CCN)c2c1
# 366  CC#CC(=O)N1CCC[C@H]1c1nc(-c2ccc(C(=O)Nc3ccccn3...
# 177  COc1ccc2c(c1)c(CC(=O)OCC(=O)O)c(C)n2C(=O)c1ccc...
# 282                           Cc1cnc(C(=O)O)c[n+]1[O-]
# 0    COc1ccc(-c2ccc3cc(C(=O)O)ccc3c2)cc1C12CC3CC(CC...
# ..                                                 ...
# 97   COc1nc(C)cnc1NS(=O)(=O)c1cccnc1-c1ccc(-c2nnco2...
# 94                         CC(c1cc2ccccc2s1)N(O)C(N)=O
# 56      O=C1Cc2cc(CCN3CCN(c4nsc5ccccc45)CC3)c(Cl)cc2N1
# 93                            NS(=O)(=O)Cc1noc2ccccc12
# 234                                 Nc1nc2cc(Cl)ccc2o1
#
# [425 rows x 42 columns]

# %%
# Print the columns

df.columns
# Out:
# Index(['DRUG NAME', 'MDA7+D1+1', 'MDA7+D1+2', 'MDA7+D1+3', 'MDA7+D2+1',
#        'MDA7+D2+2', 'MDA7+D2+3', 'D1+1', 'D1+2', 'D1+3', 'D2+1', 'D2+2',
#        'D2+3', 'MDA7+D1+4', 'MDA7+D1+5', 'MDA7+D1+6', 'MDA7+D2+4', 'MDA7+D2+5',
#        'MDA7+D2+6', 'D1+4', 'D1+5', 'D1+6', 'D2+4', 'D2+5', 'D2+6',
#        'MDA7+D1+7', 'MDA7+D1+8', 'MDA7+D1+9', 'MDA7+D2+7', 'MDA7+D2+8',
#        'MDA7+D2+9', 'D1+7', 'D1+8', 'D1+9', 'D2+7', 'D2+8', 'D2+9',
#        'DRUG_NAME', 'SMILES', 'standardized_SMILES', 'pref_name',
#        'molecule_structures'],
#       dtype='object')

# %%
# Separate the instances were drugs were adminisitered synergistiacally with  MDA7, comapred to when administered alone

df_mda7_drug = df.filter(like='MDA7', axis=1)
df_mda7_drug
# Out:
#      MDA7+D1+1  MDA7+D1+2  MDA7+D1+3  MDA7+D2+1  MDA7+D2+2  MDA7+D2+3  \
# 372   0.723188   0.801154   0.822601   0.839875   0.834651   0.819050
# 366   0.627039   0.772925   0.757654   0.762336   0.803738   0.807494
# 177   0.587154   0.662696   0.692944   0.931102   0.716981   0.550529
# 282   0.902399   0.939315   0.990576   1.059831   0.901014   1.065956
# 0     0.407362   0.425062   0.490854   0.489590   0.513733   0.395002
# ..         ...        ...        ...        ...        ...        ...
# 97    0.752919   0.913578   0.820408   0.710610   0.751213   0.728701
# 94    0.665070   0.687888   0.820727   0.620963   0.651704   0.639108
# 56    0.488007   0.446471   0.405887   0.406742   0.393678   0.383321
# 93    0.673634   0.773978   0.726651   0.690597   0.698378   0.677257
# 234   0.879666   0.921867   0.642560   0.738475   0.630410   0.465936
#
#      MDA7+D1+4  MDA7+D1+5  MDA7+D1+6  MDA7+D2+4  MDA7+D2+5  MDA7+D2+6  \
# 372        NaN        NaN        NaN        NaN        NaN        NaN
# 366        NaN        NaN        NaN        NaN        NaN        NaN
# 177        NaN        NaN        NaN        NaN        NaN        NaN
# 282        NaN        NaN        NaN        NaN        NaN        NaN
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...        ...
# 97    0.711303   0.863505   0.754552   0.629044   0.689602   0.677496
# 94         NaN        NaN        NaN        NaN        NaN        NaN
# 56    0.530469   0.606786   0.598286   0.472077   0.436442   0.402544
# 93         NaN        NaN        NaN        NaN        NaN        NaN
# 234        NaN        NaN        NaN        NaN        NaN        NaN
#
#      MDA7+D1+7  MDA7+D1+8  MDA7+D1+9  MDA7+D2+7  MDA7+D2+8  MDA7+D2+9
# 372        NaN        NaN        NaN        NaN        NaN        NaN
# 366        NaN        NaN        NaN        NaN        NaN        NaN
# 177        NaN        NaN        NaN        NaN        NaN        NaN
# 282        NaN        NaN        NaN        NaN        NaN        NaN
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...        ...
# 97         NaN        NaN        NaN        NaN        NaN        NaN
# 94         NaN        NaN        NaN        NaN        NaN        NaN
# 56         NaN        NaN        NaN        NaN        NaN        NaN
# 93         NaN        NaN        NaN        NaN        NaN        NaN
# 234        NaN        NaN        NaN        NaN        NaN        NaN
#
# [425 rows x 18 columns]

# %%
def normalize(x):
    return 2*(x-x.min())/(x.max()-x.min())-1

# %%
# Remove the NaN columns
df_mda7_drug = df_mda7_drug.dropna(axis=1)

# Calculate mean
df_mda7_drug['MDA7+Drug_mean'] = df_mda7_drug.mean(axis=1)

# Standardize the mean
df_mda7_drug['MDA7+Drug_mean_standardized'] = zscore(df_mda7_drug['MDA7+Drug_mean'])
# df_mda7_drug['MDA7+Drug_mean_standardized'] = normalize(df_mda7_drug['MDA7+Drug_mean'])

df_mda7_drug
# Out:
# C:\Users\debnathk\AppData\Local\Temp\ipykernel_16536\2987235133.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mda7_drug['MDA7+Drug_mean'] = df_mda7_drug.mean(axis=1)
# C:\Users\debnathk\AppData\Local\Temp\ipykernel_16536\2987235133.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mda7_drug['MDA7+Drug_mean_standardized'] = zscore(df_mda7_drug['MDA7+Drug_mean'])
#      MDA7+D1+1  MDA7+D1+2  MDA7+D1+3  MDA7+D2+1  MDA7+D2+2  MDA7+D2+3  \
# 372   0.723188   0.801154   0.822601   0.839875   0.834651   0.819050
# 366   0.627039   0.772925   0.757654   0.762336   0.803738   0.807494
# 177   0.587154   0.662696   0.692944   0.931102   0.716981   0.550529
# 282   0.902399   0.939315   0.990576   1.059831   0.901014   1.065956
# 0     0.407362   0.425062   0.490854   0.489590   0.513733   0.395002
# ..         ...        ...        ...        ...        ...        ...
# 97    0.752919   0.913578   0.820408   0.710610   0.751213   0.728701
# 94    0.665070   0.687888   0.820727   0.620963   0.651704   0.639108
# 56    0.488007   0.446471   0.405887   0.406742   0.393678   0.383321
# 93    0.673634   0.773978   0.726651   0.690597   0.698378   0.677257
# 234   0.879666   0.921867   0.642560   0.738475   0.630410   0.465936
#
#      MDA7+Drug_mean  MDA7+Drug_mean_standardized
# 372        0.806753                     0.597140
# 366        0.755198                     0.372143
# 177        0.690234                     0.088633
# 282        0.976515                     1.338007
# 0          0.453601                    -0.944074
# ..              ...                          ...
# 97         0.779571                     0.478514
# 94         0.680910                     0.047940
# 56         0.420684                    -1.087725
# 93         0.706749                     0.160707
# 234        0.713152                     0.188650
#
# [425 rows x 8 columns]

# %%
df_drug_only = df.filter(regex='^D\d', axis=1)
df_drug_only
# Out:
#          D1+1      D1+2      D1+3      D2+1      D2+2      D2+3      D1+4  \
# 372  1.001127  0.976009  0.948555  1.062186  1.048878  1.049779       NaN
# 366  0.900312  0.894956  0.836284  0.772389  0.876201  0.845054       NaN
# 177  0.752684  0.983370  0.906611  0.860769  0.850819  0.700735       NaN
# 282  0.945784  1.126811  1.140040  1.113521  1.102547  0.940450       NaN
# 0    0.437537  0.569486  0.435191  0.506453  0.486821  0.289898       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 97   0.895915  0.794392  0.893209  0.909357  0.937930  0.777015  0.849211
# 94   0.762338  0.525181  0.765302  0.577695  0.799038  0.737935       NaN
# 56   0.380997  0.428339  0.412881  0.444951  0.402802  0.535376  0.425675
# 93   0.919629  0.797323  0.860303  0.905727  0.767213  0.910196       NaN
# 234  0.729317  0.739281  0.786496  0.742241  0.894530  0.948339       NaN
#
#          D1+5      D1+6      D2+4      D2+5      D2+6  D1+7  D1+8  D1+9  D2+7  \
# 372       NaN       NaN       NaN       NaN       NaN   NaN   NaN   NaN   NaN
# 366       NaN       NaN       NaN       NaN       NaN   NaN   NaN   NaN   NaN
# 177       NaN       NaN       NaN       NaN       NaN   NaN   NaN   NaN   NaN
# 282       NaN       NaN       NaN       NaN       NaN   NaN   NaN   NaN   NaN
# 0         NaN       NaN       NaN       NaN       NaN   NaN   NaN   NaN   NaN
# ..        ...       ...       ...       ...       ...   ...   ...   ...   ...
# 97   0.758255  0.847685  0.860044  0.884873  0.732273   NaN   NaN   NaN   NaN
# 94        NaN       NaN       NaN       NaN       NaN   NaN   NaN   NaN   NaN
# 56   0.441575  0.469691  0.466946  0.445346  0.663560   NaN   NaN   NaN   NaN
# 93        NaN       NaN       NaN       NaN       NaN   NaN   NaN   NaN   NaN
# 234       NaN       NaN       NaN       NaN       NaN   NaN   NaN   NaN   NaN
#
#      D2+8  D2+9
# 372   NaN   NaN
# 366   NaN   NaN
# 177   NaN   NaN
# 282   NaN   NaN
# 0     NaN   NaN
# ..    ...   ...
# 97    NaN   NaN
# 94    NaN   NaN
# 56    NaN   NaN
# 93    NaN   NaN
# 234   NaN   NaN
#
# [425 rows x 18 columns]

# %%
df_drug_only = df_drug_only.dropna(axis=1)

# Calculate mean
df_drug_only['Drug_mean'] = df_drug_only.mean(axis=1)

# Standardize mean
df_drug_only['Drug_mean_standardized'] = zscore(df_drug_only['Drug_mean'])
# df_drug_only['Drug_mean_standardized'] = normalize(df_drug_only['Drug_mean'])


df_drug_only
# Out:
# C:\Users\debnathk\AppData\Local\Temp\ipykernel_16536\2467704557.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_drug_only['Drug_mean'] = df_drug_only.mean(axis=1)
# C:\Users\debnathk\AppData\Local\Temp\ipykernel_16536\2467704557.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_drug_only['Drug_mean_standardized'] = zscore(df_drug_only['Drug_mean'])
#          D1+1      D1+2      D1+3      D2+1      D2+2      D2+3  Drug_mean  \
# 372  1.001127  0.976009  0.948555  1.062186  1.048878  1.049779   1.014422
# 366  0.900312  0.894956  0.836284  0.772389  0.876201  0.845054   0.854199
# 177  0.752684  0.983370  0.906611  0.860769  0.850819  0.700735   0.842498
# 282  0.945784  1.126811  1.140040  1.113521  1.102547  0.940450   1.061525
# 0    0.437537  0.569486  0.435191  0.506453  0.486821  0.289898   0.454231
# ..        ...       ...       ...       ...       ...       ...        ...
# 97   0.895915  0.794392  0.893209  0.909357  0.937930  0.777015   0.867970
# 94   0.762338  0.525181  0.765302  0.577695  0.799038  0.737935   0.694582
# 56   0.380997  0.428339  0.412881  0.444951  0.402802  0.535376   0.434224
# 93   0.919629  0.797323  0.860303  0.905727  0.767213  0.910196   0.860065
# 234  0.729317  0.739281  0.786496  0.742241  0.894530  0.948339   0.806701
#
#      Drug_mean_standardized
# 372                1.049205
# 366                0.390101
# 177                0.341965
# 282                1.242972
# 0                 -1.255237
# ..                      ...
# 97                 0.446748
# 94                -0.266513
# 56                -1.337538
# 93                 0.414231
# 234                0.194707
#
# [425 rows x 8 columns]

# %%
# Use z-score method, the other method doesn't work because inconsistent data loss

x = df_mda7_drug['MDA7+Drug_mean_standardized']
y = df_drug_only['Drug_mean_standardized']

# diff_squared = (x - y)**2
diff = x - y

# MDA7_only_data = np.sqrt(diff_squared)
MDA7_only_data = diff
MDA7_only_data
# Out:
# 372   -0.452065
# 366   -0.017959
# 177   -0.253332
# 282    0.095035
# 0      0.311162
#          ...
# 97     0.031765
# 94     0.314454
# 56     0.249813
# 93    -0.253524
# 234   -0.006057
# Length: 425, dtype: float64

# %%
# Plot all three distributions
fig, axs = plt.subplots(1, 3, figsize=(15, 6))

# Plot MDA7 + Drug
axs[0].hist(x, bins=20, alpha=0.5, color='b')
axs[0].set_title('Distribution of MDA7 + Drug')
axs[0].set_xlim(-5, 5)

# Plot Drug only
axs[1].hist(y, bins=20, alpha=0.5, color='r')
axs[1].set_title('Distribution of Drug only')
axs[1].set_xlim(-5, 5)

# Plot MDA7 + Drug - Drug
axs[2].hist(MDA7_only_data, bins=20, alpha=0.5, color='g')
axs[2].set_title('Distribution of MDA7 + Drug - Drug')
axs[2].set_xlim(-5, 5)

plt.tight_layout()
plt.show()

# %%
# Save values as target sets

h5f = h5py.File('y_MDA7+DRUG.h5', 'w')
h5f.create_dataset('data', data=x)
h5f.close()

h5f = h5py.File('y_DRUG.h5', 'w')
h5f.create_dataset('data', data=y)
h5f.close()

h5f = h5py.File('y_MDA7.h5', 'w')
h5f.create_dataset('data', data=MDA7_only_data)
h5f.close()

# %%
h5f1 = h5py.File('y_MDA7+DRUG.h5', 'r')
data1 = h5f1['data'][:]

h5f2 = h5py.File('y_DRUG.h5', 'r')
data2 = h5f2['data'][:]

h5f3 = h5py.File('y_MDA7.h5', 'r')
data3 = h5f3['data'][:]

print(data1.shape, data2.shape, data3.shape)
# Out:
# (425,) (425,) (425,)

# %%
# Plot all three distributions
fig, axs = plt.subplots(1, 3, figsize=(15, 6))

# Plot MDA7 + Drug
axs[0].hist(data1, bins=20, alpha=0.5, color='b')
axs[0].set_title('Distribution of MDA7 + Drug')
axs[0].set_xlim(-5, 5)

# Plot Drug only
axs[1].hist(data2, bins=20, alpha=0.5, color='r')
axs[1].set_title('Distribution of Drug only')
axs[1].set_xlim(-5, 5)

# Plot MDA7 + Drug - Drug
axs[2].hist(data3, bins=20, alpha=0.5, color='g')
axs[2].set_title('Distribution of MDA7 + Drug - Drug')
axs[2].set_xlim(-5, 5)

plt.tight_layout()
plt.show()

# %%
# Train test split
TEST_SIZE = 75

data1_train = data1[TEST_SIZE:]
data1_test = data1[:TEST_SIZE]

h5f1 = h5py.File('y_MDA7+DRUG_train.h5', 'w')
h5f1.create_dataset('data', data=data1_train)
h5f1.close()

h5f1 = h5py.File('y_MDA7+DRUG_test.h5', 'w')
h5f1.create_dataset('data', data=data1_test)
h5f1.close()

data2_train = data2[TEST_SIZE:]
data2_test = data2[:TEST_SIZE]

h5f2 = h5py.File('y_DRUG_train.h5', 'w')
h5f2.create_dataset('data', data=data2_train)
h5f2.close()

h5f2 = h5py.File('y_DRUG_test.h5', 'w')
h5f2.create_dataset('data', data=data2_test)
h5f2.close()

data3_train = data3[TEST_SIZE:]
data3_test = data3[:TEST_SIZE]

h5f3 = h5py.File('y_MDA7_train.h5', 'w')
h5f3.create_dataset('data', data=data3_train)
h5f3.close()

h5f3 = h5py.File('y_MDA7_test.h5', 'w')
h5f3.create_dataset('data', data=data3_test)
h5f3.close()
