# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
os.environ["CUDA_VISIBLE_DEVICES"] = "4"

from dleps_predictor2 import DLEPS

## Note: protobuf error can be resolved by downgrading it v3.20.1

# %%
dleps_p = DLEPS()
dleps_p.model[0].summary()
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 277, 76)      0
# __________________________________________________________________________________________________
# conv_1 (Conv1D)                 (None, 269, 9)       6165        input_8[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv1D)                 (None, 261, 9)       738         conv_1[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv1D)                 (None, 251, 10)      1000        conv_2[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2510)         0           conv_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 435)          1092285     flatten_1[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 56)           24416       dense_1[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 56)           24416       dense_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 56)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 512)          29184       lambda[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 512)          0           dense_10[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 512)          262656      dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512)          0           dense_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 512)          262656      dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 512)          0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 512)          262656      dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 1)            513         dense_13[0][0]
# ==================================================================================================
# Total params: 1,966,685
# Trainable params: 1,966,685
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import h5py

h5f = h5py.File('../../data/SMILE_train_demo2.h5', 'r')
smile_train = h5f['data'][:]
h5f2 = h5py.File('../../data/SMILE_test_demo2.h5', 'r')
smile_test = h5f2['data'][:]
h5f3 = h5py.File('../../data/appostasis_train_demo2.h5', 'r')
rna_train = h5f3['data'][:]
h5f4 = h5py.File('../../data/appostasis_test_demo2.h5', 'r')
rna_test = h5f4['data'][:]

print(rna_train.shape)
print(rna_test.shape)
print(smile_train.shape)
print(smile_test.shape)
# Out:
# (1026,)
# (100,)
# (1026, 277, 76)
# (100, 277, 76)

# %%
his = dleps_p.train(smile_train, rna_train,(smile_test, rna_test), epochs=50,
                batch_size=32,
                shuffle=True,)
# Out:
# Train on 1026 samples, validate on 100 samples
# Epoch 1/50
# 1026/1026 [==============================] - 1s 1ms/step - loss: 0.1509 - val_loss: 0.1440
# Epoch 2/50
# 1026/1026 [==============================] - 1s 803us/step - loss: 0.1429 - val_loss: 0.1412
# Epoch 3/50
# 1026/1026 [==============================] - 1s 864us/step - loss: 0.1447 - val_loss: 0.1429
# Epoch 4/50
# 1026/1026 [==============================] - 1s 803us/step - loss: 0.1448 - val_loss: 0.1402
# Epoch 5/50
# 1026/1026 [==============================] - 1s 776us/step - loss: 0.1409 - val_loss: 0.1399
# Epoch 6/50
# 1026/1026 [==============================] - 1s 761us/step - loss: 0.1402 - val_loss: 0.1402
# Epoch 7/50
# 1026/1026 [==============================] - 1s 916us/step - loss: 0.1383 - val_loss: 0.1393
# Epoch 8/50
# 1026/1026 [==============================] - 1s 995us/step - loss: 0.1394 - val_loss: 0.1389
# Epoch 9/50
# 1026/1026 [==============================] - 1s 927us/step - loss: 0.1384 - val_loss: 0.1389
# Epoch 10/50
# 1026/1026 [==============================] - 1s 1ms/step - loss: 0.1386 - val_loss: 0.1382
# Epoch 11/50
# 1026/1026 [==============================] - 1s 1ms/step - loss: 0.1401 - val_loss: 0.1383
# Epoch 12/50
# 1026/1026 [==============================] - 1s 1ms/step - loss: 0.1423 - val_loss: 0.1379
# Epoch 13/50
# 1026/1026 [==============================] - 1s 923us/step - loss: 0.1378 - val_loss: 0.1375
# Epoch 14/50
# 1026/1026 [==============================] - 1s 1ms/step - loss: 0.1365 - val_loss: 0.1388
# Epoch 15/50
# 1026/1026 [==============================] - 1s 1ms/step - loss: 0.1347 - val_loss: 0.1375
# Epoch 16/50
# 1026/1026 [==============================] - 1s 947us/step - loss: 0.1379 - val_loss: 0.1373
# Epoch 17/50
# 1026/1026 [==============================] - 1s 970us/step - loss: 0.1355 - val_loss: 0.1372
# Epoch 18/50
# 1026/1026 [==============================] - 1s 1ms/step - loss: 0.1391 - val_loss: 0.1378
# Epoch 19/50
# 1026/1026 [==============================] - 1s 976us/step - loss: 0.1365 - val_loss: 0.1382
# Epoch 20/50
# 1026/1026 [==============================] - 1s 1ms/step - loss: 0.1349 - val_loss: 0.1380
# Epoch 21/50
# 1026/1026 [==============================] - 1s 940us/step - loss: 0.1350 - val_loss: 0.1376
# Epoch 22/50
# 1026/1026 [==============================] - 1s 958us/step - loss: 0.1361 - val_loss: 0.1376
# Epoch 23/50
# 1026/1026 [==============================] - 1s 943us/step - loss: 0.1365 - val_loss: 0.1380
# Epoch 24/50
# 1026/1026 [==============================] - 1s 957us/step - loss: 0.1374 - val_loss: 0.1379
# Epoch 25/50
# 1026/1026 [==============================] - 1s 940us/step - loss: 0.1350 - val_loss: 0.1375
# Epoch 26/50
# 1026/1026 [==============================] - 1s 921us/step - loss: 0.1365 - val_loss: 0.1374
# Epoch 27/50
# 1026/1026 [==============================] - 1s 1000us/step - loss: 0.1340 - val_loss: 0.1373
# Epoch 28/50
# 1026/1026 [==============================] - 1s 937us/step - loss: 0.1348 - val_loss: 0.1374
# Epoch 29/50
# 1026/1026 [==============================] - 1s 929us/step - loss: 0.1371 - val_loss: 0.1372
# Epoch 30/50
# 1026/1026 [==============================] - 1s 933us/step - loss: 0.1348 - val_loss: 0.1370
# Epoch 31/50
# 1026/1026 [==============================] - 1s 931us/step - loss: 0.1349 - val_loss: 0.1377
# Epoch 32/50
# 1026/1026 [==============================] - 1s 943us/step - loss: 0.1387 - val_loss: 0.1374
# Epoch 33/50
# 1026/1026 [==============================] - 1s 920us/step - loss: 0.1356 - val_loss: 0.1372
# Epoch 34/50
# 1026/1026 [==============================] - 1s 1ms/step - loss: 0.1367 - val_loss: 0.1375
# Epoch 35/50
# 1026/1026 [==============================] - 1s 928us/step - loss: 0.1358 - val_loss: 0.1380
# Epoch 36/50
# 1026/1026 [==============================] - 1s 929us/step - loss: 0.1371 - val_loss: 0.1373
# Epoch 37/50
# 1026/1026 [==============================] - 1s 990us/step - loss: 0.1354 - val_loss: 0.1376
# Epoch 38/50
# 1026/1026 [==============================] - 1s 941us/step - loss: 0.1344 - val_loss: 0.1370
# Epoch 39/50
# 1026/1026 [==============================] - 1s 1ms/step - loss: 0.1330 - val_loss: 0.1373
# Epoch 40/50
# 1026/1026 [==============================] - 1s 985us/step - loss: 0.1338 - val_loss: 0.1374
# Epoch 41/50
# 1026/1026 [==============================] - 1s 914us/step - loss: 0.1368 - val_loss: 0.1373
# Epoch 42/50
# 1026/1026 [==============================] - 1s 926us/step - loss: 0.1367 - val_loss: 0.1366
# Epoch 43/50
# 1026/1026 [==============================] - 1s 936us/step - loss: 0.1385 - val_loss: 0.1372
# Epoch 44/50
# 1026/1026 [==============================] - 1s 932us/step - loss: 0.1349 - val_loss: 0.1375
# Epoch 45/50
# 1026/1026 [==============================] - 1s 909us/step - loss: 0.1352 - val_loss: 0.1366
# Epoch 46/50
# 1026/1026 [==============================] - 1s 1ms/step - loss: 0.1339 - val_loss: 0.1367
# Epoch 47/50
# 1026/1026 [==============================] - 1s 1000us/step - loss: 0.1364 - val_loss: 0.1370
# Epoch 48/50
# 1026/1026 [==============================] - 1s 957us/step - loss: 0.1348 - val_loss: 0.1374
# Epoch 49/50
# 1026/1026 [==============================] - 1s 910us/step - loss: 0.1365 - val_loss: 0.1369
# Epoch 50/50
# 1026/1026 [==============================] - 1s 888us/step - loss: 0.1352 - val_loss: 0.1368

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np
pred = dleps_p.model[0].predict(smile_test)
print(np.corrcoef(rna_test, pred.ravel()))
r2 = r2_score(rna_test, pred)
print(f'R2 Score: {r2}')
mse = mean_squared_error(rna_test, pred)
print(f'MSE Loss: {mse}')
# fig = plt.figure()
plt.scatter(rna_test, pred)
m, b = np.polyfit(rna_test, pred, 1)
plt.plot(rna_test, m * rna_test + b, 'r');
plt.xlabel('Actual')
plt.ylabel('predicted')
# fig.set_facecolor("white")
# Out:
# [[1.         0.20187762]
#  [0.20187762 1.        ]]
# R2 Score: 0.036991481580349705
# MSE Loss: 0.13697097753716247
# Text(0, 0.5, 'predicted')

# %%
# Save model
from joblib import dump, load
dump(dleps_p.model[0], 'model.joblib')
# Out:
# ['model.joblib']

# %%
model = load('model.joblib')
model

# %%
h5f_zinc = h5py.File('../../data/SMILES_zinc_world.h5', 'r')
world_test = h5f_zinc['data'][:]
world_pred = model.predict(world_test)
world_pred
# Out:
# array([[0.0725529 ],
#        [0.08412603],
#        [0.03728059],
#        ...,
#        [0.07069267],
#        [0.06799851],
#        [0.17354915]], dtype=float32)

# %%
# Merge test results column to the test dataset
import pandas as pd
zinc_world_test = pd.read_csv('../../data/WORLD_test.csv')
zinc_world_test.head()
# Out:
#             zinc_id                                             smiles  \
# 0  ZINC000095618893      CN[C@H]1CC[C@H]2Nc3c(O)cc(C(N)=O)cc3[C@@H]2C1
# 1  ZINC000095618901              C[C@@H]1CN(S(=O)(=O)O)CCc2ccc(Cl)cc21
# 2  ZINC000095618909    CC(=O)N[C@H]1CC[C@H]2Nc3ccc(C(N)=O)cc3[C@@H]2C1
# 3  ZINC000095618925  O=C(O)[C@@H]1O[C@H](O[n+]2ccccc2)[C@@H](O)[C@H...
# 4  ZINC000000000513                        COc1ccccc1OC[C@H](O)CNC(C)C
#
#                                         smiles_rdkit
# 0      CN[C@H]1CC[C@H]2Nc3c(O)cc(C(N)=O)cc3[C@@H]2C1
# 1              C[C@@H]1CN(S(=O)(=O)O)CCc2ccc(Cl)cc21
# 2    CC(=O)N[C@H]1CC[C@H]2Nc3ccc(C(N)=O)cc3[C@@H]2C1
# 3  O=C(O)[C@@H]1O[C@H](O[n+]2ccccc2)[C@@H](O)[C@H...
# 4                        COc1ccccc1OC[C@H](O)CNC(C)C

# %%
zinc_world_test['results'] = world_pred
zinc_world_test
# Out:
#                zinc_id                                             smiles  \
# 0     ZINC000095618893      CN[C@H]1CC[C@H]2Nc3c(O)cc(C(N)=O)cc3[C@@H]2C1
# 1     ZINC000095618901              C[C@@H]1CN(S(=O)(=O)O)CCc2ccc(Cl)cc21
# 2     ZINC000095618909    CC(=O)N[C@H]1CC[C@H]2Nc3ccc(C(N)=O)cc3[C@@H]2C1
# 3     ZINC000095618925  O=C(O)[C@@H]1O[C@H](O[n+]2ccccc2)[C@@H](O)[C@H...
# 4     ZINC000000000513                        COc1ccccc1OC[C@H](O)CNC(C)C
# ...                ...                                                ...
# 4152  ZINC000101144764  C[N+]1(C)[C@@H]2C[C@H](OC(=O)C(O)(c3cccs3)c3cc...
# 4153  ZINC000118913164  C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=C(CCC(=O)C4)[C@...
# 4154  ZINC000085537078  CC[C@]12C=CCN3CC[C@@]4(c5cc([C@@]6(C(=O)OC)C[C...
# 4155  ZINC000085537089  CCCN(CCC)C(=O)[C@@H](CCC(=O)OCCCN1CCN(CCOC(=O)...
# 4156  ZINC000085537091  CCCN(CCC)C(=O)[C@H](CCC(=O)OCCCN1CCN(CCOC(=O)C...
#
#                                            smiles_rdkit   results
# 0         CN[C@H]1CC[C@H]2Nc3c(O)cc(C(N)=O)cc3[C@@H]2C1  0.072553
# 1                 C[C@@H]1CN(S(=O)(=O)O)CCc2ccc(Cl)cc21  0.084126
# 2       CC(=O)N[C@H]1CC[C@H]2Nc3ccc(C(N)=O)cc3[C@@H]2C1  0.037281
# 3     O=C(O)[C@@H]1O[C@H](O[n+]2ccccc2)[C@@H](O)[C@H...  0.107676
# 4                           COc1ccccc1OC[C@H](O)CNC(C)C  0.059833
# ...                                                 ...       ...
# 4152  C[N+]1(C)[C@@H]2C[C@H](OC(=O)C(O)(c3cccs3)c3cc...  0.060864
# 4153  C#C[C@]1(O)CC[C@H]2[C@@H]3CCC4=C(CCC(=O)C4)[C@...  0.033594
# 4154  CC[C@]12C=CCN3CC[C@@]4(c5cc([C@@]6(C(=O)OC)C[C...  0.070693
# 4155  CCCN(CCC)C(=O)[C@@H](CCC(=O)OCCCN1CCN(CCOC(=O)...  0.067999
# 4156  CCCN(CCC)C(=O)[C@H](CCC(=O)OCCCN1CCN(CCOC(=O)C...  0.173549
#
# [4157 rows x 4 columns]

# %%
zinc_world_test_sorted = zinc_world_test.sort_values(by='results', ascending=False)
zinc_world_test_sorted.head()
# Out:
#                zinc_id                                             smiles  \
# 1510  ZINC000000056646                 CC(C)NC[C@@H](O)COc1cccc2[nH]ccc12
# 679   ZINC000003929022  CC(C)OC(=O)OCOP(=O)(CO[C@H](C)Cn1cnc2c(N)ncnc2...
# 514   ZINC000000004760                 O[C@](CCN1CCCC1)(c1ccccc1)C1CCCCC1
# 1701  ZINC000008220548  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...
# 1807  ZINC000004095793  OC[C@H]1O[C@H](O)[C@H](O)[C@@H](O)[C@@H]1O[C@@...
#
#                                            smiles_rdkit   results
# 1510                 CC(C)NC[C@@H](O)COc1cccc2[nH]ccc12  0.380811
# 679   CC(C)OC(=O)OCOP(=O)(CO[C@H](C)Cn1cnc2c(N)ncnc2...  0.375881
# 514                  O[C@](CCN1CCCC1)(c1ccccc1)C1CCCCC1  0.352869
# 1701  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...  0.348708
# 1807  OC[C@H]1O[C@H](O)[C@H](O)[C@@H](O)[C@@H]1O[C@@...  0.347759

# %%
zinc_world_test_sorted.to_csv("../../data/zinc_world_output_1.csv", index=False)

# %%
import pandas as pd
df_zinc_output = pd.read_csv("../../data/zinc_world_output_1.csv")
df_zinc_output.head()
# Out:
#             zinc_id                                             smiles  \
# 0  ZINC000000056646                 CC(C)NC[C@@H](O)COc1cccc2[nH]ccc12
# 1  ZINC000003929022  CC(C)OC(=O)OCOP(=O)(CO[C@H](C)Cn1cnc2c(N)ncnc2...
# 2  ZINC000000004760                 O[C@](CCN1CCCC1)(c1ccccc1)C1CCCCC1
# 3  ZINC000008220548  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...
# 4  ZINC000004095793  OC[C@H]1O[C@H](O)[C@H](O)[C@@H](O)[C@@H]1O[C@@...
#
#                                         smiles_rdkit   results
# 0                 CC(C)NC[C@@H](O)COc1cccc2[nH]ccc12  0.380811
# 1  CC(C)OC(=O)OCOP(=O)(CO[C@H](C)Cn1cnc2c(N)ncnc2...  0.375881
# 2                 O[C@](CCN1CCCC1)(c1ccccc1)C1CCCCC1  0.352869
# 3  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...  0.348708
# 4  OC[C@H]1O[C@H](O)[C@H](O)[C@@H](O)[C@@H]1O[C@@...  0.347759

# %%
df_zinc_output_top_100 = df_zinc_output[:100]
df_zinc_output_top_100
# Out:
#              zinc_id                                             smiles  \
# 0   ZINC000000056646                 CC(C)NC[C@@H](O)COc1cccc2[nH]ccc12
# 1   ZINC000003929022  CC(C)OC(=O)OCOP(=O)(CO[C@H](C)Cn1cnc2c(N)ncnc2...
# 2   ZINC000000004760                 O[C@](CCN1CCCC1)(c1ccccc1)C1CCCCC1
# 3   ZINC000008220548  CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...
# 4   ZINC000004095793  OC[C@H]1O[C@H](O)[C@H](O)[C@@H](O)[C@@H]1O[C@@...
# ..               ...                                                ...
# 95  ZINC000253476025  CC(C)[N@+]1(C)[C@H]2CC[C@@H]1C[C@H](OC(=O)[C@H...
# 96  ZINC000008552159  N[C@H](CCC(=O)N[C@H](CS[C@@H]1CCO[P@@](=O)(N(C...
# 97  ZINC000003779720  CC(C)c1cc2c(cc1S(=O)(=O)O)[C@@]1(C)CCC[C@@](C)...
# 98  ZINC000077312930  O=C(Nc1c(Cl)c[n+]([O-])cc1Cl)c1ccc(OC(F)F)c(OC...
# 99  ZINC000000002097                    COc1nccnc1NS(=O)(=O)c1ccc(N)cc1
#
#                                          smiles_rdkit   results
# 0                  CC(C)NC[C@@H](O)COc1cccc2[nH]ccc12  0.380811
# 1   CC(C)OC(=O)OCOP(=O)(CO[C@H](C)Cn1cnc2c(N)ncnc2...  0.375881
# 2                  O[C@](CCN1CCCC1)(c1ccccc1)C1CCCCC1  0.352869
# 3   CC[C@H]1[C@@H]2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]4...  0.348708
# 4   OC[C@H]1O[C@H](O)[C@H](O)[C@@H](O)[C@@H]1O[C@@...  0.347759
# ..                                                ...       ...
# 95  CC(C)[N@+]1(C)[C@H]2CC[C@@H]1C[C@H](OC(=O)[C@H...  0.290118
# 96  N[C@H](CCC(=O)N[C@H](CS[C@@H]1CCO[P@@](=O)(N(C...  0.289406
# 97  CC(C)c1cc2c(cc1S(=O)(=O)O)[C@@]1(C)CCC[C@@](C)...  0.289152
# 98  O=C(Nc1c(Cl)c[n+]([O-])cc1Cl)c1ccc(OC(F)F)c(OC...  0.289059
# 99                    COc1nccnc1NS(=O)(=O)c1ccc(N)cc1  0.289037
#
# [100 rows x 4 columns]

# %%
df_zinc_output_top_100.to_csv("../../data/zinc_world_top_100.csv", index=False)

# %%
### End

# %%
# y_pred = dleps_p.model[0].predict(smile_train)
# rna_train = np.reshape(rna_train, y_pred.shape)
# print(rna_train.shape)
# print(y_pred.shape)
# corr = np.array([0.])
# corr=np.hstack((corr,np.corrcoef(rna_train[0],y_pred[0])[0, 1]))
# print(corr)

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# %matplotlib inline

# y_pred = dleps_p.model[0].predict(smile_train)

# corr = np.array([0.])

# print(smile_train.shape)

# print(y_pred.shape)
# for i in range(smile_train.shape[0]):
    
#     corr=np.hstack((corr,np.corrcoef(rna_train[i],y_pred[i])[0, 1]))
# plt.hist(corr,50)
# plt.show()
# print(corr.mean())

# %%
# corr

# %%
# from scipy.stats import gaussian_kde

# def density(x,y):
#     xy = np.vstack([x,y])
#     return gaussian_kde(xy)(xy)

# %% [markdown]
# Training set

# %%
# n = 10  # how many digits we will display
# sam = 50
# plt.figure(figsize=(20, 6))

# with plt.style.context(['ggplot']):
#     plt.figure(figsize=(20, 6))
#     for i in range(10):
#         # display original
#         ax = plt.subplot(3, n, i + 1)

#         plt.scatter(y_pred[sam+i],rna_train[sam+i],c=density(y_pred[sam+i],rna_train[sam+i]),s=8,cmap=plt.get_cmap("coolwarm"))
#         ax = plt.subplot(3, n, i + 1*10+1)

#         plt.scatter(y_pred[sam+i+10],rna_train[sam+i+10],c=density(y_pred[sam+i+10],rna_train[sam+i+10]),s=8,cmap=plt.get_cmap("coolwarm"))
#         ax = plt.subplot(3, n, i + 1*20+1)

#         plt.scatter(y_pred[sam+i+20],rna_train[sam+i+20],c=density(y_pred[sam+i+20],rna_train[sam+i+20]),s=8,cmap=plt.get_cmap("coolwarm"))


# plt.tight_layout()
# #plt.savefig('../analysis_plot/Figures/Train_Samples3_density.svg', format='svg')

# %%
# plt.style.available

# %% [markdown]
# Analysis of Testing set

# %%
# y_pred2 = dleps_p.model[0].predict(smile_test)

# corr = np.array([0.])

# print(smile_test.shape)

# print(y_pred2.shape)
# for i in range(smile_test.shape[0]):
#     corr=np.hstack((corr,np.corrcoef(rna_test[i],y_pred2[i])[0, 1]))
# plt.hist(corr,50)
# plt.show()
# print(corr.mean())

# %% [markdown]
# Testing set

# %%
# n = 10  # how many digits we will display
# sam = 50
# with plt.style.context(['science','no-latex']):
#     plt.figure(figsize=(20, 6))
#     for i in range(10):
#         # display original
#         ax = plt.subplot(3, n, i + 1)

#         plt.scatter(y_pred2[sam+i],rna_test[sam+i],s=8,c=density(y_pred2[sam+i],rna_test[sam+i]),cmap="coolwarm")
#         ax = plt.subplot(3, n, i + 1*10+1)

#         plt.scatter(y_pred2[sam+i+10],rna_test[sam+i+10],c=density(y_pred2[sam+i+10],rna_test[sam+i+10]),s=8,cmap=plt.get_cmap("coolwarm"))
#         ax = plt.subplot(3, n, i + 1*20+1)

#         plt.scatter(y_pred2[sam+i+20],rna_test[sam+i+20],c=density(y_pred2[sam+i+20],rna_test[sam+i+20]),s=8,cmap=plt.get_cmap("coolwarm"))


# plt.tight_layout()
# #plt.savefig('../analysis_plot/Figures/Test_Samples3_density.svg', format='svg')
