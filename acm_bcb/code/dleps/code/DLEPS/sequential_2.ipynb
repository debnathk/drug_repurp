# %% [markdown]
# # Start with basic model, without hyperparameter tuning, keeping the epoch high

# %% [markdown]
# # Import libraries

# %%
# import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Flatten, Input, Dropout
from keras.models import Model
from keras import regularizers 
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
# tf.enable_eager_execution()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Create a Fully Connected Network

# %%
# define the keras model

visible_1 = Input(shape=(978, 2))
flaten_1 = Flatten()(visible_1)
dense_11 = Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(0.00001))(flaten_1)
drop_1 = Dropout(0.4)(dense_11)
dense_12 = Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.00001))(drop_1)
drop_2 = Dropout(0.4)(dense_12)
dense_13 = Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.00001))(drop_2)
drop_3 = Dropout(0.4)(dense_13)
dense_14 = Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.00001))(drop_3)
drop_4 = Dropout(0.4)(dense_14)
dense_15 = Dense(56, activation='relu', kernel_regularizer=regularizers.l2(0.00001))(drop_4)
output_1 = Dense(1, activation='linear')(dense_15)
sequential = Model(inputs=visible_1, outputs=output_1)
# Out:
# WARNING:tensorflow:From c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# # Feed Forward model summary

# %%
sequential.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 978, 2)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1956)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              2003968
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 56)                7224
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 57
# =================================================================
# Total params: 2,700,273
# Trainable params: 2,700,273
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Workflow
# Our goal here is to combine the outputs of a FC model and VAE model - a process known as model ensemble (weighted sum)/model stacking (concatenation).
# - Af of now, for 781 drugs:
#     - For VAE model: features = (for each drug)(277 * 76)(Max_length * #production), labels = lab_experiment_shrinkage_measure(regression_value)
#     - For FC model: features = (for each drug)(978 * 2)(#landmark_genes * #replicates), labels = lab_experiment_shrinkage_measure(regression_value)

# %% [markdown]
# # Create predictor setup

# %%
# Hyperparameters
epochs = 500
batch_size = 50
# lr = 0.001

# %%
# Compile the model
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
sequential.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])  # Mean Squared Error and Mean Absolute Error as metrics for regression

# %% [markdown]
# # Load dummy datasets

# %%
# import h5py

# h5f = h5py.File('../../code/demo_data_train.h5', 'r')
# data_train = h5f['data'][:]
# h5f2 = h5py.File('../../code/demo_labels_train.h5', 'r')
# labels_train = h5f2['data'][:]
# h5f3 = h5py.File('../../code/demo_data_test.h5', 'r')
# data_test = h5f3['data'][:]
# h5f4 = h5py.File('../../code/demo_labels_test.h5', 'r')
# labels_test = h5f4['data'][:]

# print(data_train.shape)
# print(labels_train.shape)
# print(data_test.shape)
# print(labels_test.shape)

# %% [markdown]
# # Load gene expression datasets

# %%
import h5py

h5f = h5py.File('../../data/gene_exp_data_train.h5', 'r')
data_train = h5f['data'][:]
h5f2 = h5py.File('../../data/y_train.h5', 'r')
y_train = h5f2['data'][:]
h5f3 = h5py.File('../../data/gene_exp_data_test.h5', 'r')
data_test = h5f3['data'][:]
h5f4 = h5py.File('../../data/y_test.h5', 'r')
y_test = h5f4['data'][:]

print(data_train.shape)
print(y_train.shape)
print(data_test.shape)
print(y_test.shape)
# Out:
# (350, 978, 2)
# (350,)
# (75, 978, 2)
# (75,)

# %%
y_train
# Out:
# array([ 0.31870147,  0.        ,  0.        ,  0.34142961,  0.63646757,
#         0.1180304 ,  0.34099285,  0.35394935,  0.18696834,  0.        ,
#         0.5876263 ,  0.55351936,  0.31120249,  0.45899222,  0.37034251,
#         0.08709298,  0.55740248, -0.33594711,  0.        ,  0.11327593,
#         0.30463854,  0.42623692,  0.44397821, -0.72502218,  0.35462568,
#         0.15875689,  0.75497421, -0.33522473,  0.5652437 ,  0.28033079,
#         0.27635941,  0.54927641, -0.1186228 ,  0.39184923,  0.81990192,
#         0.04099389,  0.19681693,  0.64381663, -0.9902941 ,  0.27234796,
#         0.03512117,  0.36485174, -0.68464686,  0.35530743,  0.26567856,
#         0.36192124,  0.2016589 ,  0.01625079,  0.42056455,  0.44375193,
#         0.58765375,  0.13670053,  0.36507739,  0.14406319, -0.01102782,
#        -0.49747348,  0.18451314,  0.41469743,  0.19897498, -0.26625046,
#         0.43062639,  0.62288937, -0.48614113,  0.12902235,  0.62730443,
#         0.53584646,  0.24025383,  0.35299475, -0.20456006,  0.57435941,
#         0.4201331 ,  0.00225281,  0.32435231,  0.15893491,  0.25702861,
#         0.58369972, -0.5862925 ,  0.38661113,  0.56446508,  0.01538956,
#         0.00153177, -0.76430592,  0.47629381,  0.12972626,  0.33720392,
#         0.28102888,  0.56487079,  0.54691815,  0.53168898, -0.23815286,
#        -0.05553755, -0.20657813,  0.49599289, -0.25996808,  0.14485236,
#         0.41108915,  0.48739195,  0.25305298, -0.19176904,  0.90366309,
#         0.20753409,  0.38681861,  0.52944552,  0.12791741,  0.19270093,
#         0.49874361, -0.0361616 , -0.02446402,  0.32618655,  0.        ,
#         0.37274223,  0.21344873, -0.77612202,  0.02586053,  0.32226319,
#         0.26800748,  0.53995687,  0.58470718, -0.35283821,  0.23384679,
#         0.03548016,  0.30173732, -0.06889876, -0.48425313,  0.21049757,
#         0.20060726, -0.03767369,  0.20487056, -0.36553015, -0.77707281,
#         0.60300505, -0.47488652, -0.76563464, -0.23029822,  0.37113374,
#         0.82711676, -0.26056121, -0.76798967,  0.30628899,  0.23970329,
#        -0.11974618,  0.02435587,  0.12338672,  0.22511732, -0.60348111,
#        -0.5131304 ,  0.23021614, -0.79806442,  0.43806839, -0.82858649,
#         0.01687326, -0.04599207,  0.34626271,  0.04991001,  0.87349956,
#         0.29189974,  0.74038302,  0.4228221 , -0.74932095, -0.04604251,
#        -0.0912934 ,  0.07763894, -0.11974618,  0.14491305, -0.28784296,
#         0.09524477, -0.29454041, -0.06899779, -0.35712853,  0.47692695,
#        -0.38917101, -0.57937048,  0.58931132, -0.01213758,  0.00739325,
#        -0.45655196, -0.05888414,  0.39853221, -0.80005618,  0.16099463,
#         0.18411486,  0.20575444,  0.49672266,  0.56171273,  0.28102207,
#         0.6184469 , -0.02446402,  0.05884213,  0.18890806,  0.44642936,
#         0.50113729, -0.00557041,  0.56548888,  0.49814692,  0.60809175,
#         0.61973508,  0.06618717,  0.37927527, -0.45922463,  0.16198295,
#         0.49208596, -0.05439913,  0.34853016,  0.37361019,  0.37524241,
#         0.26569346,  0.01742526, -0.64779703,  0.3165756 ,  0.26213645,
#         0.05577447,  0.16611684, -0.18941894,  0.15969312,  0.04382642,
#         0.10211155,  0.37954416,  0.64181174,  0.81880367,  0.61306321,
#        -0.01360136, -0.42081684,  0.26943588, -0.60495327, -0.21529161,
#        -0.58710298, -0.05573927,  0.42458488,  0.51636915,  0.12106915,
#         0.14938635,  0.29082501, -0.18782901, -0.27108358,  0.5211497 ,
#         0.48340788,  0.37134106,  0.43773119,  0.50955614,  0.01580898,
#        -0.72886554,  0.22749031, -0.23797224,  0.39311371, -0.17800726,
#         0.57400328,  0.35773596,  0.54267185, -0.2964232 ,  0.53987836,
#         0.0380312 ,  0.41923887,  0.40391556, -0.04322892,  0.47282106,
#        -0.13927028, -0.0366909 , -0.00168154, -0.10913882, -0.1563465 ,
#         0.24730522,  0.22429439,  0.53806418,  0.2114958 ,  0.28553558,
#        -0.78000487,  0.49423725,  0.1328042 ,  0.03534474, -0.07849025,
#        -0.7955126 ,  0.11854454,  0.29111545,  0.31940773,  0.4214168 ,
#         0.54163045,  0.75291383,  0.63710713,  0.40020236,  0.1903236 ,
#         0.80929244,  0.36098407,  0.05156508,  0.45539373,  0.57795979,
#         0.0147698 ,  0.1168312 ,  0.10416488,  0.09761671, -0.19452071,
#         0.1000738 ,  0.31921516, -0.07007878,  0.36098407,  0.20483322,
#         0.3267428 ,  0.46123553, -0.10343111,  0.14789651,  0.32045194,
#         0.29934796,  0.08301972,  0.5219478 ,  0.53480233,  0.55958188,
#         0.3781415 , -0.7200041 , -0.09804993,  0.57459034,  0.4915913 ,
#         0.09470735,  0.55806924,  0.63323068,  0.42340244,  0.2943936 ,
#        -0.09594627,  0.27796089, -0.76563464,  0.43184361, -0.23026576,
#         0.37798416, -0.01501714, -0.00825384,  0.14802603,  0.20794947,
#        -0.20452404,  0.55099433, -0.17233041, -0.33836884, -0.53448661,
#         0.16611684,  0.68558356,  0.66665035,  0.42915289,  0.23884963,
#         0.23714301, -0.74969073, -0.02355487,  0.34205271, -0.762849  ,
#        -0.36445594, -0.35129232,  0.57705757,  0.71371934,  0.21622247,
#         0.31685652,  0.18188189, -0.18411794,  0.18221501,  0.33755932])

# %% [markdown]
# # Load pretrained weights

# %%
sequential.load_weights('../../data/sample_weights.h5')

# %% [markdown]
# # Train the model

# %%
# # learning rate schedule
# import math
# def step_decay(epoch):
#     initial_lrate = 0.0001
#     drop = 0.01
#     epochs_drop = 100.0
#     lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
#     return lrate

# %%
# Set up ModelCheckpoint to save weights for the epoch with the best validation loss
# checkpoint_filepath = "../../data/seq_weights.h5"
checkpoint_filepath = "../../../../../data/seq_weights_lr_sched_2.h5"
model_checkpoint = ModelCheckpoint(checkpoint_filepath, save_best_only=True, monitor='val_loss', mode='min', verbose=1)

# %%
# Train the model
# epochs = 1000
# batch_size = 50
# lr_scheduler = LearningRateScheduler(step_decay)
history = sequential.fit(data_train, y_train, validation_data=(data_test, y_test), epochs=epochs, batch_size=batch_size, verbose=2, callbacks=[model_checkpoint])
# Out:
# WARNING:tensorflow:From c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 671 samples, validate on 100 samples
# Epoch 1/10000
#  - 1s - loss: 0.2086 - mae: 0.3454 - val_loss: 0.2143 - val_mae: 0.3552
#
# Epoch 00001: val_loss improved from inf to 0.21427, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 2/10000
#  - 1s - loss: 0.2158 - mae: 0.3480 - val_loss: 0.2000 - val_mae: 0.3297
#
# Epoch 00002: val_loss improved from 0.21427 to 0.20004, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 3/10000
#  - 1s - loss: 0.2046 - mae: 0.3373 - val_loss: 0.1955 - val_mae: 0.3189
#
# Epoch 00003: val_loss improved from 0.20004 to 0.19549, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 4/10000
#  - 1s - loss: 0.2011 - mae: 0.3343 - val_loss: 0.1952 - val_mae: 0.3200
#
# Epoch 00004: val_loss improved from 0.19549 to 0.19524, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 5/10000
#  - 1s - loss: 0.2021 - mae: 0.3362 - val_loss: 0.1947 - val_mae: 0.3180
#
# Epoch 00005: val_loss improved from 0.19524 to 0.19473, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 6/10000
#  - 1s - loss: 0.1951 - mae: 0.3296 - val_loss: 0.1968 - val_mae: 0.3221
#
# Epoch 00006: val_loss did not improve from 0.19473
# Epoch 7/10000
#  - 1s - loss: 0.1954 - mae: 0.3302 - val_loss: 0.1942 - val_mae: 0.3178
#
# Epoch 00007: val_loss improved from 0.19473 to 0.19419, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 8/10000
#  - 1s - loss: 0.1951 - mae: 0.3306 - val_loss: 0.1948 - val_mae: 0.3226
#
# Epoch 00008: val_loss did not improve from 0.19419
# Epoch 9/10000
#  - 1s - loss: 0.1884 - mae: 0.3211 - val_loss: 0.1941 - val_mae: 0.3213
#
# Epoch 00009: val_loss improved from 0.19419 to 0.19412, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 10/10000
#  - 1s - loss: 0.1921 - mae: 0.3272 - val_loss: 0.1953 - val_mae: 0.3267
#
# Epoch 00010: val_loss did not improve from 0.19412
# Epoch 11/10000
#  - 1s - loss: 0.1893 - mae: 0.3266 - val_loss: 0.1927 - val_mae: 0.3205
#
# Epoch 00011: val_loss improved from 0.19412 to 0.19274, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 12/10000
#  - 1s - loss: 0.1916 - mae: 0.3250 - val_loss: 0.1959 - val_mae: 0.3298
#
# Epoch 00012: val_loss did not improve from 0.19274
# Epoch 13/10000
#  - 1s - loss: 0.1829 - mae: 0.3174 - val_loss: 0.1929 - val_mae: 0.3222
#
# Epoch 00013: val_loss did not improve from 0.19274
# Epoch 14/10000
#  - 1s - loss: 0.1868 - mae: 0.3217 - val_loss: 0.1916 - val_mae: 0.3230
#
# Epoch 00014: val_loss improved from 0.19274 to 0.19157, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 15/10000
#  - 1s - loss: 0.1832 - mae: 0.3176 - val_loss: 0.1974 - val_mae: 0.3348
#
# Epoch 00015: val_loss did not improve from 0.19157
# Epoch 16/10000
#  - 1s - loss: 0.1779 - mae: 0.3128 - val_loss: 0.1931 - val_mae: 0.3250
#
# Epoch 00016: val_loss did not improve from 0.19157
# Epoch 17/10000
#  - 1s - loss: 0.1717 - mae: 0.3037 - val_loss: 0.2084 - val_mae: 0.3450
#
# Epoch 00017: val_loss did not improve from 0.19157
# Epoch 18/10000
#  - 1s - loss: 0.1749 - mae: 0.3107 - val_loss: 0.1880 - val_mae: 0.3120
#
# Epoch 00018: val_loss improved from 0.19157 to 0.18797, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 19/10000
#  - 1s - loss: 0.1740 - mae: 0.3066 - val_loss: 0.1898 - val_mae: 0.3219
#
# Epoch 00019: val_loss did not improve from 0.18797
# Epoch 20/10000
#  - 1s - loss: 0.1659 - mae: 0.2947 - val_loss: 0.1920 - val_mae: 0.3198
#
# Epoch 00020: val_loss did not improve from 0.18797
# Epoch 21/10000
#  - 1s - loss: 0.1639 - mae: 0.2976 - val_loss: 0.1947 - val_mae: 0.3290
#
# Epoch 00021: val_loss did not improve from 0.18797
# Epoch 22/10000
#  - 1s - loss: 0.1632 - mae: 0.2965 - val_loss: 0.1915 - val_mae: 0.3220
#
# Epoch 00022: val_loss did not improve from 0.18797
# Epoch 23/10000
#  - 1s - loss: 0.1589 - mae: 0.2869 - val_loss: 0.1913 - val_mae: 0.3187
#
# Epoch 00023: val_loss did not improve from 0.18797
# Epoch 24/10000
#  - 1s - loss: 0.1502 - mae: 0.2772 - val_loss: 0.1882 - val_mae: 0.3166
#
# Epoch 00024: val_loss did not improve from 0.18797
# Epoch 25/10000
#  - 1s - loss: 0.1401 - mae: 0.2631 - val_loss: 0.1941 - val_mae: 0.3189
#
# Epoch 00025: val_loss did not improve from 0.18797
# Epoch 26/10000
#  - 1s - loss: 0.1422 - mae: 0.2638 - val_loss: 0.1946 - val_mae: 0.3235
#
# Epoch 00026: val_loss did not improve from 0.18797
# Epoch 27/10000
#  - 1s - loss: 0.1443 - mae: 0.2723 - val_loss: 0.1904 - val_mae: 0.3183
#
# Epoch 00027: val_loss did not improve from 0.18797
# Epoch 28/10000
#  - 1s - loss: 0.1392 - mae: 0.2615 - val_loss: 0.1925 - val_mae: 0.3165
#
# Epoch 00028: val_loss did not improve from 0.18797
# Epoch 29/10000
#  - 1s - loss: 0.1361 - mae: 0.2551 - val_loss: 0.1930 - val_mae: 0.3195
#
# Epoch 00029: val_loss did not improve from 0.18797
# Epoch 30/10000
#  - 1s - loss: 0.1363 - mae: 0.2556 - val_loss: 0.1983 - val_mae: 0.3288
#
# Epoch 00030: val_loss did not improve from 0.18797
# Epoch 31/10000
#  - 1s - loss: 0.1349 - mae: 0.2514 - val_loss: 0.1965 - val_mae: 0.3243
#
# Epoch 00031: val_loss did not improve from 0.18797
# Epoch 32/10000
#  - 1s - loss: 0.1302 - mae: 0.2489 - val_loss: 0.1967 - val_mae: 0.3246
#
# Epoch 00032: val_loss did not improve from 0.18797
# Epoch 33/10000
#  - 1s - loss: 0.1310 - mae: 0.2478 - val_loss: 0.1945 - val_mae: 0.3240
#
# Epoch 00033: val_loss did not improve from 0.18797
# Epoch 34/10000
#  - 1s - loss: 0.1282 - mae: 0.2441 - val_loss: 0.1974 - val_mae: 0.3199
#
# Epoch 00034: val_loss did not improve from 0.18797
# Epoch 35/10000
#  - 1s - loss: 0.1285 - mae: 0.2448 - val_loss: 0.1944 - val_mae: 0.3224
#
# Epoch 00035: val_loss did not improve from 0.18797
# Epoch 36/10000
#  - 1s - loss: 0.1289 - mae: 0.2438 - val_loss: 0.1942 - val_mae: 0.3254
#
# Epoch 00036: val_loss did not improve from 0.18797
# Epoch 37/10000
#  - 1s - loss: 0.1287 - mae: 0.2394 - val_loss: 0.1925 - val_mae: 0.3198
#
# Epoch 00037: val_loss did not improve from 0.18797
# Epoch 38/10000
#  - 1s - loss: 0.1322 - mae: 0.2454 - val_loss: 0.1951 - val_mae: 0.3262
#
# Epoch 00038: val_loss did not improve from 0.18797
# Epoch 39/10000
#  - 1s - loss: 0.1256 - mae: 0.2375 - val_loss: 0.1926 - val_mae: 0.3251
#
# Epoch 00039: val_loss did not improve from 0.18797
# Epoch 40/10000
#  - 1s - loss: 0.1230 - mae: 0.2331 - val_loss: 0.1981 - val_mae: 0.3262
#
# Epoch 00040: val_loss did not improve from 0.18797
# Epoch 41/10000
#  - 1s - loss: 0.1285 - mae: 0.2390 - val_loss: 0.1960 - val_mae: 0.3309
#
# Epoch 00041: val_loss did not improve from 0.18797
# Epoch 42/10000
#  - 1s - loss: 0.1238 - mae: 0.2369 - val_loss: 0.2012 - val_mae: 0.3345
#
# Epoch 00042: val_loss did not improve from 0.18797
# Epoch 43/10000
#  - 1s - loss: 0.1235 - mae: 0.2370 - val_loss: 0.2012 - val_mae: 0.3297
#
# Epoch 00043: val_loss did not improve from 0.18797
# Epoch 44/10000
#  - 1s - loss: 0.1234 - mae: 0.2320 - val_loss: 0.1964 - val_mae: 0.3270
#
# Epoch 00044: val_loss did not improve from 0.18797
# Epoch 45/10000
#  - 1s - loss: 0.1214 - mae: 0.2313 - val_loss: 0.1944 - val_mae: 0.3226
#
# Epoch 00045: val_loss did not improve from 0.18797
# Epoch 46/10000
#  - 1s - loss: 0.1250 - mae: 0.2383 - val_loss: 0.1982 - val_mae: 0.3298
#
# Epoch 00046: val_loss did not improve from 0.18797
# Epoch 47/10000
#  - 1s - loss: 0.1218 - mae: 0.2313 - val_loss: 0.1979 - val_mae: 0.3251
#
# Epoch 00047: val_loss did not improve from 0.18797
# Epoch 48/10000
#  - 1s - loss: 0.1196 - mae: 0.2271 - val_loss: 0.1965 - val_mae: 0.3241
#
# Epoch 00048: val_loss did not improve from 0.18797
# Epoch 49/10000
#  - 1s - loss: 0.1186 - mae: 0.2271 - val_loss: 0.1961 - val_mae: 0.3300
#
# Epoch 00049: val_loss did not improve from 0.18797
# Epoch 50/10000
#  - 1s - loss: 0.1193 - mae: 0.2275 - val_loss: 0.1960 - val_mae: 0.3259
#
# Epoch 00050: val_loss did not improve from 0.18797
# Epoch 51/10000
#  - 1s - loss: 0.1210 - mae: 0.2322 - val_loss: 0.1970 - val_mae: 0.3221
#
# Epoch 00051: val_loss did not improve from 0.18797
# Epoch 52/10000
#  - 1s - loss: 0.1214 - mae: 0.2343 - val_loss: 0.1925 - val_mae: 0.3262
#
# Epoch 00052: val_loss did not improve from 0.18797
# Epoch 53/10000
#  - 1s - loss: 0.1171 - mae: 0.2216 - val_loss: 0.1932 - val_mae: 0.3194
#
# Epoch 00053: val_loss did not improve from 0.18797
# Epoch 54/10000
#  - 1s - loss: 0.1194 - mae: 0.2232 - val_loss: 0.1939 - val_mae: 0.3286
#
# Epoch 00054: val_loss did not improve from 0.18797
# Epoch 55/10000
#  - 1s - loss: 0.1195 - mae: 0.2291 - val_loss: 0.1896 - val_mae: 0.3196
#
# Epoch 00055: val_loss did not improve from 0.18797
# Epoch 56/10000
#  - 1s - loss: 0.1189 - mae: 0.2278 - val_loss: 0.1937 - val_mae: 0.3227
#
# Epoch 00056: val_loss did not improve from 0.18797
# Epoch 57/10000
#  - 1s - loss: 0.1181 - mae: 0.2254 - val_loss: 0.1914 - val_mae: 0.3251
#
# Epoch 00057: val_loss did not improve from 0.18797
# Epoch 58/10000
#  - 1s - loss: 0.1164 - mae: 0.2242 - val_loss: 0.1922 - val_mae: 0.3254
#
# Epoch 00058: val_loss did not improve from 0.18797
# Epoch 59/10000
#  - 1s - loss: 0.1184 - mae: 0.2289 - val_loss: 0.1935 - val_mae: 0.3255
#
# Epoch 00059: val_loss did not improve from 0.18797
# Epoch 60/10000
#  - 1s - loss: 0.1160 - mae: 0.2239 - val_loss: 0.1914 - val_mae: 0.3237
#
# Epoch 00060: val_loss did not improve from 0.18797
# Epoch 61/10000
#  - 1s - loss: 0.1177 - mae: 0.2263 - val_loss: 0.1908 - val_mae: 0.3216
#
# Epoch 00061: val_loss did not improve from 0.18797
# Epoch 62/10000
#  - 1s - loss: 0.1137 - mae: 0.2187 - val_loss: 0.1906 - val_mae: 0.3241
#
# Epoch 00062: val_loss did not improve from 0.18797
# Epoch 63/10000
#  - 1s - loss: 0.1156 - mae: 0.2227 - val_loss: 0.1909 - val_mae: 0.3272
#
# Epoch 00063: val_loss did not improve from 0.18797
# Epoch 64/10000
#  - 1s - loss: 0.1158 - mae: 0.2219 - val_loss: 0.1893 - val_mae: 0.3207
#
# Epoch 00064: val_loss did not improve from 0.18797
# Epoch 65/10000
#  - 1s - loss: 0.1147 - mae: 0.2188 - val_loss: 0.1914 - val_mae: 0.3245
#
# Epoch 00065: val_loss did not improve from 0.18797
# Epoch 66/10000
#  - 1s - loss: 0.1138 - mae: 0.2159 - val_loss: 0.1919 - val_mae: 0.3220
#
# Epoch 00066: val_loss did not improve from 0.18797
# Epoch 67/10000
#  - 1s - loss: 0.1123 - mae: 0.2145 - val_loss: 0.1951 - val_mae: 0.3305
#
# Epoch 00067: val_loss did not improve from 0.18797
# Epoch 68/10000
#  - 1s - loss: 0.1129 - mae: 0.2158 - val_loss: 0.1951 - val_mae: 0.3261
#
# Epoch 00068: val_loss did not improve from 0.18797
# Epoch 69/10000
#  - 1s - loss: 0.1151 - mae: 0.2200 - val_loss: 0.1954 - val_mae: 0.3295
#
# Epoch 00069: val_loss did not improve from 0.18797
# Epoch 70/10000
#  - 1s - loss: 0.1129 - mae: 0.2174 - val_loss: 0.1937 - val_mae: 0.3237
#
# Epoch 00070: val_loss did not improve from 0.18797
# Epoch 71/10000
#  - 1s - loss: 0.1117 - mae: 0.2140 - val_loss: 0.1943 - val_mae: 0.3244
#
# Epoch 00071: val_loss did not improve from 0.18797
# Epoch 72/10000
#  - 1s - loss: 0.1171 - mae: 0.2247 - val_loss: 0.1944 - val_mae: 0.3315
#
# Epoch 00072: val_loss did not improve from 0.18797
# Epoch 73/10000
#  - 1s - loss: 0.1163 - mae: 0.2255 - val_loss: 0.1894 - val_mae: 0.3233
#
# Epoch 00073: val_loss did not improve from 0.18797
# Epoch 74/10000
#  - 1s - loss: 0.1147 - mae: 0.2195 - val_loss: 0.1907 - val_mae: 0.3222
#
# Epoch 00074: val_loss did not improve from 0.18797
# Epoch 75/10000
#  - 1s - loss: 0.1130 - mae: 0.2165 - val_loss: 0.1911 - val_mae: 0.3241
#
# Epoch 00075: val_loss did not improve from 0.18797
# Epoch 76/10000
#  - 1s - loss: 0.1125 - mae: 0.2149 - val_loss: 0.1900 - val_mae: 0.3249
#
# Epoch 00076: val_loss did not improve from 0.18797
# Epoch 77/10000
#  - 1s - loss: 0.1129 - mae: 0.2187 - val_loss: 0.1917 - val_mae: 0.3247
#
# Epoch 00077: val_loss did not improve from 0.18797
# Epoch 78/10000
#  - 1s - loss: 0.1115 - mae: 0.2144 - val_loss: 0.1890 - val_mae: 0.3228
#
# Epoch 00078: val_loss did not improve from 0.18797
# Epoch 79/10000
#  - 1s - loss: 0.1105 - mae: 0.2143 - val_loss: 0.1924 - val_mae: 0.3259
#
# Epoch 00079: val_loss did not improve from 0.18797
# Epoch 80/10000
#  - 1s - loss: 0.1123 - mae: 0.2190 - val_loss: 0.1915 - val_mae: 0.3231
#
# Epoch 00080: val_loss did not improve from 0.18797
# Epoch 81/10000
#  - 1s - loss: 0.1120 - mae: 0.2166 - val_loss: 0.1905 - val_mae: 0.3269
#
# Epoch 00081: val_loss did not improve from 0.18797
# Epoch 82/10000
#  - 1s - loss: 0.1126 - mae: 0.2186 - val_loss: 0.1886 - val_mae: 0.3217
#
# Epoch 00082: val_loss did not improve from 0.18797
# Epoch 83/10000
#  - 1s - loss: 0.1134 - mae: 0.2181 - val_loss: 0.1923 - val_mae: 0.3229
#
# Epoch 00083: val_loss did not improve from 0.18797
# Epoch 84/10000
#  - 1s - loss: 0.1100 - mae: 0.2121 - val_loss: 0.1989 - val_mae: 0.3292
#
# Epoch 00084: val_loss did not improve from 0.18797
# Epoch 85/10000
#  - 1s - loss: 0.1104 - mae: 0.2122 - val_loss: 0.1935 - val_mae: 0.3288
#
# Epoch 00085: val_loss did not improve from 0.18797
# Epoch 86/10000
#  - 1s - loss: 0.1107 - mae: 0.2138 - val_loss: 0.1930 - val_mae: 0.3275
#
# Epoch 00086: val_loss did not improve from 0.18797
# Epoch 87/10000
#  - 1s - loss: 0.1092 - mae: 0.2104 - val_loss: 0.1932 - val_mae: 0.3265
#
# Epoch 00087: val_loss did not improve from 0.18797
# Epoch 88/10000
#  - 1s - loss: 0.1107 - mae: 0.2137 - val_loss: 0.1908 - val_mae: 0.3246
#
# Epoch 00088: val_loss did not improve from 0.18797
# Epoch 89/10000
#  - 1s - loss: 0.1075 - mae: 0.2048 - val_loss: 0.1930 - val_mae: 0.3244
#
# Epoch 00089: val_loss did not improve from 0.18797
# Epoch 90/10000
#  - 1s - loss: 0.1104 - mae: 0.2141 - val_loss: 0.1934 - val_mae: 0.3273
#
# Epoch 00090: val_loss did not improve from 0.18797
# Epoch 91/10000
#  - 1s - loss: 0.1123 - mae: 0.2192 - val_loss: 0.1892 - val_mae: 0.3269
#
# Epoch 00091: val_loss did not improve from 0.18797
# Epoch 92/10000
#  - 1s - loss: 0.1124 - mae: 0.2227 - val_loss: 0.1922 - val_mae: 0.3267
#
# Epoch 00092: val_loss did not improve from 0.18797
# Epoch 93/10000
#  - 1s - loss: 0.1081 - mae: 0.2087 - val_loss: 0.1941 - val_mae: 0.3282
#
# Epoch 00093: val_loss did not improve from 0.18797
# Epoch 94/10000
#  - 1s - loss: 0.1125 - mae: 0.2146 - val_loss: 0.1941 - val_mae: 0.3273
#
# Epoch 00094: val_loss did not improve from 0.18797
# Epoch 95/10000
#  - 1s - loss: 0.1120 - mae: 0.2174 - val_loss: 0.1963 - val_mae: 0.3324
#
# Epoch 00095: val_loss did not improve from 0.18797
# Epoch 96/10000
#  - 1s - loss: 0.1101 - mae: 0.2121 - val_loss: 0.1916 - val_mae: 0.3266
#
# Epoch 00096: val_loss did not improve from 0.18797
# Epoch 97/10000
#  - 1s - loss: 0.1092 - mae: 0.2124 - val_loss: 0.1915 - val_mae: 0.3259
#
# Epoch 00097: val_loss did not improve from 0.18797
# Epoch 98/10000
#  - 1s - loss: 0.1093 - mae: 0.2123 - val_loss: 0.1879 - val_mae: 0.3251
#
# Epoch 00098: val_loss improved from 0.18797 to 0.18795, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 99/10000
#  - 1s - loss: 0.1099 - mae: 0.2120 - val_loss: 0.1895 - val_mae: 0.3289
#
# Epoch 00099: val_loss did not improve from 0.18795
# Epoch 100/10000
#  - 1s - loss: 0.1095 - mae: 0.2118 - val_loss: 0.1892 - val_mae: 0.3255
#
# Epoch 00100: val_loss did not improve from 0.18795
# Epoch 101/10000
#  - 1s - loss: 0.1091 - mae: 0.2127 - val_loss: 0.1917 - val_mae: 0.3313
#
# Epoch 00101: val_loss did not improve from 0.18795
# Epoch 102/10000
#  - 1s - loss: 0.1086 - mae: 0.2126 - val_loss: 0.1928 - val_mae: 0.3315
#
# Epoch 00102: val_loss did not improve from 0.18795
# Epoch 103/10000
#  - 1s - loss: 0.1094 - mae: 0.2136 - val_loss: 0.1918 - val_mae: 0.3304
#
# Epoch 00103: val_loss did not improve from 0.18795
# Epoch 104/10000
#  - 1s - loss: 0.1095 - mae: 0.2153 - val_loss: 0.1886 - val_mae: 0.3259
#
# Epoch 00104: val_loss did not improve from 0.18795
# Epoch 105/10000
#  - 1s - loss: 0.1094 - mae: 0.2144 - val_loss: 0.1881 - val_mae: 0.3224
#
# Epoch 00105: val_loss did not improve from 0.18795
# Epoch 106/10000
#  - 1s - loss: 0.1077 - mae: 0.2095 - val_loss: 0.1863 - val_mae: 0.3224
#
# Epoch 00106: val_loss improved from 0.18795 to 0.18635, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 107/10000
#  - 1s - loss: 0.1085 - mae: 0.2109 - val_loss: 0.1882 - val_mae: 0.3199
#
# Epoch 00107: val_loss did not improve from 0.18635
# Epoch 108/10000
#  - 1s - loss: 0.1079 - mae: 0.2111 - val_loss: 0.1913 - val_mae: 0.3297
#
# Epoch 00108: val_loss did not improve from 0.18635
# Epoch 109/10000
#  - 1s - loss: 0.1072 - mae: 0.2101 - val_loss: 0.1873 - val_mae: 0.3215
#
# Epoch 00109: val_loss did not improve from 0.18635
# Epoch 110/10000
#  - 1s - loss: 0.1077 - mae: 0.2091 - val_loss: 0.1861 - val_mae: 0.3205
#
# Epoch 00110: val_loss improved from 0.18635 to 0.18613, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 111/10000
#  - 1s - loss: 0.1088 - mae: 0.2134 - val_loss: 0.1877 - val_mae: 0.3199
#
# Epoch 00111: val_loss did not improve from 0.18613
# Epoch 112/10000
#  - 1s - loss: 0.1087 - mae: 0.2135 - val_loss: 0.1921 - val_mae: 0.3256
#
# Epoch 00112: val_loss did not improve from 0.18613
# Epoch 113/10000
#  - 1s - loss: 0.1064 - mae: 0.2077 - val_loss: 0.1904 - val_mae: 0.3247
#
# Epoch 00113: val_loss did not improve from 0.18613
# Epoch 114/10000
#  - 1s - loss: 0.1063 - mae: 0.2050 - val_loss: 0.1878 - val_mae: 0.3220
#
# Epoch 00114: val_loss did not improve from 0.18613
# Epoch 115/10000
#  - 1s - loss: 0.1061 - mae: 0.2060 - val_loss: 0.1886 - val_mae: 0.3223
#
# Epoch 00115: val_loss did not improve from 0.18613
# Epoch 116/10000
#  - 1s - loss: 0.1067 - mae: 0.2069 - val_loss: 0.1912 - val_mae: 0.3257
#
# Epoch 00116: val_loss did not improve from 0.18613
# Epoch 117/10000
#  - 1s - loss: 0.1078 - mae: 0.2112 - val_loss: 0.1897 - val_mae: 0.3263
#
# Epoch 00117: val_loss did not improve from 0.18613
# Epoch 118/10000
#  - 1s - loss: 0.1073 - mae: 0.2130 - val_loss: 0.1877 - val_mae: 0.3211
#
# Epoch 00118: val_loss did not improve from 0.18613
# Epoch 119/10000
#  - 1s - loss: 0.1080 - mae: 0.2147 - val_loss: 0.1896 - val_mae: 0.3277
#
# Epoch 00119: val_loss did not improve from 0.18613
# Epoch 120/10000
#  - 1s - loss: 0.1069 - mae: 0.2088 - val_loss: 0.1900 - val_mae: 0.3283
#
# Epoch 00120: val_loss did not improve from 0.18613
# Epoch 121/10000
#  - 1s - loss: 0.1055 - mae: 0.2075 - val_loss: 0.1938 - val_mae: 0.3307
#
# Epoch 00121: val_loss did not improve from 0.18613
# Epoch 122/10000
#  - 1s - loss: 0.1070 - mae: 0.2088 - val_loss: 0.1901 - val_mae: 0.3252
#
# Epoch 00122: val_loss did not improve from 0.18613
# Epoch 123/10000
#  - 1s - loss: 0.1069 - mae: 0.2099 - val_loss: 0.1887 - val_mae: 0.3253
#
# Epoch 00123: val_loss did not improve from 0.18613
# Epoch 124/10000
#  - 1s - loss: 0.1069 - mae: 0.2096 - val_loss: 0.1880 - val_mae: 0.3201
#
# Epoch 00124: val_loss did not improve from 0.18613
# Epoch 125/10000
#  - 1s - loss: 0.1071 - mae: 0.2111 - val_loss: 0.1933 - val_mae: 0.3320
#
# Epoch 00125: val_loss did not improve from 0.18613
# Epoch 126/10000
#  - 1s - loss: 0.1062 - mae: 0.2082 - val_loss: 0.1900 - val_mae: 0.3251
#
# Epoch 00126: val_loss did not improve from 0.18613
# Epoch 127/10000
#  - 1s - loss: 0.1059 - mae: 0.2072 - val_loss: 0.1883 - val_mae: 0.3216
#
# Epoch 00127: val_loss did not improve from 0.18613
# Epoch 128/10000
#  - 1s - loss: 0.1070 - mae: 0.2105 - val_loss: 0.1856 - val_mae: 0.3211
#
# Epoch 00128: val_loss improved from 0.18613 to 0.18559, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 129/10000
#  - 1s - loss: 0.1078 - mae: 0.2157 - val_loss: 0.1903 - val_mae: 0.3285
#
# Epoch 00129: val_loss did not improve from 0.18559
# Epoch 130/10000
#  - 1s - loss: 0.1070 - mae: 0.2116 - val_loss: 0.1860 - val_mae: 0.3217
#
# Epoch 00130: val_loss did not improve from 0.18559
# Epoch 131/10000
#  - 1s - loss: 0.1080 - mae: 0.2140 - val_loss: 0.1895 - val_mae: 0.3206
#
# Epoch 00131: val_loss did not improve from 0.18559
# Epoch 132/10000
#  - 1s - loss: 0.1084 - mae: 0.2160 - val_loss: 0.1920 - val_mae: 0.3277
#
# Epoch 00132: val_loss did not improve from 0.18559
# Epoch 133/10000
#  - 1s - loss: 0.1080 - mae: 0.2171 - val_loss: 0.1910 - val_mae: 0.3229
#
# Epoch 00133: val_loss did not improve from 0.18559
# Epoch 134/10000
#  - 1s - loss: 0.1070 - mae: 0.2132 - val_loss: 0.1874 - val_mae: 0.3238
#
# Epoch 00134: val_loss did not improve from 0.18559
# Epoch 135/10000
#  - 1s - loss: 0.1067 - mae: 0.2096 - val_loss: 0.1859 - val_mae: 0.3262
#
# Epoch 00135: val_loss did not improve from 0.18559
# Epoch 136/10000
#  - 1s - loss: 0.1071 - mae: 0.2142 - val_loss: 0.1874 - val_mae: 0.3263
#
# Epoch 00136: val_loss did not improve from 0.18559
# Epoch 137/10000
#  - 1s - loss: 0.1049 - mae: 0.2092 - val_loss: 0.1903 - val_mae: 0.3275
#
# Epoch 00137: val_loss did not improve from 0.18559
# Epoch 138/10000
#  - 1s - loss: 0.1041 - mae: 0.2044 - val_loss: 0.1900 - val_mae: 0.3251
#
# Epoch 00138: val_loss did not improve from 0.18559
# Epoch 139/10000
#  - 1s - loss: 0.1052 - mae: 0.2069 - val_loss: 0.1892 - val_mae: 0.3234
#
# Epoch 00139: val_loss did not improve from 0.18559
# Epoch 140/10000
#  - 1s - loss: 0.1061 - mae: 0.2113 - val_loss: 0.1893 - val_mae: 0.3257
#
# Epoch 00140: val_loss did not improve from 0.18559
# Epoch 141/10000
#  - 1s - loss: 0.1063 - mae: 0.2129 - val_loss: 0.1910 - val_mae: 0.3287
#
# Epoch 00141: val_loss did not improve from 0.18559
# Epoch 142/10000
#  - 1s - loss: 0.1050 - mae: 0.2096 - val_loss: 0.1923 - val_mae: 0.3267
#
# Epoch 00142: val_loss did not improve from 0.18559
# Epoch 143/10000
#  - 1s - loss: 0.1055 - mae: 0.2089 - val_loss: 0.1872 - val_mae: 0.3215
#
# Epoch 00143: val_loss did not improve from 0.18559
# Epoch 144/10000
#  - 1s - loss: 0.1050 - mae: 0.2110 - val_loss: 0.1873 - val_mae: 0.3252
#
# Epoch 00144: val_loss did not improve from 0.18559
# Epoch 145/10000
#  - 1s - loss: 0.1051 - mae: 0.2075 - val_loss: 0.1898 - val_mae: 0.3242
#
# Epoch 00145: val_loss did not improve from 0.18559
# Epoch 146/10000
#  - 1s - loss: 0.1039 - mae: 0.2057 - val_loss: 0.1889 - val_mae: 0.3245
#
# Epoch 00146: val_loss did not improve from 0.18559
# Epoch 147/10000
#  - 1s - loss: 0.1049 - mae: 0.2058 - val_loss: 0.1886 - val_mae: 0.3256
#
# Epoch 00147: val_loss did not improve from 0.18559
# Epoch 148/10000
#  - 1s - loss: 0.1053 - mae: 0.2091 - val_loss: 0.1875 - val_mae: 0.3236
#
# Epoch 00148: val_loss did not improve from 0.18559
# Epoch 149/10000
#  - 1s - loss: 0.1047 - mae: 0.2059 - val_loss: 0.1890 - val_mae: 0.3221
#
# Epoch 00149: val_loss did not improve from 0.18559
# Epoch 150/10000
#  - 1s - loss: 0.1041 - mae: 0.2057 - val_loss: 0.1887 - val_mae: 0.3270
#
# Epoch 00150: val_loss did not improve from 0.18559
# Epoch 151/10000
#  - 1s - loss: 0.1042 - mae: 0.2064 - val_loss: 0.1917 - val_mae: 0.3314
#
# Epoch 00151: val_loss did not improve from 0.18559
# Epoch 152/10000
#  - 1s - loss: 0.1035 - mae: 0.2049 - val_loss: 0.1899 - val_mae: 0.3276
#
# Epoch 00152: val_loss did not improve from 0.18559
# Epoch 153/10000
#  - 1s - loss: 0.1027 - mae: 0.2029 - val_loss: 0.1891 - val_mae: 0.3269
#
# Epoch 00153: val_loss did not improve from 0.18559
# Epoch 154/10000
#  - 1s - loss: 0.1059 - mae: 0.2114 - val_loss: 0.1914 - val_mae: 0.3267
#
# Epoch 00154: val_loss did not improve from 0.18559
# Epoch 155/10000
#  - 1s - loss: 0.1053 - mae: 0.2098 - val_loss: 0.1938 - val_mae: 0.3294
#
# Epoch 00155: val_loss did not improve from 0.18559
# Epoch 156/10000
#  - 1s - loss: 0.1037 - mae: 0.2062 - val_loss: 0.1942 - val_mae: 0.3333
#
# Epoch 00156: val_loss did not improve from 0.18559
# Epoch 157/10000
#  - 1s - loss: 0.1061 - mae: 0.2123 - val_loss: 0.1879 - val_mae: 0.3222
#
# Epoch 00157: val_loss did not improve from 0.18559
# Epoch 158/10000
#  - 1s - loss: 0.1060 - mae: 0.2133 - val_loss: 0.1891 - val_mae: 0.3306
#
# Epoch 00158: val_loss did not improve from 0.18559
# Epoch 159/10000
#  - 1s - loss: 0.1043 - mae: 0.2091 - val_loss: 0.1856 - val_mae: 0.3227
#
# Epoch 00159: val_loss did not improve from 0.18559
# Epoch 160/10000
#  - 1s - loss: 0.1064 - mae: 0.2102 - val_loss: 0.1894 - val_mae: 0.3243
#
# Epoch 00160: val_loss did not improve from 0.18559
# Epoch 161/10000
#  - 1s - loss: 0.1040 - mae: 0.2083 - val_loss: 0.1929 - val_mae: 0.3317
#
# Epoch 00161: val_loss did not improve from 0.18559
# Epoch 162/10000
#  - 1s - loss: 0.1047 - mae: 0.2118 - val_loss: 0.1899 - val_mae: 0.3271
#
# Epoch 00162: val_loss did not improve from 0.18559
# Epoch 163/10000
#  - 1s - loss: 0.1064 - mae: 0.2151 - val_loss: 0.1890 - val_mae: 0.3251
#
# Epoch 00163: val_loss did not improve from 0.18559
# Epoch 164/10000
#  - 1s - loss: 0.1062 - mae: 0.2120 - val_loss: 0.1857 - val_mae: 0.3230
#
# Epoch 00164: val_loss did not improve from 0.18559
# Epoch 165/10000
#  - 1s - loss: 0.1059 - mae: 0.2140 - val_loss: 0.1858 - val_mae: 0.3237
#
# Epoch 00165: val_loss did not improve from 0.18559
# Epoch 166/10000
#  - 1s - loss: 0.1057 - mae: 0.2131 - val_loss: 0.1921 - val_mae: 0.3315
#
# Epoch 00166: val_loss did not improve from 0.18559
# Epoch 167/10000
#  - 1s - loss: 0.1046 - mae: 0.2115 - val_loss: 0.1913 - val_mae: 0.3324
#
# Epoch 00167: val_loss did not improve from 0.18559
# Epoch 168/10000
#  - 1s - loss: 0.1048 - mae: 0.2121 - val_loss: 0.1864 - val_mae: 0.3266
#
# Epoch 00168: val_loss did not improve from 0.18559
# Epoch 169/10000
#  - 1s - loss: 0.1033 - mae: 0.2088 - val_loss: 0.1879 - val_mae: 0.3266
#
# Epoch 00169: val_loss did not improve from 0.18559
# Epoch 170/10000
#  - 1s - loss: 0.1047 - mae: 0.2098 - val_loss: 0.1870 - val_mae: 0.3253
#
# Epoch 00170: val_loss did not improve from 0.18559
# Epoch 171/10000
#  - 1s - loss: 0.1025 - mae: 0.2018 - val_loss: 0.1882 - val_mae: 0.3250
#
# Epoch 00171: val_loss did not improve from 0.18559
# Epoch 172/10000
#  - 1s - loss: 0.1036 - mae: 0.2083 - val_loss: 0.1887 - val_mae: 0.3287
#
# Epoch 00172: val_loss did not improve from 0.18559
# Epoch 173/10000
#  - 1s - loss: 0.1031 - mae: 0.2049 - val_loss: 0.1896 - val_mae: 0.3286
#
# Epoch 00173: val_loss did not improve from 0.18559
# Epoch 174/10000
#  - 1s - loss: 0.1023 - mae: 0.2045 - val_loss: 0.1876 - val_mae: 0.3260
#
# Epoch 00174: val_loss did not improve from 0.18559
# Epoch 175/10000
#  - 1s - loss: 0.1021 - mae: 0.2026 - val_loss: 0.1854 - val_mae: 0.3247
#
# Epoch 00175: val_loss improved from 0.18559 to 0.18541, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 176/10000
#  - 1s - loss: 0.1035 - mae: 0.2069 - val_loss: 0.1862 - val_mae: 0.3255
#
# Epoch 00176: val_loss did not improve from 0.18541
# Epoch 177/10000
#  - 1s - loss: 0.1034 - mae: 0.2036 - val_loss: 0.1868 - val_mae: 0.3239
#
# Epoch 00177: val_loss did not improve from 0.18541
# Epoch 178/10000
#  - 1s - loss: 0.1032 - mae: 0.2052 - val_loss: 0.1869 - val_mae: 0.3245
#
# Epoch 00178: val_loss did not improve from 0.18541
# Epoch 179/10000
#  - 1s - loss: 0.1036 - mae: 0.2072 - val_loss: 0.1876 - val_mae: 0.3272
#
# Epoch 00179: val_loss did not improve from 0.18541
# Epoch 180/10000
#  - 1s - loss: 0.1035 - mae: 0.2075 - val_loss: 0.1903 - val_mae: 0.3315
#
# Epoch 00180: val_loss did not improve from 0.18541
# Epoch 181/10000
#  - 1s - loss: 0.1021 - mae: 0.2019 - val_loss: 0.1896 - val_mae: 0.3286
#
# Epoch 00181: val_loss did not improve from 0.18541
# Epoch 182/10000
#  - 1s - loss: 0.1014 - mae: 0.2005 - val_loss: 0.1891 - val_mae: 0.3264
#
# Epoch 00182: val_loss did not improve from 0.18541
# Epoch 183/10000
#  - 1s - loss: 0.1032 - mae: 0.2049 - val_loss: 0.1876 - val_mae: 0.3274
#
# Epoch 00183: val_loss did not improve from 0.18541
# Epoch 184/10000
#  - 1s - loss: 0.1023 - mae: 0.2058 - val_loss: 0.1913 - val_mae: 0.3289
#
# Epoch 00184: val_loss did not improve from 0.18541
# Epoch 185/10000
#  - 1s - loss: 0.1031 - mae: 0.2080 - val_loss: 0.1945 - val_mae: 0.3320
#
# Epoch 00185: val_loss did not improve from 0.18541
# Epoch 186/10000
#  - 1s - loss: 0.1019 - mae: 0.2048 - val_loss: 0.1914 - val_mae: 0.3299
#
# Epoch 00186: val_loss did not improve from 0.18541
# Epoch 187/10000
#  - 1s - loss: 0.1016 - mae: 0.2030 - val_loss: 0.1849 - val_mae: 0.3280
#
# Epoch 00187: val_loss improved from 0.18541 to 0.18493, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 188/10000
#  - 1s - loss: 0.1020 - mae: 0.2031 - val_loss: 0.1849 - val_mae: 0.3250
#
# Epoch 00188: val_loss improved from 0.18493 to 0.18491, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 189/10000
#  - 1s - loss: 0.1021 - mae: 0.2033 - val_loss: 0.1878 - val_mae: 0.3293
#
# Epoch 00189: val_loss did not improve from 0.18491
# Epoch 190/10000
#  - 1s - loss: 0.1019 - mae: 0.2026 - val_loss: 0.1902 - val_mae: 0.3319
#
# Epoch 00190: val_loss did not improve from 0.18491
# Epoch 191/10000
#  - 1s - loss: 0.1018 - mae: 0.2050 - val_loss: 0.1872 - val_mae: 0.3236
#
# Epoch 00191: val_loss did not improve from 0.18491
# Epoch 192/10000
#  - 1s - loss: 0.1028 - mae: 0.2048 - val_loss: 0.1867 - val_mae: 0.3248
#
# Epoch 00192: val_loss did not improve from 0.18491
# Epoch 193/10000
#  - 1s - loss: 0.1023 - mae: 0.2061 - val_loss: 0.1873 - val_mae: 0.3278
#
# Epoch 00193: val_loss did not improve from 0.18491
# Epoch 194/10000
#  - 1s - loss: 0.1018 - mae: 0.2035 - val_loss: 0.1860 - val_mae: 0.3270
#
# Epoch 00194: val_loss did not improve from 0.18491
# Epoch 195/10000
#  - 1s - loss: 0.1016 - mae: 0.2061 - val_loss: 0.1840 - val_mae: 0.3245
#
# Epoch 00195: val_loss improved from 0.18491 to 0.18404, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 196/10000
#  - 1s - loss: 0.1028 - mae: 0.2093 - val_loss: 0.1899 - val_mae: 0.3301
#
# Epoch 00196: val_loss did not improve from 0.18404
# Epoch 197/10000
#  - 1s - loss: 0.1034 - mae: 0.2094 - val_loss: 0.1894 - val_mae: 0.3267
#
# Epoch 00197: val_loss did not improve from 0.18404
# Epoch 198/10000
#  - 1s - loss: 0.1024 - mae: 0.2067 - val_loss: 0.1826 - val_mae: 0.3218
#
# Epoch 00198: val_loss improved from 0.18404 to 0.18264, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 199/10000
#  - 1s - loss: 0.1027 - mae: 0.2058 - val_loss: 0.1831 - val_mae: 0.3189
#
# Epoch 00199: val_loss did not improve from 0.18264
# Epoch 200/10000
#  - 1s - loss: 0.1019 - mae: 0.2054 - val_loss: 0.1905 - val_mae: 0.3319
#
# Epoch 00200: val_loss did not improve from 0.18264
# Epoch 201/10000
#  - 1s - loss: 0.1012 - mae: 0.2019 - val_loss: 0.1834 - val_mae: 0.3233
#
# Epoch 00201: val_loss did not improve from 0.18264
# Epoch 202/10000
#  - 1s - loss: 0.1013 - mae: 0.2038 - val_loss: 0.1859 - val_mae: 0.3266
#
# Epoch 00202: val_loss did not improve from 0.18264
# Epoch 203/10000
#  - 1s - loss: 0.1008 - mae: 0.2022 - val_loss: 0.1917 - val_mae: 0.3320
#
# Epoch 00203: val_loss did not improve from 0.18264
# Epoch 204/10000
#  - 1s - loss: 0.1019 - mae: 0.2049 - val_loss: 0.1895 - val_mae: 0.3287
#
# Epoch 00204: val_loss did not improve from 0.18264
# Epoch 205/10000
#  - 1s - loss: 0.1026 - mae: 0.2047 - val_loss: 0.1898 - val_mae: 0.3294
#
# Epoch 00205: val_loss did not improve from 0.18264
# Epoch 206/10000
#  - 1s - loss: 0.1009 - mae: 0.2019 - val_loss: 0.1882 - val_mae: 0.3307
#
# Epoch 00206: val_loss did not improve from 0.18264
# Epoch 207/10000
#  - 1s - loss: 0.1019 - mae: 0.2049 - val_loss: 0.1906 - val_mae: 0.3299
#
# Epoch 00207: val_loss did not improve from 0.18264
# Epoch 208/10000
#  - 1s - loss: 0.0995 - mae: 0.1983 - val_loss: 0.1958 - val_mae: 0.3371
#
# Epoch 00208: val_loss did not improve from 0.18264
# Epoch 209/10000
#  - 1s - loss: 0.1013 - mae: 0.2013 - val_loss: 0.1887 - val_mae: 0.3285
#
# Epoch 00209: val_loss did not improve from 0.18264
# Epoch 210/10000
#  - 1s - loss: 0.1025 - mae: 0.2084 - val_loss: 0.1901 - val_mae: 0.3338
#
# Epoch 00210: val_loss did not improve from 0.18264
# Epoch 211/10000
#  - 1s - loss: 0.1029 - mae: 0.2081 - val_loss: 0.1841 - val_mae: 0.3241
#
# Epoch 00211: val_loss did not improve from 0.18264
# Epoch 212/10000
#  - 1s - loss: 0.1024 - mae: 0.2075 - val_loss: 0.1848 - val_mae: 0.3252
#
# Epoch 00212: val_loss did not improve from 0.18264
# Epoch 213/10000
#  - 1s - loss: 0.1015 - mae: 0.2052 - val_loss: 0.1841 - val_mae: 0.3203
#
# Epoch 00213: val_loss did not improve from 0.18264
# Epoch 214/10000
#  - 1s - loss: 0.1015 - mae: 0.2059 - val_loss: 0.1885 - val_mae: 0.3293
#
# Epoch 00214: val_loss did not improve from 0.18264
# Epoch 215/10000
#  - 1s - loss: 0.1018 - mae: 0.2034 - val_loss: 0.1906 - val_mae: 0.3303
#
# Epoch 00215: val_loss did not improve from 0.18264
# Epoch 216/10000
#  - 1s - loss: 0.1015 - mae: 0.2047 - val_loss: 0.1863 - val_mae: 0.3287
#
# Epoch 00216: val_loss did not improve from 0.18264
# Epoch 217/10000
#  - 1s - loss: 0.1009 - mae: 0.2042 - val_loss: 0.1893 - val_mae: 0.3290
#
# Epoch 00217: val_loss did not improve from 0.18264
# Epoch 218/10000
#  - 1s - loss: 0.1012 - mae: 0.2049 - val_loss: 0.1843 - val_mae: 0.3251
#
# Epoch 00218: val_loss did not improve from 0.18264
# Epoch 219/10000
#  - 1s - loss: 0.1021 - mae: 0.2054 - val_loss: 0.1888 - val_mae: 0.3286
#
# Epoch 00219: val_loss did not improve from 0.18264
# Epoch 220/10000
#  - 1s - loss: 0.1011 - mae: 0.2052 - val_loss: 0.1892 - val_mae: 0.3298
#
# Epoch 00220: val_loss did not improve from 0.18264
# Epoch 221/10000
#  - 1s - loss: 0.1012 - mae: 0.2040 - val_loss: 0.1897 - val_mae: 0.3295
#
# Epoch 00221: val_loss did not improve from 0.18264
# Epoch 222/10000
#  - 1s - loss: 0.1011 - mae: 0.2041 - val_loss: 0.1907 - val_mae: 0.3319
#
# Epoch 00222: val_loss did not improve from 0.18264
# Epoch 223/10000
#  - 1s - loss: 0.1017 - mae: 0.2053 - val_loss: 0.1827 - val_mae: 0.3228
#
# Epoch 00223: val_loss did not improve from 0.18264
# Epoch 224/10000
#  - 1s - loss: 0.1026 - mae: 0.2079 - val_loss: 0.1888 - val_mae: 0.3313
#
# Epoch 00224: val_loss did not improve from 0.18264
# Epoch 225/10000
#  - 1s - loss: 0.1009 - mae: 0.2043 - val_loss: 0.1886 - val_mae: 0.3308
#
# Epoch 00225: val_loss did not improve from 0.18264
# Epoch 226/10000
#  - 1s - loss: 0.1011 - mae: 0.2041 - val_loss: 0.1873 - val_mae: 0.3245
#
# Epoch 00226: val_loss did not improve from 0.18264
# Epoch 227/10000
#  - 1s - loss: 0.1007 - mae: 0.2031 - val_loss: 0.1933 - val_mae: 0.3307
#
# Epoch 00227: val_loss did not improve from 0.18264
# Epoch 228/10000
#  - 1s - loss: 0.1010 - mae: 0.2058 - val_loss: 0.1895 - val_mae: 0.3304
#
# Epoch 00228: val_loss did not improve from 0.18264
# Epoch 229/10000
#  - 1s - loss: 0.1010 - mae: 0.2067 - val_loss: 0.1886 - val_mae: 0.3336
#
# Epoch 00229: val_loss did not improve from 0.18264
# Epoch 230/10000
#  - 1s - loss: 0.1023 - mae: 0.2073 - val_loss: 0.1869 - val_mae: 0.3253
#
# Epoch 00230: val_loss did not improve from 0.18264
# Epoch 231/10000
#  - 1s - loss: 0.1024 - mae: 0.2091 - val_loss: 0.1850 - val_mae: 0.3290
#
# Epoch 00231: val_loss did not improve from 0.18264
# Epoch 232/10000
#  - 1s - loss: 0.1011 - mae: 0.2053 - val_loss: 0.1860 - val_mae: 0.3279
#
# Epoch 00232: val_loss did not improve from 0.18264
# Epoch 233/10000
#  - 1s - loss: 0.1004 - mae: 0.2042 - val_loss: 0.1925 - val_mae: 0.3337
#
# Epoch 00233: val_loss did not improve from 0.18264
# Epoch 234/10000
#  - 1s - loss: 0.1000 - mae: 0.2039 - val_loss: 0.1853 - val_mae: 0.3242
#
# Epoch 00234: val_loss did not improve from 0.18264
# Epoch 235/10000
#  - 1s - loss: 0.1002 - mae: 0.2022 - val_loss: 0.1868 - val_mae: 0.3277
#
# Epoch 00235: val_loss did not improve from 0.18264
# Epoch 236/10000
#  - 1s - loss: 0.1031 - mae: 0.2102 - val_loss: 0.1898 - val_mae: 0.3270
#
# Epoch 00236: val_loss did not improve from 0.18264
# Epoch 237/10000
#  - 1s - loss: 0.1036 - mae: 0.2115 - val_loss: 0.1927 - val_mae: 0.3332
#
# Epoch 00237: val_loss did not improve from 0.18264
# Epoch 238/10000
#  - 1s - loss: 0.1036 - mae: 0.2122 - val_loss: 0.1889 - val_mae: 0.3333
#
# Epoch 00238: val_loss did not improve from 0.18264
# Epoch 239/10000
#  - 1s - loss: 0.1014 - mae: 0.2086 - val_loss: 0.1901 - val_mae: 0.3296
#
# Epoch 00239: val_loss did not improve from 0.18264
# Epoch 240/10000
#  - 1s - loss: 0.1013 - mae: 0.2065 - val_loss: 0.1845 - val_mae: 0.3211
#
# Epoch 00240: val_loss did not improve from 0.18264
# Epoch 241/10000
#  - 1s - loss: 0.1016 - mae: 0.2078 - val_loss: 0.1918 - val_mae: 0.3348
#
# Epoch 00241: val_loss did not improve from 0.18264
# Epoch 242/10000
#  - 1s - loss: 0.1014 - mae: 0.2059 - val_loss: 0.1852 - val_mae: 0.3286
#
# Epoch 00242: val_loss did not improve from 0.18264
# Epoch 243/10000
#  - 1s - loss: 0.1022 - mae: 0.2104 - val_loss: 0.1921 - val_mae: 0.3354
#
# Epoch 00243: val_loss did not improve from 0.18264
# Epoch 244/10000
#  - 1s - loss: 0.1004 - mae: 0.2041 - val_loss: 0.1845 - val_mae: 0.3229
#
# Epoch 00244: val_loss did not improve from 0.18264
# Epoch 245/10000
#  - 1s - loss: 0.1050 - mae: 0.2189 - val_loss: 0.1912 - val_mae: 0.3350
#
# Epoch 00245: val_loss did not improve from 0.18264
# Epoch 246/10000
#  - 1s - loss: 0.1043 - mae: 0.2149 - val_loss: 0.1859 - val_mae: 0.3265
#
# Epoch 00246: val_loss did not improve from 0.18264
# Epoch 247/10000
#  - 1s - loss: 0.1034 - mae: 0.2144 - val_loss: 0.1810 - val_mae: 0.3205
#
# Epoch 00247: val_loss improved from 0.18264 to 0.18100, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 248/10000
#  - 1s - loss: 0.1051 - mae: 0.2139 - val_loss: 0.1808 - val_mae: 0.3270
#
# Epoch 00248: val_loss improved from 0.18100 to 0.18079, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 249/10000
#  - 1s - loss: 0.1056 - mae: 0.2183 - val_loss: 0.1840 - val_mae: 0.3259
#
# Epoch 00249: val_loss did not improve from 0.18079
# Epoch 250/10000
#  - 1s - loss: 0.1021 - mae: 0.2115 - val_loss: 0.1854 - val_mae: 0.3264
#
# Epoch 00250: val_loss did not improve from 0.18079
# Epoch 251/10000
#  - 1s - loss: 0.1034 - mae: 0.2143 - val_loss: 0.1831 - val_mae: 0.3312
#
# Epoch 00251: val_loss did not improve from 0.18079
# Epoch 252/10000
#  - 1s - loss: 0.1057 - mae: 0.2223 - val_loss: 0.1874 - val_mae: 0.3297
#
# Epoch 00252: val_loss did not improve from 0.18079
# Epoch 253/10000
#  - 1s - loss: 0.1062 - mae: 0.2198 - val_loss: 0.1927 - val_mae: 0.3370
#
# Epoch 00253: val_loss did not improve from 0.18079
# Epoch 254/10000
#  - 1s - loss: 0.1033 - mae: 0.2135 - val_loss: 0.1848 - val_mae: 0.3217
#
# Epoch 00254: val_loss did not improve from 0.18079
# Epoch 255/10000
#  - 1s - loss: 0.1025 - mae: 0.2102 - val_loss: 0.1832 - val_mae: 0.3245
#
# Epoch 00255: val_loss did not improve from 0.18079
# Epoch 256/10000
#  - 1s - loss: 0.1026 - mae: 0.2110 - val_loss: 0.1900 - val_mae: 0.3322
#
# Epoch 00256: val_loss did not improve from 0.18079
# Epoch 257/10000
#  - 1s - loss: 0.1037 - mae: 0.2128 - val_loss: 0.1922 - val_mae: 0.3291
#
# Epoch 00257: val_loss did not improve from 0.18079
# Epoch 258/10000
#  - 1s - loss: 0.1036 - mae: 0.2137 - val_loss: 0.1914 - val_mae: 0.3314
#
# Epoch 00258: val_loss did not improve from 0.18079
# Epoch 259/10000
#  - 1s - loss: 0.1027 - mae: 0.2114 - val_loss: 0.1847 - val_mae: 0.3268
#
# Epoch 00259: val_loss did not improve from 0.18079
# Epoch 260/10000
#  - 1s - loss: 0.1057 - mae: 0.2182 - val_loss: 0.1886 - val_mae: 0.3304
#
# Epoch 00260: val_loss did not improve from 0.18079
# Epoch 261/10000
#  - 1s - loss: 0.1048 - mae: 0.2161 - val_loss: 0.1923 - val_mae: 0.3327
#
# Epoch 00261: val_loss did not improve from 0.18079
# Epoch 262/10000
#  - 1s - loss: 0.1025 - mae: 0.2083 - val_loss: 0.1905 - val_mae: 0.3321
#
# Epoch 00262: val_loss did not improve from 0.18079
# Epoch 263/10000
#  - 1s - loss: 0.1035 - mae: 0.2133 - val_loss: 0.1850 - val_mae: 0.3213
#
# Epoch 00263: val_loss did not improve from 0.18079
# Epoch 264/10000
#  - 1s - loss: 0.1050 - mae: 0.2170 - val_loss: 0.1819 - val_mae: 0.3261
#
# Epoch 00264: val_loss did not improve from 0.18079
# Epoch 265/10000
#  - 1s - loss: 0.1056 - mae: 0.2187 - val_loss: 0.1906 - val_mae: 0.3322
#
# Epoch 00265: val_loss did not improve from 0.18079
# Epoch 266/10000
#  - 1s - loss: 0.1051 - mae: 0.2178 - val_loss: 0.1823 - val_mae: 0.3218
#
# Epoch 00266: val_loss did not improve from 0.18079
# Epoch 267/10000
#  - 1s - loss: 0.1086 - mae: 0.2237 - val_loss: 0.1888 - val_mae: 0.3373
#
# Epoch 00267: val_loss did not improve from 0.18079
# Epoch 268/10000
#  - 1s - loss: 0.1135 - mae: 0.2375 - val_loss: 0.1815 - val_mae: 0.3164
#
# Epoch 00268: val_loss did not improve from 0.18079
# Epoch 269/10000
#  - 1s - loss: 0.1134 - mae: 0.2344 - val_loss: 0.1898 - val_mae: 0.3325
#
# Epoch 00269: val_loss did not improve from 0.18079
# Epoch 270/10000
#  - 1s - loss: 0.1056 - mae: 0.2213 - val_loss: 0.1956 - val_mae: 0.3312
#
# Epoch 00270: val_loss did not improve from 0.18079
# Epoch 271/10000
#  - 1s - loss: 0.1072 - mae: 0.2189 - val_loss: 0.1870 - val_mae: 0.3326
#
# Epoch 00271: val_loss did not improve from 0.18079
# Epoch 272/10000
#  - 1s - loss: 0.1065 - mae: 0.2210 - val_loss: 0.1816 - val_mae: 0.3256
#
# Epoch 00272: val_loss did not improve from 0.18079
# Epoch 273/10000
#  - 1s - loss: 0.1035 - mae: 0.2126 - val_loss: 0.1840 - val_mae: 0.3252
#
# Epoch 00273: val_loss did not improve from 0.18079
# Epoch 274/10000
#  - 1s - loss: 0.1037 - mae: 0.2121 - val_loss: 0.1774 - val_mae: 0.3198
#
# Epoch 00274: val_loss improved from 0.18079 to 0.17744, saving model to ../../../../../data/seq_weights_lr_sched_2.h5
# Epoch 275/10000
#  - 1s - loss: 0.1039 - mae: 0.2120 - val_loss: 0.1865 - val_mae: 0.3245
#
# Epoch 00275: val_loss did not improve from 0.17744
# Epoch 276/10000
#  - 1s - loss: 0.1034 - mae: 0.2124 - val_loss: 0.1846 - val_mae: 0.3275
#
# Epoch 00276: val_loss did not improve from 0.17744
# Epoch 277/10000
#  - 1s - loss: 0.1035 - mae: 0.2143 - val_loss: 0.1844 - val_mae: 0.3250
#
# Epoch 00277: val_loss did not improve from 0.17744
# Epoch 278/10000
#  - 1s - loss: 0.1044 - mae: 0.2122 - val_loss: 0.1861 - val_mae: 0.3241
#
# Epoch 00278: val_loss did not improve from 0.17744
# Epoch 279/10000
#  - 1s - loss: 0.1033 - mae: 0.2111 - val_loss: 0.1873 - val_mae: 0.3314
#
# Epoch 00279: val_loss did not improve from 0.17744
# Epoch 280/10000
#  - 1s - loss: 0.1038 - mae: 0.2130 - val_loss: 0.1821 - val_mae: 0.3246
#
# Epoch 00280: val_loss did not improve from 0.17744
# Epoch 281/10000
#  - 1s - loss: 0.1030 - mae: 0.2125 - val_loss: 0.1886 - val_mae: 0.3321
#
# Epoch 00281: val_loss did not improve from 0.17744
# Epoch 282/10000
#  - 1s - loss: 0.1008 - mae: 0.2040 - val_loss: 0.1862 - val_mae: 0.3273
#
# Epoch 00282: val_loss did not improve from 0.17744
# Epoch 283/10000
#  - 1s - loss: 0.1011 - mae: 0.2045 - val_loss: 0.1843 - val_mae: 0.3259
#
# Epoch 00283: val_loss did not improve from 0.17744
# Epoch 284/10000
#  - 1s - loss: 0.0997 - mae: 0.2010 - val_loss: 0.1880 - val_mae: 0.3303
#
# Epoch 00284: val_loss did not improve from 0.17744
# Epoch 285/10000
#  - 1s - loss: 0.1012 - mae: 0.2057 - val_loss: 0.1878 - val_mae: 0.3292
#
# Epoch 00285: val_loss did not improve from 0.17744
# Epoch 286/10000
#  - 1s - loss: 0.1003 - mae: 0.2018 - val_loss: 0.1828 - val_mae: 0.3244
#
# Epoch 00286: val_loss did not improve from 0.17744
# Epoch 287/10000
#  - 1s - loss: 0.1003 - mae: 0.2028 - val_loss: 0.1818 - val_mae: 0.3233
#
# Epoch 00287: val_loss did not improve from 0.17744
# Epoch 288/10000
#  - 1s - loss: 0.1013 - mae: 0.2073 - val_loss: 0.1924 - val_mae: 0.3345
#
# Epoch 00288: val_loss did not improve from 0.17744
# Epoch 289/10000
#  - 1s - loss: 0.1009 - mae: 0.2043 - val_loss: 0.1913 - val_mae: 0.3317
#
# Epoch 00289: val_loss did not improve from 0.17744
# Epoch 290/10000
#  - 1s - loss: 0.1008 - mae: 0.2054 - val_loss: 0.1847 - val_mae: 0.3245
#
# Epoch 00290: val_loss did not improve from 0.17744
# Epoch 291/10000
#  - 1s - loss: 0.1006 - mae: 0.2034 - val_loss: 0.1936 - val_mae: 0.3385
#
# Epoch 00291: val_loss did not improve from 0.17744
# Epoch 292/10000
#  - 1s - loss: 0.1018 - mae: 0.2071 - val_loss: 0.1832 - val_mae: 0.3251
#
# Epoch 00292: val_loss did not improve from 0.17744
# Epoch 293/10000
#  - 1s - loss: 0.1000 - mae: 0.2013 - val_loss: 0.1845 - val_mae: 0.3249
#
# Epoch 00293: val_loss did not improve from 0.17744
# Epoch 294/10000
#  - 1s - loss: 0.1018 - mae: 0.2076 - val_loss: 0.1901 - val_mae: 0.3335
#
# Epoch 00294: val_loss did not improve from 0.17744
# Epoch 295/10000
#  - 1s - loss: 0.0998 - mae: 0.2003 - val_loss: 0.1904 - val_mae: 0.3316
#
# Epoch 00295: val_loss did not improve from 0.17744
# Epoch 296/10000
#  - 1s - loss: 0.0999 - mae: 0.2003 - val_loss: 0.1880 - val_mae: 0.3286
#
# Epoch 00296: val_loss did not improve from 0.17744
# Epoch 297/10000
#  - 1s - loss: 0.0999 - mae: 0.2026 - val_loss: 0.1853 - val_mae: 0.3284
#
# Epoch 00297: val_loss did not improve from 0.17744
# Epoch 298/10000
#  - 1s - loss: 0.0996 - mae: 0.2009 - val_loss: 0.1866 - val_mae: 0.3288
#
# Epoch 00298: val_loss did not improve from 0.17744
# Epoch 299/10000
#  - 1s - loss: 0.0994 - mae: 0.2021 - val_loss: 0.1866 - val_mae: 0.3308
#
# Epoch 00299: val_loss did not improve from 0.17744
# Epoch 300/10000
#  - 1s - loss: 0.0998 - mae: 0.2015 - val_loss: 0.1860 - val_mae: 0.3306
#
# Epoch 00300: val_loss did not improve from 0.17744
# Epoch 301/10000
#  - 1s - loss: 0.0997 - mae: 0.2031 - val_loss: 0.1885 - val_mae: 0.3311
#
# Epoch 00301: val_loss did not improve from 0.17744
# Epoch 302/10000
#  - 1s - loss: 0.0999 - mae: 0.2063 - val_loss: 0.1921 - val_mae: 0.3358
#
# Epoch 00302: val_loss did not improve from 0.17744
# Epoch 303/10000
#  - 1s - loss: 0.1006 - mae: 0.2049 - val_loss: 0.1888 - val_mae: 0.3338
#
# Epoch 00303: val_loss did not improve from 0.17744
# Epoch 304/10000
#  - 1s - loss: 0.1007 - mae: 0.2061 - val_loss: 0.1893 - val_mae: 0.3322
#
# Epoch 00304: val_loss did not improve from 0.17744
# Epoch 305/10000
#  - 1s - loss: 0.1003 - mae: 0.2035 - val_loss: 0.1878 - val_mae: 0.3275
#
# Epoch 00305: val_loss did not improve from 0.17744
# Epoch 306/10000
#  - 1s - loss: 0.0989 - mae: 0.2002 - val_loss: 0.1842 - val_mae: 0.3255
#
# Epoch 00306: val_loss did not improve from 0.17744
# Epoch 307/10000
#  - 1s - loss: 0.0993 - mae: 0.2007 - val_loss: 0.1915 - val_mae: 0.3324
#
# Epoch 00307: val_loss did not improve from 0.17744
# Epoch 308/10000
#  - 1s - loss: 0.0995 - mae: 0.2017 - val_loss: 0.1897 - val_mae: 0.3327
#
# Epoch 00308: val_loss did not improve from 0.17744
# Epoch 309/10000
#  - 1s - loss: 0.0986 - mae: 0.1988 - val_loss: 0.1844 - val_mae: 0.3282
#
# Epoch 00309: val_loss did not improve from 0.17744
# Epoch 310/10000
#  - 1s - loss: 0.0979 - mae: 0.1969 - val_loss: 0.1841 - val_mae: 0.3266
#
# Epoch 00310: val_loss did not improve from 0.17744
# Epoch 311/10000
#  - 1s - loss: 0.0980 - mae: 0.1983 - val_loss: 0.1850 - val_mae: 0.3282
#
# Epoch 00311: val_loss did not improve from 0.17744
# Epoch 312/10000
#  - 1s - loss: 0.0984 - mae: 0.1999 - val_loss: 0.1822 - val_mae: 0.3246
#
# Epoch 00312: val_loss did not improve from 0.17744
# Epoch 313/10000
#  - 1s - loss: 0.0999 - mae: 0.2029 - val_loss: 0.1883 - val_mae: 0.3315
#
# Epoch 00313: val_loss did not improve from 0.17744
# Epoch 314/10000
#  - 1s - loss: 0.0987 - mae: 0.1999 - val_loss: 0.1896 - val_mae: 0.3339
#
# Epoch 00314: val_loss did not improve from 0.17744
# Epoch 315/10000
#  - 1s - loss: 0.0985 - mae: 0.1995 - val_loss: 0.1998 - val_mae: 0.3397
#
# Epoch 00315: val_loss did not improve from 0.17744
# Epoch 316/10000
#  - 1s - loss: 0.0986 - mae: 0.2000 - val_loss: 0.1884 - val_mae: 0.3296
#
# Epoch 00316: val_loss did not improve from 0.17744
# Epoch 317/10000
#  - 1s - loss: 0.0991 - mae: 0.1998 - val_loss: 0.1972 - val_mae: 0.3426
#
# Epoch 00317: val_loss did not improve from 0.17744
# Epoch 318/10000
#  - 1s - loss: 0.0998 - mae: 0.2027 - val_loss: 0.1848 - val_mae: 0.3292
#
# Epoch 00318: val_loss did not improve from 0.17744
# Epoch 319/10000
#  - 1s - loss: 0.0982 - mae: 0.1991 - val_loss: 0.1946 - val_mae: 0.3348
#
# Epoch 00319: val_loss did not improve from 0.17744
# Epoch 320/10000
#  - 1s - loss: 0.0988 - mae: 0.1997 - val_loss: 0.1913 - val_mae: 0.3297
#
# Epoch 00320: val_loss did not improve from 0.17744
# Epoch 321/10000
#  - 1s - loss: 0.0987 - mae: 0.2009 - val_loss: 0.1812 - val_mae: 0.3219
#
# Epoch 00321: val_loss did not improve from 0.17744
# Epoch 322/10000
#  - 1s - loss: 0.0986 - mae: 0.2015 - val_loss: 0.1859 - val_mae: 0.3234
#
# Epoch 00322: val_loss did not improve from 0.17744
# Epoch 323/10000
#  - 1s - loss: 0.0983 - mae: 0.1989 - val_loss: 0.1843 - val_mae: 0.3290
#
# Epoch 00323: val_loss did not improve from 0.17744
# Epoch 324/10000
#  - 1s - loss: 0.0970 - mae: 0.1950 - val_loss: 0.1859 - val_mae: 0.3291
#
# Epoch 00324: val_loss did not improve from 0.17744
# Epoch 325/10000
#  - 1s - loss: 0.0975 - mae: 0.1954 - val_loss: 0.1865 - val_mae: 0.3270
#
# Epoch 00325: val_loss did not improve from 0.17744
# Epoch 326/10000
#  - 1s - loss: 0.1002 - mae: 0.2068 - val_loss: 0.1897 - val_mae: 0.3309
#
# Epoch 00326: val_loss did not improve from 0.17744
# Epoch 327/10000
#  - 1s - loss: 0.0994 - mae: 0.2031 - val_loss: 0.1860 - val_mae: 0.3261
#
# Epoch 00327: val_loss did not improve from 0.17744
# Epoch 328/10000
#  - 1s - loss: 0.0977 - mae: 0.1987 - val_loss: 0.1846 - val_mae: 0.3268
#
# Epoch 00328: val_loss did not improve from 0.17744
# Epoch 329/10000
#  - 1s - loss: 0.0982 - mae: 0.2002 - val_loss: 0.1920 - val_mae: 0.3380
#
# Epoch 00329: val_loss did not improve from 0.17744
# Epoch 330/10000
#  - 1s - loss: 0.0974 - mae: 0.1969 - val_loss: 0.1885 - val_mae: 0.3303
#
# Epoch 00330: val_loss did not improve from 0.17744
# Epoch 331/10000
#  - 1s - loss: 0.0989 - mae: 0.1994 - val_loss: 0.1896 - val_mae: 0.3332
#
# Epoch 00331: val_loss did not improve from 0.17744
# Epoch 332/10000
# ...
#
# Epoch 09887: val_loss did not improve from 0.17046
# Epoch 9888/10000
#  - 1s - loss: 0.0940 - mae: 0.1944 - val_loss: 0.1836 - val_mae: 0.3275
#
# Epoch 09888: val_loss did not improve from 0.17046
# Epoch 9889/10000
#  - 1s - loss: 0.0968 - mae: 0.1998 - val_loss: 0.1851 - val_mae: 0.3306
#
# Epoch 09889: val_loss did not improve from 0.17046
# Epoch 9890/10000
#  - 1s - loss: 0.0942 - mae: 0.1957 - val_loss: 0.1792 - val_mae: 0.3234
#
# Epoch 09890: val_loss did not improve from 0.17046
# Epoch 9891/10000
#  - 1s - loss: 0.0951 - mae: 0.1964 - val_loss: 0.1817 - val_mae: 0.3265
#
# Epoch 09891: val_loss did not improve from 0.17046
# Epoch 9892/10000
#  - 1s - loss: 0.0946 - mae: 0.1946 - val_loss: 0.1802 - val_mae: 0.3243
#
# Epoch 09892: val_loss did not improve from 0.17046
# Epoch 9893/10000
#  - 1s - loss: 0.0929 - mae: 0.1906 - val_loss: 0.1804 - val_mae: 0.3257
#
# Epoch 09893: val_loss did not improve from 0.17046
# Epoch 9894/10000
#  - 1s - loss: 0.0933 - mae: 0.1931 - val_loss: 0.1822 - val_mae: 0.3270
#
# Epoch 09894: val_loss did not improve from 0.17046
# Epoch 9895/10000
#  - 1s - loss: 0.0930 - mae: 0.1890 - val_loss: 0.1827 - val_mae: 0.3265
#
# Epoch 09895: val_loss did not improve from 0.17046
# Epoch 9896/10000
#  - 1s - loss: 0.0940 - mae: 0.1929 - val_loss: 0.1820 - val_mae: 0.3267
#
# Epoch 09896: val_loss did not improve from 0.17046
# Epoch 9897/10000
#  - 1s - loss: 0.0948 - mae: 0.1939 - val_loss: 0.1840 - val_mae: 0.3322
#
# Epoch 09897: val_loss did not improve from 0.17046
# Epoch 9898/10000
#  - 1s - loss: 0.0938 - mae: 0.1931 - val_loss: 0.1829 - val_mae: 0.3319
#
# Epoch 09898: val_loss did not improve from 0.17046
# Epoch 9899/10000
#  - 1s - loss: 0.0931 - mae: 0.1912 - val_loss: 0.1828 - val_mae: 0.3283
#
# Epoch 09899: val_loss did not improve from 0.17046
# Epoch 9900/10000
#  - 1s - loss: 0.0949 - mae: 0.1953 - val_loss: 0.1822 - val_mae: 0.3266
#
# Epoch 09900: val_loss did not improve from 0.17046
# Epoch 9901/10000
#  - 1s - loss: 0.0958 - mae: 0.1968 - val_loss: 0.1818 - val_mae: 0.3249
#
# Epoch 09901: val_loss did not improve from 0.17046
# Epoch 9902/10000
#  - 1s - loss: 0.0934 - mae: 0.1910 - val_loss: 0.1847 - val_mae: 0.3298
#
# Epoch 09902: val_loss did not improve from 0.17046
# Epoch 9903/10000
#  - 1s - loss: 0.0945 - mae: 0.1939 - val_loss: 0.1817 - val_mae: 0.3256
#
# Epoch 09903: val_loss did not improve from 0.17046
# Epoch 9904/10000
#  - 1s - loss: 0.0938 - mae: 0.1927 - val_loss: 0.1808 - val_mae: 0.3261
#
# Epoch 09904: val_loss did not improve from 0.17046
# Epoch 9905/10000
#  - 1s - loss: 0.0944 - mae: 0.1951 - val_loss: 0.1837 - val_mae: 0.3287
#
# Epoch 09905: val_loss did not improve from 0.17046
# Epoch 9906/10000
#  - 1s - loss: 0.0938 - mae: 0.1934 - val_loss: 0.1846 - val_mae: 0.3287
#
# Epoch 09906: val_loss did not improve from 0.17046
# Epoch 9907/10000
#  - 1s - loss: 0.0952 - mae: 0.1952 - val_loss: 0.1835 - val_mae: 0.3279
#
# Epoch 09907: val_loss did not improve from 0.17046
# Epoch 9908/10000
#  - 1s - loss: 0.0972 - mae: 0.2013 - val_loss: 0.1833 - val_mae: 0.3279
#
# Epoch 09908: val_loss did not improve from 0.17046
# Epoch 9909/10000
#  - 1s - loss: 0.0977 - mae: 0.1998 - val_loss: 0.1816 - val_mae: 0.3268
#
# Epoch 09909: val_loss did not improve from 0.17046
# Epoch 9910/10000
#  - 1s - loss: 0.0965 - mae: 0.2009 - val_loss: 0.1797 - val_mae: 0.3254
#
# Epoch 09910: val_loss did not improve from 0.17046
# Epoch 9911/10000
#  - 1s - loss: 0.0945 - mae: 0.1956 - val_loss: 0.1839 - val_mae: 0.3279
#
# Epoch 09911: val_loss did not improve from 0.17046
# Epoch 9912/10000
#  - 1s - loss: 0.0955 - mae: 0.1965 - val_loss: 0.1823 - val_mae: 0.3271
#
# Epoch 09912: val_loss did not improve from 0.17046
# Epoch 9913/10000
#  - 1s - loss: 0.0951 - mae: 0.1976 - val_loss: 0.1868 - val_mae: 0.3323
#
# Epoch 09913: val_loss did not improve from 0.17046
# Epoch 9914/10000
#  - 1s - loss: 0.0946 - mae: 0.1978 - val_loss: 0.1837 - val_mae: 0.3295
#
# Epoch 09914: val_loss did not improve from 0.17046
# Epoch 9915/10000
#  - 1s - loss: 0.0963 - mae: 0.2012 - val_loss: 0.1835 - val_mae: 0.3283
#
# Epoch 09915: val_loss did not improve from 0.17046
# Epoch 9916/10000
#  - 1s - loss: 0.0951 - mae: 0.1966 - val_loss: 0.1838 - val_mae: 0.3278
#
# Epoch 09916: val_loss did not improve from 0.17046
# Epoch 9917/10000
#  - 1s - loss: 0.0981 - mae: 0.2018 - val_loss: 0.1798 - val_mae: 0.3227
#
# Epoch 09917: val_loss did not improve from 0.17046
# Epoch 9918/10000
#  - 1s - loss: 0.0951 - mae: 0.1986 - val_loss: 0.1831 - val_mae: 0.3266
#
# Epoch 09918: val_loss did not improve from 0.17046
# Epoch 9919/10000
#  - 1s - loss: 0.0966 - mae: 0.2002 - val_loss: 0.1803 - val_mae: 0.3258
#
# Epoch 09919: val_loss did not improve from 0.17046
# Epoch 9920/10000
#  - 1s - loss: 0.0970 - mae: 0.2027 - val_loss: 0.1795 - val_mae: 0.3228
#
# Epoch 09920: val_loss did not improve from 0.17046
# Epoch 9921/10000
#  - 1s - loss: 0.0957 - mae: 0.2013 - val_loss: 0.1842 - val_mae: 0.3303
#
# Epoch 09921: val_loss did not improve from 0.17046
# Epoch 9922/10000
#  - 1s - loss: 0.0944 - mae: 0.1967 - val_loss: 0.1866 - val_mae: 0.3314
#
# Epoch 09922: val_loss did not improve from 0.17046
# Epoch 9923/10000
#  - 1s - loss: 0.0942 - mae: 0.1964 - val_loss: 0.1805 - val_mae: 0.3235
#
# Epoch 09923: val_loss did not improve from 0.17046
# Epoch 9924/10000
#  - 1s - loss: 0.0982 - mae: 0.2042 - val_loss: 0.1901 - val_mae: 0.3358
#
# Epoch 09924: val_loss did not improve from 0.17046
# Epoch 9925/10000
#  - 1s - loss: 0.0992 - mae: 0.2046 - val_loss: 0.1904 - val_mae: 0.3345
#
# Epoch 09925: val_loss did not improve from 0.17046
# Epoch 9926/10000
#  - 1s - loss: 0.0965 - mae: 0.2026 - val_loss: 0.1874 - val_mae: 0.3335
#
# Epoch 09926: val_loss did not improve from 0.17046
# Epoch 9927/10000
#  - 1s - loss: 0.0957 - mae: 0.1995 - val_loss: 0.1887 - val_mae: 0.3361
#
# Epoch 09927: val_loss did not improve from 0.17046
# Epoch 9928/10000
#  - 1s - loss: 0.0974 - mae: 0.2019 - val_loss: 0.1825 - val_mae: 0.3248
#
# Epoch 09928: val_loss did not improve from 0.17046
# Epoch 9929/10000
#  - 1s - loss: 0.0972 - mae: 0.1995 - val_loss: 0.1840 - val_mae: 0.3287
#
# Epoch 09929: val_loss did not improve from 0.17046
# Epoch 9930/10000
#  - 1s - loss: 0.0955 - mae: 0.1989 - val_loss: 0.1885 - val_mae: 0.3338
#
# Epoch 09930: val_loss did not improve from 0.17046
# Epoch 9931/10000
#  - 1s - loss: 0.0953 - mae: 0.1971 - val_loss: 0.1838 - val_mae: 0.3291
#
# Epoch 09931: val_loss did not improve from 0.17046
# Epoch 9932/10000
#  - 1s - loss: 0.0999 - mae: 0.2069 - val_loss: 0.1816 - val_mae: 0.3278
#
# Epoch 09932: val_loss did not improve from 0.17046
# Epoch 9933/10000
#  - 1s - loss: 0.0952 - mae: 0.1999 - val_loss: 0.1880 - val_mae: 0.3358
#
# Epoch 09933: val_loss did not improve from 0.17046
# Epoch 9934/10000
#  - 1s - loss: 0.0950 - mae: 0.1975 - val_loss: 0.1860 - val_mae: 0.3321
#
# Epoch 09934: val_loss did not improve from 0.17046
# Epoch 9935/10000
#  - 1s - loss: 0.0952 - mae: 0.1948 - val_loss: 0.1848 - val_mae: 0.3298
#
# Epoch 09935: val_loss did not improve from 0.17046
# Epoch 9936/10000
#  - 1s - loss: 0.0959 - mae: 0.1971 - val_loss: 0.1833 - val_mae: 0.3304
#
# Epoch 09936: val_loss did not improve from 0.17046
# Epoch 9937/10000
#  - 1s - loss: 0.0971 - mae: 0.2008 - val_loss: 0.1819 - val_mae: 0.3275
#
# Epoch 09937: val_loss did not improve from 0.17046
# Epoch 9938/10000
#  - 1s - loss: 0.0975 - mae: 0.2031 - val_loss: 0.1854 - val_mae: 0.3323
#
# Epoch 09938: val_loss did not improve from 0.17046
# Epoch 9939/10000
#  - 1s - loss: 0.0955 - mae: 0.1978 - val_loss: 0.1820 - val_mae: 0.3253
#
# Epoch 09939: val_loss did not improve from 0.17046
# Epoch 9940/10000
#  - 1s - loss: 0.0951 - mae: 0.1973 - val_loss: 0.1866 - val_mae: 0.3319
#
# Epoch 09940: val_loss did not improve from 0.17046
# Epoch 9941/10000
#  - 1s - loss: 0.0953 - mae: 0.1971 - val_loss: 0.1832 - val_mae: 0.3260
#
# Epoch 09941: val_loss did not improve from 0.17046
# Epoch 9942/10000
#  - 1s - loss: 0.0957 - mae: 0.1982 - val_loss: 0.1878 - val_mae: 0.3334
#
# Epoch 09942: val_loss did not improve from 0.17046
# Epoch 9943/10000
#  - 1s - loss: 0.0951 - mae: 0.1942 - val_loss: 0.1833 - val_mae: 0.3285
#
# Epoch 09943: val_loss did not improve from 0.17046
# Epoch 9944/10000
#  - 1s - loss: 0.0947 - mae: 0.1948 - val_loss: 0.1862 - val_mae: 0.3323
#
# Epoch 09944: val_loss did not improve from 0.17046
# Epoch 9945/10000
#  - 1s - loss: 0.0971 - mae: 0.2004 - val_loss: 0.1850 - val_mae: 0.3317
#
# Epoch 09945: val_loss did not improve from 0.17046
# Epoch 9946/10000
#  - 1s - loss: 0.0948 - mae: 0.1972 - val_loss: 0.1842 - val_mae: 0.3280
#
# Epoch 09946: val_loss did not improve from 0.17046
# Epoch 9947/10000
#  - 1s - loss: 0.0953 - mae: 0.1975 - val_loss: 0.1821 - val_mae: 0.3282
#
# Epoch 09947: val_loss did not improve from 0.17046
# Epoch 9948/10000
#  - 1s - loss: 0.0970 - mae: 0.2010 - val_loss: 0.1884 - val_mae: 0.3341
#
# Epoch 09948: val_loss did not improve from 0.17046
# Epoch 9949/10000
#  - 1s - loss: 0.0982 - mae: 0.2017 - val_loss: 0.1808 - val_mae: 0.3246
#
# Epoch 09949: val_loss did not improve from 0.17046
# Epoch 9950/10000
#  - 1s - loss: 0.0966 - mae: 0.1992 - val_loss: 0.1841 - val_mae: 0.3289
#
# Epoch 09950: val_loss did not improve from 0.17046
# Epoch 9951/10000
#  - 1s - loss: 0.0963 - mae: 0.1998 - val_loss: 0.1854 - val_mae: 0.3307
#
# Epoch 09951: val_loss did not improve from 0.17046
# Epoch 9952/10000
#  - 1s - loss: 0.0967 - mae: 0.2016 - val_loss: 0.1850 - val_mae: 0.3297
#
# Epoch 09952: val_loss did not improve from 0.17046
# Epoch 9953/10000
#  - 1s - loss: 0.0956 - mae: 0.1981 - val_loss: 0.1878 - val_mae: 0.3339
#
# Epoch 09953: val_loss did not improve from 0.17046
# Epoch 9954/10000
#  - 1s - loss: 0.0969 - mae: 0.2020 - val_loss: 0.1865 - val_mae: 0.3323
#
# Epoch 09954: val_loss did not improve from 0.17046
# Epoch 9955/10000
#  - 1s - loss: 0.0953 - mae: 0.1990 - val_loss: 0.1867 - val_mae: 0.3332
#
# Epoch 09955: val_loss did not improve from 0.17046
# Epoch 9956/10000
#  - 1s - loss: 0.0968 - mae: 0.2002 - val_loss: 0.1919 - val_mae: 0.3361
#
# Epoch 09956: val_loss did not improve from 0.17046
# Epoch 9957/10000
#  - 1s - loss: 0.0967 - mae: 0.1967 - val_loss: 0.1885 - val_mae: 0.3329
#
# Epoch 09957: val_loss did not improve from 0.17046
# Epoch 9958/10000
#  - 1s - loss: 0.0969 - mae: 0.2034 - val_loss: 0.1824 - val_mae: 0.3260
#
# Epoch 09958: val_loss did not improve from 0.17046
# Epoch 9959/10000
#  - 1s - loss: 0.0950 - mae: 0.1977 - val_loss: 0.1924 - val_mae: 0.3377
#
# Epoch 09959: val_loss did not improve from 0.17046
# Epoch 9960/10000
#  - 1s - loss: 0.0958 - mae: 0.1972 - val_loss: 0.1851 - val_mae: 0.3301
#
# Epoch 09960: val_loss did not improve from 0.17046
# Epoch 9961/10000
#  - 1s - loss: 0.0958 - mae: 0.1968 - val_loss: 0.1835 - val_mae: 0.3282
#
# Epoch 09961: val_loss did not improve from 0.17046
# Epoch 9962/10000
#  - 1s - loss: 0.0964 - mae: 0.1960 - val_loss: 0.1818 - val_mae: 0.3250
#
# Epoch 09962: val_loss did not improve from 0.17046
# Epoch 9963/10000
#  - 1s - loss: 0.0961 - mae: 0.1971 - val_loss: 0.1846 - val_mae: 0.3297
#
# Epoch 09963: val_loss did not improve from 0.17046
# Epoch 9964/10000
#  - 1s - loss: 0.0945 - mae: 0.1955 - val_loss: 0.1858 - val_mae: 0.3322
#
# Epoch 09964: val_loss did not improve from 0.17046
# Epoch 9965/10000
#  - 1s - loss: 0.0964 - mae: 0.1988 - val_loss: 0.1802 - val_mae: 0.3263
#
# Epoch 09965: val_loss did not improve from 0.17046
# Epoch 9966/10000
#  - 1s - loss: 0.0957 - mae: 0.2006 - val_loss: 0.1862 - val_mae: 0.3355
#
# Epoch 09966: val_loss did not improve from 0.17046
# Epoch 9967/10000
#  - 1s - loss: 0.0949 - mae: 0.1955 - val_loss: 0.1840 - val_mae: 0.3292
#
# Epoch 09967: val_loss did not improve from 0.17046
# Epoch 9968/10000
#  - 1s - loss: 0.0961 - mae: 0.1986 - val_loss: 0.1829 - val_mae: 0.3269
#
# Epoch 09968: val_loss did not improve from 0.17046
# Epoch 9969/10000
#  - 1s - loss: 0.0941 - mae: 0.1952 - val_loss: 0.1857 - val_mae: 0.3310
#
# Epoch 09969: val_loss did not improve from 0.17046
# Epoch 9970/10000
#  - 1s - loss: 0.0934 - mae: 0.1931 - val_loss: 0.1888 - val_mae: 0.3315
#
# Epoch 09970: val_loss did not improve from 0.17046
# Epoch 9971/10000
#  - 1s - loss: 0.0969 - mae: 0.1981 - val_loss: 0.1825 - val_mae: 0.3263
#
# Epoch 09971: val_loss did not improve from 0.17046
# Epoch 9972/10000
#  - 1s - loss: 0.0947 - mae: 0.1946 - val_loss: 0.1834 - val_mae: 0.3274
#
# Epoch 09972: val_loss did not improve from 0.17046
# Epoch 9973/10000
#  - 1s - loss: 0.0939 - mae: 0.1949 - val_loss: 0.1858 - val_mae: 0.3312
#
# Epoch 09973: val_loss did not improve from 0.17046
# Epoch 9974/10000
#  - 1s - loss: 0.0951 - mae: 0.1957 - val_loss: 0.1819 - val_mae: 0.3265
#
# Epoch 09974: val_loss did not improve from 0.17046
# Epoch 9975/10000
#  - 1s - loss: 0.0943 - mae: 0.1948 - val_loss: 0.1888 - val_mae: 0.3350
#
# Epoch 09975: val_loss did not improve from 0.17046
# Epoch 9976/10000
#  - 1s - loss: 0.0958 - mae: 0.1979 - val_loss: 0.1824 - val_mae: 0.3261
#
# Epoch 09976: val_loss did not improve from 0.17046
# Epoch 9977/10000
#  - 1s - loss: 0.0942 - mae: 0.1949 - val_loss: 0.1882 - val_mae: 0.3335
#
# Epoch 09977: val_loss did not improve from 0.17046
# Epoch 9978/10000
#  - 1s - loss: 0.0954 - mae: 0.1967 - val_loss: 0.1875 - val_mae: 0.3314
#
# Epoch 09978: val_loss did not improve from 0.17046
# Epoch 9979/10000
#  - 1s - loss: 0.0957 - mae: 0.1962 - val_loss: 0.1797 - val_mae: 0.3243
#
# Epoch 09979: val_loss did not improve from 0.17046
# Epoch 9980/10000
#  - 1s - loss: 0.0949 - mae: 0.1954 - val_loss: 0.1829 - val_mae: 0.3282
#
# Epoch 09980: val_loss did not improve from 0.17046
# Epoch 9981/10000
#  - 1s - loss: 0.0973 - mae: 0.2020 - val_loss: 0.1836 - val_mae: 0.3290
#
# Epoch 09981: val_loss did not improve from 0.17046
# Epoch 9982/10000
#  - 1s - loss: 0.0957 - mae: 0.1977 - val_loss: 0.1842 - val_mae: 0.3286
#
# Epoch 09982: val_loss did not improve from 0.17046
# Epoch 9983/10000
#  - 1s - loss: 0.0947 - mae: 0.1965 - val_loss: 0.1820 - val_mae: 0.3280
#
# Epoch 09983: val_loss did not improve from 0.17046
# Epoch 9984/10000
#  - 1s - loss: 0.0949 - mae: 0.1947 - val_loss: 0.1856 - val_mae: 0.3304
#
# Epoch 09984: val_loss did not improve from 0.17046
# Epoch 9985/10000
#  - 1s - loss: 0.0956 - mae: 0.1957 - val_loss: 0.1841 - val_mae: 0.3282
#
# Epoch 09985: val_loss did not improve from 0.17046
# Epoch 9986/10000
#  - 1s - loss: 0.0945 - mae: 0.1934 - val_loss: 0.1872 - val_mae: 0.3316
#
# Epoch 09986: val_loss did not improve from 0.17046
# Epoch 9987/10000
#  - 1s - loss: 0.0946 - mae: 0.1949 - val_loss: 0.1851 - val_mae: 0.3295
#
# Epoch 09987: val_loss did not improve from 0.17046
# Epoch 9988/10000
#  - 1s - loss: 0.0937 - mae: 0.1928 - val_loss: 0.1858 - val_mae: 0.3294
#
# Epoch 09988: val_loss did not improve from 0.17046
# Epoch 9989/10000
#  - 1s - loss: 0.0940 - mae: 0.1932 - val_loss: 0.1839 - val_mae: 0.3287
#
# Epoch 09989: val_loss did not improve from 0.17046
# Epoch 9990/10000
#  - 1s - loss: 0.0951 - mae: 0.1947 - val_loss: 0.1835 - val_mae: 0.3282
#
# Epoch 09990: val_loss did not improve from 0.17046
# Epoch 9991/10000
#  - 1s - loss: 0.0960 - mae: 0.1970 - val_loss: 0.1815 - val_mae: 0.3254
#
# Epoch 09991: val_loss did not improve from 0.17046
# Epoch 9992/10000
#  - 1s - loss: 0.0957 - mae: 0.1969 - val_loss: 0.1808 - val_mae: 0.3260
#
# Epoch 09992: val_loss did not improve from 0.17046
# Epoch 9993/10000
#  - 1s - loss: 0.0959 - mae: 0.1969 - val_loss: 0.1838 - val_mae: 0.3290
#
# Epoch 09993: val_loss did not improve from 0.17046
# Epoch 9994/10000
#  - 1s - loss: 0.0937 - mae: 0.1951 - val_loss: 0.1895 - val_mae: 0.3363
#
# Epoch 09994: val_loss did not improve from 0.17046
# Epoch 9995/10000
#  - 1s - loss: 0.1010 - mae: 0.2107 - val_loss: 0.1817 - val_mae: 0.3301
#
# Epoch 09995: val_loss did not improve from 0.17046
# Epoch 9996/10000
#  - 1s - loss: 0.0973 - mae: 0.2054 - val_loss: 0.1855 - val_mae: 0.3315
#
# Epoch 09996: val_loss did not improve from 0.17046
# Epoch 9997/10000
#  - 1s - loss: 0.0961 - mae: 0.1985 - val_loss: 0.1841 - val_mae: 0.3260
#
# Epoch 09997: val_loss did not improve from 0.17046
# Epoch 9998/10000
#  - 1s - loss: 0.0952 - mae: 0.1984 - val_loss: 0.1888 - val_mae: 0.3323
#
# Epoch 09998: val_loss did not improve from 0.17046
# Epoch 9999/10000
#  - 1s - loss: 0.0967 - mae: 0.1998 - val_loss: 0.1827 - val_mae: 0.3286
#
# Epoch 09999: val_loss did not improve from 0.17046
# Epoch 10000/10000
#  - 1s - loss: 0.0961 - mae: 0.1976 - val_loss: 0.1873 - val_mae: 0.3307
#
# Epoch 10000: val_loss did not improve from 0.17046

# %%
# Plot the training and validation loss
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot the training and validation MAE
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
# Load the best weights based on the optimal epoch
checkpoint_filepath = "../../../../../data/seq_weights_lr_sched_2.h5"
sequential.load_weights(checkpoint_filepath)

# %% [markdown]
# # Evaluate the model

# %%
# Evaluate the model on the test set
results = sequential.evaluate(data_test, y_test, batch_size=batch_size)
# Out:
# 75/75 [==============================] - 0s 294us/step

# %% [markdown]
# # Results

# %%
# Print the evaluation results
print("Test Loss:", results[0])
print("Test MAE:", results[1])
# Out:
# Test Loss: 0.13813328494628271
# Test MAE: 0.28268468379974365

# %%
# Find the epoch with the minimum validation loss
optimal_epoch = history.history['val_loss'].index(min(history.history['val_loss'])) + 1
print(f"Optimal Epoch: {optimal_epoch} loss: {history.history['val_loss'][optimal_epoch-1]}")
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\IPython\core\interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\debnathk\AppData\Local\Temp\ipykernel_13636\4083246319.py", line 2, in <module>
#     optimal_epoch = history.history['val_loss'].index(min(history.history['val_loss'])) + 1
# NameError: name 'history' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\IPython\core\interactiveshell.py", line 2077, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\inspect.py", line 1500, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\inspect.py", line 1458, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\tensorflow\__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\tensorflow\__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\tensorflow_core\contrib\__init__.py", line 71, in <module>
#     from tensorflow.contrib import opt
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\tensorflow_core\contrib\opt\__init__.py", line 22, in <module>
#     from tensorflow.contrib.opt.python.training.adam_gs_optimizer import *
#   File "c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\tensorflow_core\contrib\opt\__init__.py", line 30, in <module>
#     from tensorflow.contrib.opt.python.training.ggt import *
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 963, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 906, in _find_spec
#   File "<frozen importlib._bootstrap_external>", line 1280, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 1252, in _get_spec
#   File "<frozen importlib._bootstrap_external>", line 1364, in find_spec
#   File "<frozen importlib._bootstrap_external>", line 81, in _path_stat
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp\ipykernel_13636\4083246319.py in <module>
#       1 # Find the epoch with the minimum validation loss
# ----> 2 optimal_epoch = history.history['val_loss'].index(min(history.history['val_loss'])) + 1
#       3 print(f"Optimal Epoch: {optimal_epoch} loss: {history.history['val_loss'][optimal_epoch-1]}")
#
# NameError: name 'history' is not defined
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2076                         # in the engines. This should return a list of strings.
# -> 2077                         stb = value._render_traceback_()
#    2078                     except Exception:
#
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2078                     except Exception:
#    2079                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2080                                             value, tb, tb_offset=tb_offset)
#    2081
#    2082                     self._showtraceback(etype, value, stb)
#
# c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# c:\Users\debnathk\AppData\Local\miniconda3\envs\dleps\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import numpy as np
y_pred = sequential.predict(data_test)
print(np.corrcoef(y_test, y_pred.ravel()))
print(r2_score(y_test, y_pred))
plt.scatter(y_test, y_pred)
m, b = np.polyfit(y_test, y_pred, 1)
plt.plot(y_test, m * y_test + b, 'r')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.show()
# Out:
# [[1.         0.48627715]
#  [0.48627715 1.        ]]
# 0.2243856126265178

# %% [markdown]
# # Save model weights

# %%
# sequential.save_weights('../../data/sequential.h5')
# print("Model weights saved to 'sequential.h5'")

# %% [markdown]
# # Finish!

# %% [markdown]
# # Test the model

# %%
# Load test set for gene expression data
# h5f = h5py.File('../../data/gene_exp_test_data.h5', 'r')
# seq_test_data = h5f['data'][:]
# h5f = h5py.File('../../data/vae_test_data.h5', 'r')
# vae_test_data = h5f['data'][:]

# print(seq_test_data.shape)
# print(vae_test_data.shape)

# %%
# from densenet import DenseNet

# model = DenseNet()
# model.summary()
