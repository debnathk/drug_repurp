# %%
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID" 
os.environ["CUDA_VISIBLE_DEVICES"] = "4"

# %%
import sys
sys.path.append('../DLEPS')
import molecule_vae
from rdkit.Chem import MolFromSmiles, MolToSmiles
from rdkit.Chem import Draw

import numpy as np  
import pandas as pd
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From c:\Anaconda3\envs\dleps\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
def normalize(x):
    return 2*(x-x.min())/(x.max()-x.min())-1

# %%
df_drug_appostasis =  pd.read_csv("../../data/drug full screening data NEW edited.csv")
df_drug_appostasis.head()
# Out:
#         DRUG NAME  MDA7+D1+1  MDA7+D1+2  MDA7+D1+3  MDA7+D2+1  MDA7+D2+2  \
# 0  Angiotensin II   0.467198   0.492122   0.500198   0.651233   0.762780
# 1   Levetiracetam   0.424844   0.503705   0.433523   0.517083   0.498133
# 2      Daptomycin   0.462072   0.509482   0.424083   0.451883   0.495565
# 3    Lansoprazole   0.464806   0.494925   0.502533   0.491361   0.479975
# 4       Adapalene   0.407362   0.425062   0.490854   0.489590   0.513733
#
#    MDA7+D2+3      D1+1      D1+2      D1+3  ...  MDA7+D1+9  MDA7+D2+7  \
# 0   0.484070  0.878523  0.952131  1.122307  ...        NaN        NaN
# 1   0.485443  0.985621  1.002564  1.297499  ...        NaN        NaN
# 2   0.472871  0.980899  0.906619  0.982075  ...        NaN        NaN
# 3   0.443513  1.363714  0.919337  1.273511  ...        NaN        NaN
# 4   0.395002  0.437537  0.569486  0.435191  ...        NaN        NaN
#
#    MDA7+D2+8  MDA7+D2+9  D1+7  D1+8  D1+9  D2+7  D2+8  D2+9
# 0        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4        NaN        NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 37 columns]

# %%
### average response on MDA7+D1
### Removing highly varibale gene
cols = ["MDA7+D1+" + str(i) for i in range(1,7)]
df_drug_appostasis["MDA7+D1+Mean"] = df_drug_appostasis[cols].mean(axis=1)
df_drug_appostasis["MDA7+D1+std"] = df_drug_appostasis[cols].std(axis=1)
df_drug_appostasis = df_drug_appostasis[df_drug_appostasis["MDA7+D1+std"] < 0.3]
df_drug_appostasis = df_drug_appostasis[df_drug_appostasis["MDA7+D1+Mean"] < 1.2]
df_drug_appostasis["MDA7+D1+Mean"] = normalize(df_drug_appostasis["MDA7+D1+Mean"])
df_drug_appostasis.head()
# Out:
#         DRUG NAME  MDA7+D1+1  MDA7+D1+2  MDA7+D1+3  MDA7+D2+1  MDA7+D2+2  \
# 0  Angiotensin II   0.467198   0.492122   0.500198   0.651233   0.762780
# 1   Levetiracetam   0.424844   0.503705   0.433523   0.517083   0.498133
# 2      Daptomycin   0.462072   0.509482   0.424083   0.451883   0.495565
# 3    Lansoprazole   0.464806   0.494925   0.502533   0.491361   0.479975
# 4       Adapalene   0.407362   0.425062   0.490854   0.489590   0.513733
#
#    MDA7+D2+3      D1+1      D1+2      D1+3  ...  MDA7+D2+8  MDA7+D2+9  D1+7  \
# 0   0.484070  0.878523  0.952131  1.122307  ...        NaN        NaN   NaN
# 1   0.485443  0.985621  1.002564  1.297499  ...        NaN        NaN   NaN
# 2   0.472871  0.980899  0.906619  0.982075  ...        NaN        NaN   NaN
# 3   0.443513  1.363714  0.919337  1.273511  ...        NaN        NaN   NaN
# 4   0.395002  0.437537  0.569486  0.435191  ...        NaN        NaN   NaN
#
#    D1+8  D1+9  D2+7  D2+8  D2+9  MDA7+D1+Mean  MDA7+D1+std
# 0   NaN   NaN   NaN   NaN   NaN     -0.229274     0.017202
# 1   NaN   NaN   NaN   NaN   NaN     -0.285375     0.043243
# 2   NaN   NaN   NaN   NaN   NaN     -0.266051     0.042786
# 3   NaN   NaN   NaN   NaN   NaN     -0.227693     0.019951
# 4   NaN   NaN   NaN   NaN   NaN     -0.307710     0.043994
#
# [5 rows x 39 columns]

# %%
# Note: Add missing SMILE string
df_smile = pd.read_csv("../../data/L1021-DiscoveryProbe-FDA-approved-drug-Library 1971 COMPOUNDS_cleaned.csv")
df_smile.head()
# Out:
#   CatalogNumber       Item Name   CAS Number Plate Location Rack Number  \
# 0         A1042  Angiotensin II    4474-91-3            A01    L1021-01
# 1         A1198   Levetiracetam  102767-28-2            A02    L1021-01
# 2         A1206      Daptomycin  103060-53-3            A03    L1021-01
# 3         A1229    Lansoprazole  103577-45-3            A04    L1021-01
# 4         A1267       Adapalene  106685-40-9            A05    L1021-01
#
#       M.w.        Formula                                             SMILES  \
# 0   1046.2   C50H71N13O12                                                NaN
# 1   170.21      C8H14N2O2                               CCC(C(=O)N)N1CCCC1=O
# 2  1620.67  C72H101N17O26  CCCCCCCCCC(=O)NC(CC1=CNC2=CC=CC=C21)C(=O)NC(CC...
# 3   369.36  C16H14F3N3O2S    CC1=C(C=CN=C1CS(=O)C2=NC3=CC=CC=C3N2)OCC(F)(F)F
# 4   412.52       C28H28O3  COC1=C(C=C(C=C1)C2=CC3=C(C=C2)C=C(C=C3)C(=O)O)...
#
#                                Solubility       Form         Pathway  \
# 0  ≥100.2mg/mL in H2O, <2.09mg/mL in DMSO        NaN  Cancer Biology
# 1                       >8.5mg/mL in DMSO  Free Base  Cancer Biology
# 2                      >81.1mg/mL in DMSO  Free Base  Cancer Biology
# 3                      >18.5mg/mL in DMSO  Free Base  Cancer Biology
# 4                      >10.3mg/mL in DMSO  Free Base  Cancer Biology
#
#                       Target            Indication  \
# 0             Cardiovascular                   NaN
# 1  Other Signal Transduction  Neurological Disease
# 2              DNA Synthesis             Infection
# 3                Proton Pump             Infection
# 4                     Others          Inflammation
#
#                     Information  \
# 0                           NaN
# 1            Antiepileptic drug
# 2  Calcium-dependent antibiotic
# 3        H+,K+-ATPase inhibitor
# 4         RARβ and RARγ agonist
#
#                                               URL
# 0  http://www.apexbt.com/search.php?catalog=A1042
# 1  http://www.apexbt.com/search.php?catalog=A1198
# 2  http://www.apexbt.com/search.php?catalog=A1206
# 3  http://www.apexbt.com/search.php?catalog=A1229
# 4  http://www.apexbt.com/search.php?catalog=A1267

# %%
sum(df_smile["SMILES"].notna())
# Out:
# 1743

# %%
df_merged = df_drug_appostasis.merge(df_smile, left_on="DRUG NAME", right_on="Item Name")
df_merged.head()
# Out:
#         DRUG NAME  MDA7+D1+1  MDA7+D1+2  MDA7+D1+3  MDA7+D2+1  MDA7+D2+2  \
# 0  Angiotensin II   0.467198   0.492122   0.500198   0.651233   0.762780
# 1   Levetiracetam   0.424844   0.503705   0.433523   0.517083   0.498133
# 2      Daptomycin   0.462072   0.509482   0.424083   0.451883   0.495565
# 3    Lansoprazole   0.464806   0.494925   0.502533   0.491361   0.479975
# 4       Adapalene   0.407362   0.425062   0.490854   0.489590   0.513733
#
#    MDA7+D2+3      D1+1      D1+2      D1+3  ...     M.w.        Formula  \
# 0   0.484070  0.878523  0.952131  1.122307  ...   1046.2   C50H71N13O12
# 1   0.485443  0.985621  1.002564  1.297499  ...   170.21      C8H14N2O2
# 2   0.472871  0.980899  0.906619  0.982075  ...  1620.67  C72H101N17O26
# 3   0.443513  1.363714  0.919337  1.273511  ...   369.36  C16H14F3N3O2S
# 4   0.395002  0.437537  0.569486  0.435191  ...   412.52       C28H28O3
#
#                                               SMILES  \
# 0                                                NaN
# 1                               CCC(C(=O)N)N1CCCC1=O
# 2  CCCCCCCCCC(=O)NC(CC1=CNC2=CC=CC=C21)C(=O)NC(CC...
# 3    CC1=C(C=CN=C1CS(=O)C2=NC3=CC=CC=C3N2)OCC(F)(F)F
# 4  COC1=C(C=C(C=C1)C2=CC3=C(C=C2)C=C(C=C3)C(=O)O)...
#
#                                Solubility       Form         Pathway  \
# 0  ≥100.2mg/mL in H2O, <2.09mg/mL in DMSO        NaN  Cancer Biology
# 1                       >8.5mg/mL in DMSO  Free Base  Cancer Biology
# 2                      >81.1mg/mL in DMSO  Free Base  Cancer Biology
# 3                      >18.5mg/mL in DMSO  Free Base  Cancer Biology
# 4                      >10.3mg/mL in DMSO  Free Base  Cancer Biology
#
#                       Target            Indication  \
# 0             Cardiovascular                   NaN
# 1  Other Signal Transduction  Neurological Disease
# 2              DNA Synthesis             Infection
# 3                Proton Pump             Infection
# 4                     Others          Inflammation
#
#                     Information  \
# 0                           NaN
# 1            Antiepileptic drug
# 2  Calcium-dependent antibiotic
# 3        H+,K+-ATPase inhibitor
# 4         RARβ and RARγ agonist
#
#                                               URL
# 0  http://www.apexbt.com/search.php?catalog=A1042
# 1  http://www.apexbt.com/search.php?catalog=A1198
# 2  http://www.apexbt.com/search.php?catalog=A1206
# 3  http://www.apexbt.com/search.php?catalog=A1229
# 4  http://www.apexbt.com/search.php?catalog=A1267
#
# [5 rows x 54 columns]

# %%
print(len(df_drug_appostasis), len(df_smile), len(df_merged))
# Out:
# 1946 1971 1940

# %%
df_merged_cleaned = df_merged[df_merged['SMILES'].notna()]
print(len(df_merged_cleaned))
# Out:
# 1714

# %%
smiles = df_merged_cleaned['SMILES'].values

# %%
print(smiles[2])
MolToSmiles(MolFromSmiles(smiles[2]))
# Out:
# CC1=C(C=CN=C1CS(=O)C2=NC3=CC=CC=C3N2)OCC(F)(F)F
# 'Cc1c(OCC(F)(F)F)ccnc1CS(=O)c1nc2ccccc2[nH]1'

# %%
#smiles = smiles[:100]
smiles_rdkit = []
iid = []
bad_iid = []
for i in range(len(smiles)):
    try:
        smiles_rdkit.append(MolToSmiles(MolFromSmiles(smiles[ i ])))
        iid.append(i)
    except:
        bad_iid.append(i)
        print("Error at %d" % (i))
# Out:
# Error at 75
# Error at 82
# Error at 126
# Error at 158
# Error at 432
# Error at 851
# Error at 853
# Error at 1329
# Error at 1373

# %%
print(len(smiles))
print(len(iid))
# Out:
# 1714
# 1705

# %%
def get_zinc_tokenizer(cfg):
    long_tokens = [a for a in list(cfg._lexical_index.keys()) if xlength(a) > 1] ####
    replacements = ['$','%','^'] # ,'&']
    assert xlength(long_tokens) == len(replacements) ####xzw
    for token in replacements: 
        assert token not in cfg._lexical_index ####
    
    def tokenize(smiles):
        for i, token in enumerate(long_tokens):
            smiles = smiles.replace(token, replacements[i])
        tokens = []
        for token in smiles:
            try:
                ix = replacements.index(token)
                tokens.append(long_tokens[ix])
            except:
                tokens.append(token)
        return tokens
    
    return tokenize

# %%
from functools import reduce

def xlength(y):
    return reduce(lambda sum, element: sum + 1, y, 0)

# %%
import zinc_grammar
import nltk

_tokenize = get_zinc_tokenizer(zinc_grammar.GCFG)
_parser = nltk.ChartParser(zinc_grammar.GCFG)
_productions = zinc_grammar.GCFG.productions()
_prod_map = {}
for ix, prod in enumerate(_productions):
    _prod_map[prod] = ix
MAX_LEN = 277
_n_chars = len(_productions)

# %%
_parser

# %%
""" Encode a list of smiles strings into the latent space """
assert type(smiles_rdkit) == list
tokens = map(_tokenize, smiles_rdkit)
parse_trees = []
i = 0
badi = []
for t in tokens:
    #while True:
    try:
        tp = next(_parser.parse(t))
        parse_trees.append(tp)
    except:
        print("Parse tree error at %d" % i)
        badi.append(i)
    i += 1
    #print(i)
productions_seq = [tree.productions() for tree in parse_trees]
indices = [np.array([_prod_map[prod] for prod in entry], dtype=int) for entry in productions_seq]
one_hot = np.zeros((len(indices), MAX_LEN, _n_chars), dtype=np.float32)
for i in range(len(indices)):
    num_productions = len(indices[i])
    if num_productions > MAX_LEN:
        print("Too large molecules, out of range")
    #print("i=  {%d} len(indices)=  {%d} num_productions = %d " % (i,len(indices),num_productions))
        one_hot[i][np.arange(MAX_LEN),indices[i][:MAX_LEN]] = 1.
    else:    
        one_hot[i][np.arange(num_productions),indices[i]] = 1.
        one_hot[i][np.arange(num_productions, MAX_LEN),-1] = 1.
# Out:
# Parse tree error at 4
# Parse tree error at 8
# Parse tree error at 10
# Parse tree error at 14
# Parse tree error at 16
# Parse tree error at 18
# Parse tree error at 21
# Parse tree error at 24
# Parse tree error at 32
# Parse tree error at 34
# Parse tree error at 35
# Parse tree error at 36
# Parse tree error at 37
# Parse tree error at 38
# Parse tree error at 39
# Parse tree error at 40
# Parse tree error at 41
# Parse tree error at 54
# Parse tree error at 56
# Parse tree error at 61
# Parse tree error at 67
# Parse tree error at 70
# Parse tree error at 71
# Parse tree error at 72
# Parse tree error at 74
# Parse tree error at 76
# Parse tree error at 77
# Parse tree error at 79
# Parse tree error at 82
# Parse tree error at 90
# Parse tree error at 110
# Parse tree error at 112
# Parse tree error at 113
# Parse tree error at 115
# Parse tree error at 116
# Parse tree error at 122
# Parse tree error at 123
# Parse tree error at 129
# Parse tree error at 131
# Parse tree error at 136
# Parse tree error at 137
# Parse tree error at 139
# Parse tree error at 141
# Parse tree error at 143
# Parse tree error at 148
# Parse tree error at 151
# Parse tree error at 152
# Parse tree error at 153
# Parse tree error at 156
# Parse tree error at 157
# Parse tree error at 160
# Parse tree error at 162
# Parse tree error at 164
# Parse tree error at 165
# Parse tree error at 167
# Parse tree error at 170
# Parse tree error at 174
# Parse tree error at 175
# Parse tree error at 178
# Parse tree error at 179
# Parse tree error at 184
# Parse tree error at 187
# Parse tree error at 188
# Parse tree error at 193
# Parse tree error at 195
# Parse tree error at 196
# Parse tree error at 197
# Parse tree error at 198
# Parse tree error at 202
# Parse tree error at 203
# Parse tree error at 204
# Parse tree error at 207
# Parse tree error at 209
# Parse tree error at 213
# Parse tree error at 221
# Parse tree error at 224
# Parse tree error at 227
# Parse tree error at 243
# Parse tree error at 244
# Parse tree error at 248
# Parse tree error at 254
# Parse tree error at 266
# Parse tree error at 267
# Parse tree error at 271
# Parse tree error at 274
# Parse tree error at 280
# Parse tree error at 282
# Parse tree error at 297
# Parse tree error at 302
# Parse tree error at 304
# Parse tree error at 308
# Parse tree error at 311
# Parse tree error at 312
# Parse tree error at 313
# Parse tree error at 314
# Parse tree error at 321
# Parse tree error at 330
# Parse tree error at 334
# Parse tree error at 338
# Parse tree error at 339
# Parse tree error at 341
# Parse tree error at 342
# Parse tree error at 345
# Parse tree error at 346
# Parse tree error at 347
# Parse tree error at 349
# Parse tree error at 350
# Parse tree error at 351
# Parse tree error at 355
# Parse tree error at 357
# Parse tree error at 360
# Parse tree error at 367
# Parse tree error at 373
# Parse tree error at 377
# Parse tree error at 389
# Parse tree error at 409
# Parse tree error at 412
# Parse tree error at 415
# Parse tree error at 419
# Parse tree error at 422
# Parse tree error at 428
# Parse tree error at 431
# Parse tree error at 435
# Parse tree error at 438
# Parse tree error at 440
# Parse tree error at 442
# Parse tree error at 444
# Parse tree error at 447
# Parse tree error at 453
# Parse tree error at 455
# Parse tree error at 462
# Parse tree error at 466
# Parse tree error at 467
# Parse tree error at 471
# Parse tree error at 472
# Parse tree error at 473
# Parse tree error at 476
# Parse tree error at 477
# Parse tree error at 478
# Parse tree error at 479
# Parse tree error at 485
# Parse tree error at 497
# Parse tree error at 499
# Parse tree error at 506
# Parse tree error at 509
# Parse tree error at 511
# Parse tree error at 519
# Parse tree error at 521
# Parse tree error at 526
# Parse tree error at 528
# Parse tree error at 532
# Parse tree error at 535
# Parse tree error at 536
# Parse tree error at 537
# Parse tree error at 544
# Parse tree error at 545
# Parse tree error at 546
# Parse tree error at 549
# Parse tree error at 559
# Parse tree error at 566
# Parse tree error at 567
# Parse tree error at 573
# Parse tree error at 578
# Parse tree error at 582
# Parse tree error at 584
# Parse tree error at 592
# Parse tree error at 602
# Parse tree error at 607
# Parse tree error at 610
# Parse tree error at 612
# Parse tree error at 613
# Parse tree error at 615
# Parse tree error at 616
# Parse tree error at 619
# Parse tree error at 620
# Parse tree error at 621
# Parse tree error at 622
# Parse tree error at 623
# Parse tree error at 625
# Parse tree error at 628
# Parse tree error at 629
# Parse tree error at 630
# Parse tree error at 631
# Parse tree error at 632
# Parse tree error at 634
# Parse tree error at 636
# Parse tree error at 637
# Parse tree error at 639
# Parse tree error at 640
# Parse tree error at 641
# Parse tree error at 642
# Parse tree error at 643
# Parse tree error at 644
# Parse tree error at 645
# Parse tree error at 646
# Parse tree error at 647
# Parse tree error at 648
# Parse tree error at 649
# Parse tree error at 651
# Parse tree error at 652
# Parse tree error at 653
# Parse tree error at 654
# Parse tree error at 655
# Parse tree error at 656
# Parse tree error at 657
# Parse tree error at 658
# Parse tree error at 660
# Parse tree error at 662
# Parse tree error at 663
# Parse tree error at 664
# Parse tree error at 665
# Parse tree error at 667
# Parse tree error at 674
# Parse tree error at 676
# Parse tree error at 677
# Parse tree error at 679
# Parse tree error at 681
# Parse tree error at 682
# Parse tree error at 683
# Parse tree error at 686
# Parse tree error at 688
# Parse tree error at 690
# Parse tree error at 691
# Parse tree error at 692
# Parse tree error at 698
# Parse tree error at 699
# Parse tree error at 701
# Parse tree error at 707
# Parse tree error at 709
# Parse tree error at 717
# Parse tree error at 722
# Parse tree error at 724
# Parse tree error at 725
# Parse tree error at 729
# Parse tree error at 732
# Parse tree error at 734
# Parse tree error at 737
# Parse tree error at 738
# Parse tree error at 739
# Parse tree error at 741
# Parse tree error at 742
# Parse tree error at 746
# Parse tree error at 754
# Parse tree error at 755
# Parse tree error at 759
# Parse tree error at 760
# Parse tree error at 766
# Parse tree error at 767
# Parse tree error at 768
# Parse tree error at 770
# Parse tree error at 771
# Parse tree error at 772
# Parse tree error at 773
# Parse tree error at 775
# Parse tree error at 777
# Parse tree error at 778
# Parse tree error at 779
# Parse tree error at 780
# Parse tree error at 781
# Parse tree error at 782
# Parse tree error at 783
# Parse tree error at 785
# Parse tree error at 786
# Parse tree error at 788
# Parse tree error at 789
# Parse tree error at 791
# Parse tree error at 792
# Parse tree error at 793
# Parse tree error at 794
# Parse tree error at 795
# Parse tree error at 796
# Parse tree error at 797
# Parse tree error at 798
# Parse tree error at 799
# Parse tree error at 801
# Parse tree error at 802
# Parse tree error at 804
# Parse tree error at 805
# Parse tree error at 806
# Parse tree error at 807
# Parse tree error at 808
# Parse tree error at 809
# Parse tree error at 810
# Parse tree error at 811
# Parse tree error at 812
# Parse tree error at 813
# Parse tree error at 817
# Parse tree error at 818
# Parse tree error at 819
# Parse tree error at 823
# Parse tree error at 824
# Parse tree error at 825
# Parse tree error at 826
# Parse tree error at 827
# Parse tree error at 830
# Parse tree error at 834
# Parse tree error at 837
# Parse tree error at 838
# Parse tree error at 842
# Parse tree error at 843
# Parse tree error at 845
# Parse tree error at 848
# Parse tree error at 849
# Parse tree error at 850
# Parse tree error at 853
# Parse tree error at 854
# Parse tree error at 858
# Parse tree error at 860
# Parse tree error at 862
# Parse tree error at 871
# Parse tree error at 873
# Parse tree error at 878
# Parse tree error at 881
# Parse tree error at 882
# Parse tree error at 883
# Parse tree error at 884
# Parse tree error at 885
# Parse tree error at 886
# Parse tree error at 888
# Parse tree error at 895
# Parse tree error at 896
# Parse tree error at 899
# Parse tree error at 900
# Parse tree error at 905
# Parse tree error at 906
# Parse tree error at 907
# Parse tree error at 908
# Parse tree error at 909
# Parse tree error at 910
# Parse tree error at 911
# Parse tree error at 912
# Parse tree error at 913
# Parse tree error at 916
# Parse tree error at 917
# Parse tree error at 918
# Parse tree error at 919
# Parse tree error at 920
# Parse tree error at 921
# Parse tree error at 922
# Parse tree error at 925
# Parse tree error at 927
# Parse tree error at 929
# Parse tree error at 932
# Parse tree error at 933
# Parse tree error at 935
# Parse tree error at 936
# Parse tree error at 938
# Parse tree error at 939
# Parse tree error at 940
# Parse tree error at 941
# Parse tree error at 942
# Parse tree error at 945
# Parse tree error at 946
# Parse tree error at 947
# Parse tree error at 948
# Parse tree error at 949
# Parse tree error at 950
# Parse tree error at 959
# Parse tree error at 961
# Parse tree error at 964
# Parse tree error at 971
# Parse tree error at 972
# Parse tree error at 973
# Parse tree error at 980
# Parse tree error at 985
# Parse tree error at 988
# Parse tree error at 990
# Parse tree error at 993
# Parse tree error at 994
# Parse tree error at 998
# Parse tree error at 1000
# Parse tree error at 1001
# Parse tree error at 1002
# Parse tree error at 1005
# Parse tree error at 1006
# Parse tree error at 1010
# Parse tree error at 1011
# Parse tree error at 1014
# Parse tree error at 1016
# Parse tree error at 1024
# Parse tree error at 1025
# Parse tree error at 1027
# Parse tree error at 1029
# Parse tree error at 1030
# Parse tree error at 1031
# Parse tree error at 1032
# Parse tree error at 1039
# Parse tree error at 1040
# Parse tree error at 1041
# Parse tree error at 1043
# Parse tree error at 1047
# Parse tree error at 1056
# Parse tree error at 1059
# Parse tree error at 1060
# Parse tree error at 1066
# Parse tree error at 1068
# Parse tree error at 1071
# Parse tree error at 1072
# Parse tree error at 1074
# Parse tree error at 1078
# Parse tree error at 1080
# Parse tree error at 1082
# Parse tree error at 1084
# Parse tree error at 1087
# Parse tree error at 1088
# Parse tree error at 1091
# Parse tree error at 1092
# Parse tree error at 1101
# Parse tree error at 1106
# Parse tree error at 1108
# Parse tree error at 1109
# Parse tree error at 1111
# Parse tree error at 1112
# Parse tree error at 1113
# Parse tree error at 1122
# Parse tree error at 1131
# Parse tree error at 1132
# Parse tree error at 1134
# Parse tree error at 1137
# Parse tree error at 1140
# Parse tree error at 1143
# Parse tree error at 1145
# Parse tree error at 1148
# Parse tree error at 1149
# Parse tree error at 1152
# Parse tree error at 1162
# Parse tree error at 1170
# Parse tree error at 1172
# Parse tree error at 1174
# Parse tree error at 1176
# Parse tree error at 1183
# Parse tree error at 1188
# Parse tree error at 1200
# Parse tree error at 1201
# Parse tree error at 1203
# Parse tree error at 1204
# Parse tree error at 1212
# Parse tree error at 1215
# Parse tree error at 1221
# Parse tree error at 1222
# Parse tree error at 1224
# Parse tree error at 1225
# Parse tree error at 1228
# Parse tree error at 1230
# Parse tree error at 1231
# Parse tree error at 1233
# Parse tree error at 1239
# Parse tree error at 1240
# Parse tree error at 1241
# Parse tree error at 1243
# Parse tree error at 1246
# Parse tree error at 1247
# Parse tree error at 1249
# Parse tree error at 1250
# Parse tree error at 1251
# Parse tree error at 1252
# Parse tree error at 1255
# Parse tree error at 1256
# Parse tree error at 1258
# Parse tree error at 1261
# Parse tree error at 1263
# Parse tree error at 1264
# Parse tree error at 1267
# Parse tree error at 1268
# Parse tree error at 1271
# Parse tree error at 1274
# Parse tree error at 1277
# Parse tree error at 1279
# Parse tree error at 1281
# Parse tree error at 1282
# Parse tree error at 1284
# Parse tree error at 1286
# Parse tree error at 1287
# Parse tree error at 1289
# Parse tree error at 1290
# Parse tree error at 1291
# Parse tree error at 1292
# Parse tree error at 1294
# Parse tree error at 1295
# Parse tree error at 1297
# Parse tree error at 1298
# Parse tree error at 1302
# Parse tree error at 1306
# Parse tree error at 1313
# Parse tree error at 1322
# Parse tree error at 1324
# Parse tree error at 1328
# Parse tree error at 1329
# Parse tree error at 1334
# Parse tree error at 1336
# Parse tree error at 1340
# Parse tree error at 1345
# Parse tree error at 1357
# Parse tree error at 1358
# Parse tree error at 1359
# Parse tree error at 1360
# Parse tree error at 1361
# Parse tree error at 1363
# Parse tree error at 1369
# Parse tree error at 1372
# Parse tree error at 1374
# Parse tree error at 1379
# Parse tree error at 1380
# Parse tree error at 1386
# Parse tree error at 1392
# Parse tree error at 1393
# Parse tree error at 1396
# Parse tree error at 1397
# Parse tree error at 1401
# Parse tree error at 1402
# Parse tree error at 1405
# Parse tree error at 1406
# Parse tree error at 1407
# Parse tree error at 1411
# Parse tree error at 1416
# Parse tree error at 1429
# Parse tree error at 1430
# Parse tree error at 1431
# Parse tree error at 1432
# Parse tree error at 1433
# Parse tree error at 1436
# Parse tree error at 1437
# Parse tree error at 1438
# Parse tree error at 1439
# Parse tree error at 1441
# Parse tree error at 1442
# Parse tree error at 1443
# Parse tree error at 1444
# Parse tree error at 1448
# Parse tree error at 1450
# Parse tree error at 1451
# Parse tree error at 1453
# Parse tree error at 1454
# Parse tree error at 1456
# Parse tree error at 1470
# Parse tree error at 1474
# Parse tree error at 1476
# Parse tree error at 1477
# Parse tree error at 1483
# Parse tree error at 1485
# Parse tree error at 1487
# Parse tree error at 1489
# Parse tree error at 1500
# Parse tree error at 1501
# Parse tree error at 1503
# Parse tree error at 1505
# Parse tree error at 1508
# Parse tree error at 1509
# Parse tree error at 1511
# Parse tree error at 1513
# Parse tree error at 1518
# Parse tree error at 1522
# Parse tree error at 1523
# Parse tree error at 1526
# Parse tree error at 1527
# Parse tree error at 1529
# Parse tree error at 1530
# Parse tree error at 1533
# Parse tree error at 1542
# Parse tree error at 1544
# Parse tree error at 1550
# Parse tree error at 1552
# Parse tree error at 1558
# Parse tree error at 1560
# Parse tree error at 1561
# Parse tree error at 1563
# Parse tree error at 1565
# Parse tree error at 1567
# Parse tree error at 1582
# Parse tree error at 1588
# Parse tree error at 1592
# Parse tree error at 1621
# Parse tree error at 1639
# Parse tree error at 1661
# Parse tree error at 1662
# Parse tree error at 1676
# Parse tree error at 1697
# Parse tree error at 1700
# Parse tree error at 1701
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range
# Too large molecules, out of range

# %%
print(len(df_merged_cleaned), len(one_hot))
print(len(bad_iid), len(badi))
df_merged_final = df_merged_cleaned.drop(df_merged_cleaned.iloc[bad_iid].index)
df_merged_final = df_merged_final.drop(df_merged_final.iloc[badi].index)
print(len(df_merged_final))
ydata =  df_merged_final["MDA7+D1+Mean"].values
# Out:
# 1714 1126
# 9 579
# 1126

# %%
perm = np.arange(len(ydata))
np.random.shuffle(perm)
appostasis = ydata[perm]
smile_rd = one_hot[perm]
TEST_SIZE = 100
appostasis_train = appostasis[TEST_SIZE:]
smile_train = smile_rd[TEST_SIZE:]
appostasis_test = appostasis[:TEST_SIZE]
smile_test = smile_rd[:TEST_SIZE]

# %%
import h5py

h5f = h5py.File('../../data/SMILE_train_demo2.h5', 'w')
h5f.create_dataset('data', data=smile_train)
h5f.close()

h5f = h5py.File('../../data/appostasis_train_demo2.h5', 'w')
h5f.create_dataset('data', data=appostasis_train)
h5f.close()

h5f = h5py.File('../../data/SMILE_test_demo2.h5', 'w')
h5f.create_dataset('data', data=smile_test)
h5f.close()

h5f = h5py.File('../../data/appostasis_test_demo2.h5', 'w')
h5f.create_dataset('data', data=appostasis_test)
h5f.close()

# %%
smile_train.shape
# Out:
# (1026, 277, 76)

# %%
appostasis_train.shape
# Out:
# (1026,)
