# %%
import pandas as pd

# df_drug_names = pd.read_csv('../../data/l100_chemical_perturbagens.csv')
# df_drug_names

# %%
# conc = '10uM'
# gene_expression_df_10um_conc = df_drug_names[df_drug_names['0'].str.contains(conc)]
# gene_expression_df_10um_conc = gene_expression_df_10um_conc.reset_index(drop=True)
# gene_expression_df_10um_conc.to_csv('../data/l100_cp_10uM_all.csv', index=False)
gene_expression_df_10um_conc = pd.read_csv('../data/l1000_cp_10uM_all_filtered.csv', header=None)
gene_expression_df_10um_conc
# Out:
#                                               0         1       2         3    \
# 0            ABY001_A375_XH_A14_erlotinib_10uM up    CDKN2C   TIMP3  COLGALT2
# 1          ABY001_A375_XH_A14_erlotinib_10uM down      PCP4  SPINK1    STEAP1
# 2            ABY001_A375_XH_A16_lapatinib_10uM up    SLC1A3    TPPP   SELENOP
# 3          ABY001_A375_XH_A16_lapatinib_10uM down     PUF60  HSPA1A    SPINK1
# 4            ABY001_A375_XH_D13_pazopanib_10uM up  TMEM185B  COL9A3     DDX42
# ...                                           ...       ...     ...       ...
# 164671  TSAI002_NPC-5_XH_F22_wortmannin_10uM down    RPS4Y1  SORBS3     EPHX1
# 164672    TSAI002_NPC-6_XH_I21_wortmannin_10uM up     NAGPA    SAT1      RCN1
# 164673  TSAI002_NPC-6_XH_I21_wortmannin_10uM down    HMGCS1   MACF1    GOLT1B
# 164674    TSAI002_NPC-8_XH_I22_wortmannin_10uM up      RTN2   PPM1E     TPGS2
# 164675  TSAI002_NPC-8_XH_I22_wortmannin_10uM down  EBNA1BP2   CCNB1    LYPLA1
#
# ...

# %%
gene_expression_df_10um_conc_up = gene_expression_df_10um_conc[gene_expression_df_10um_conc[0].str.contains('up')]
gene_expression_df_10um_conc_up.to_csv('../data/l1000_cp_10uM_up.csv', index=False)
gene_expression_df_10um_conc_up
# Out:
#                                             0         1       2         3    \
# 0          ABY001_A375_XH_A14_erlotinib_10uM up    CDKN2C   TIMP3  COLGALT2
# 2          ABY001_A375_XH_A16_lapatinib_10uM up    SLC1A3    TPPP   SELENOP
# 4          ABY001_A375_XH_D13_pazopanib_10uM up  TMEM185B  COL9A3     DDX42
# 6        ABY001_A375_XH_D15_fulvestrant_10uM up     GNAI1   FLRT3     GRB14
# 8         ABY001_A375_XH_D16_vorinostat_10uM up    TTC39A    VCAN     ANXA9
# ...                                         ...       ...     ...       ...
# 164666  TSAI002_NPC-3_XH_C22_wortmannin_10uM up     RUFY3    CTSG  PPP1R15A
# 164668  TSAI002_NPC-4_XH_F21_wortmannin_10uM up   APBB1IP     VIM    IFI44L
# 164670  TSAI002_NPC-5_XH_F22_wortmannin_10uM up     RFTN1  LGALS9     IFI16
# 164672  TSAI002_NPC-6_XH_I21_wortmannin_10uM up     NAGPA    SAT1      RCN1
# 164674  TSAI002_NPC-8_XH_I22_wortmannin_10uM up      RTN2   PPM1E     TPGS2
#
# ...

# %%
gene_expression_df_10um_conc_down = gene_expression_df_10um_conc[gene_expression_df_10um_conc[0].str.contains('down')]
gene_expression_df_10um_conc_down.to_csv('../data/l1000_cp_10uM_down.csv', index=False)
gene_expression_df_10um_conc_down
# Out:
#                                               0         1         2       3    \
# 1          ABY001_A375_XH_A14_erlotinib_10uM down      PCP4    SPINK1  STEAP1
# 3          ABY001_A375_XH_A16_lapatinib_10uM down     PUF60    HSPA1A  SPINK1
# 5          ABY001_A375_XH_D13_pazopanib_10uM down    MRPS16      PIN1    XIST
# 7        ABY001_A375_XH_D15_fulvestrant_10uM down      GNAS    MRPS16  RPS4Y1
# 9         ABY001_A375_XH_D16_vorinostat_10uM down     JMJD6     ALCAM   BASP1
# ...                                           ...       ...       ...     ...
# 164667  TSAI002_NPC-3_XH_C22_wortmannin_10uM down     TUBB6     PDGFC   ZMYM2
# 164669  TSAI002_NPC-4_XH_F21_wortmannin_10uM down    MAP4K4  ITGB1BP1    ATG3
# 164671  TSAI002_NPC-5_XH_F22_wortmannin_10uM down    RPS4Y1    SORBS3   EPHX1
# 164673  TSAI002_NPC-6_XH_I21_wortmannin_10uM down    HMGCS1     MACF1  GOLT1B
# 164675  TSAI002_NPC-8_XH_I22_wortmannin_10uM down  EBNA1BP2     CCNB1  LYPLA1
#
# ...

# %%
import pandas as pd
df_gene_info = pd.read_csv('../data/compoundinfo_beta.txt', sep='\t')
df_gene_info = df_gene_info.dropna(subset=['canonical_smiles'])
df_gene_info.to_csv('../data/compoundinfo_beta.csv', index=False)
df_gene_info
# Out:
#              pert_id      cmap_name target  \
# 0      BRD-A08715367     L-theanine    NaN
# 1      BRD-A12237696   L-citrulline    NaN
# 2      BRD-A18795974  BRD-A18795974    NaN
# 3      BRD-A27924917  BRD-A27924917    NaN
# 4      BRD-A35931254  BRD-A35931254    NaN
# ...              ...            ...    ...
# 39316  BRD-K62685538    triptorelin  GNRHR
# 39317  BRD-K62221994        T-98475  GNRHR
# 39318  BRD-K53397409   benzoic-acid  RAB9A
# 39319  BRD-A62182663        YK-4279   DHX9
# 39320  BRD-A62182663        YK-4279   FLI1
#
#                                                      moa  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# ...
